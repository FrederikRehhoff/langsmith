# %%
# %%capture --no-stderr
# %pip install -U langchain langimport os langchainhub
# Out:
# ERROR: Could not find a version that satisfies the requirement langimport (from versions: none)
# ERROR: No matching distribution found for langimport
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Initialize environment variables

# %%
import os
os.environ["OPENAI_API_KEY"] = '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'
os.environ["LANGCHAIN_API_KEY"] = 'ls__c0f826e0c4514d678c5fdec4a48e6b92'
os.environ["TAVILY_API_KEY"] = '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'

# %%
# %pip install langchainhub
# Out:
# Requirement already satisfied: langchainhub in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (0.1.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0.20240403)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from google.colab import userdata
import getpass
import os



def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass(f"Please provide your {var}")

_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("LANGCHAIN_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
# os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")
# os.environ["LANGCHAIN_API_KEY"] = userdata.get("LANGCHAIN_API_KEY")

# Optional, add tracing in LangSmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "Normal"

# %% [markdown]
# ## Initialize dummy robots
#
# This code is the simplified version of the actual agent code. This is only to show that the tools for the llm is working with the robot class

# %%
from typing import Tuple
import random

class Agent(object):
    def __init__(self, name, position, color, tool_property, inventory, status="idle"):
        self._name = name
        self._position = position
        self._color = color
        self._goal = None
        self._status = status
        self.tool_property = tool_property
        self._inventory = []
        

    def setGoal(self, goal):
        """Sets the Goal for the robot"""
        self._goal = goal
        self.set_status("active")


    def set_status(self, status="idle"):
        if status in ["idle", "active", "charging"]:
            old_status = self._status
            self._status = status
            if self._status == "idle":
                self._goal = None
    
    def add_item_invetory(self, item):
        self._inventory.append(item)

    @property
    def tool_property(self) -> str:
        """agent tool i.e gripper"""
        return self._tool_property
    
    @tool_property.setter
    def tool_property(self, new_tool):
        self._tool_property = new_tool

    @property
    def inventory(self) -> list:
        """ An agents inventory """
        return self._inventory

    @property
    def position(self) -> Tuple[int, int]:
        """ The position of the agent """
        return self._position

    @position.setter
    def position(self, new_position: Tuple[int, int]):
        """ Set the new position

        :new_position: The new node id

        """
        self._position = new_position

    @property
    def name(self) -> str:
        """ The name of the agent """
        return self._name

    @name.setter
    def name(self, new_name: str):
        """ Sets a new name for the agent

        :new_name: The new name for the agent

        """
        self._name = new_name

    @property
    def color(self) -> str:
        """ The color of the agent """
        return self._color

    @color.setter
    def color(self, new_color: str):
        """ Sets a new color for the agent

        :new_goal: The new color for the agent

        """
        self._color = new_color

    @property
    def goal(self) -> Tuple[int, int]:
        """ The goal of the agent """
        return self._goal

    @goal.setter
    def goal(self, new_goal: Tuple[int, int]):
        """ Set the new goal

        :new_goal: The new goal node id

        """
        self._goal = new_goal

# %%
# Available tools is: lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum
# define agents:  ('name', placement: (x,y), 'color', Property, inventory)
R1 = Agent("Robot1", (12, 4), "aqua", "lawnmower", None, "active")
R2 = Agent("Robot2", (4, 6), "maroon", "gripper", None, "charging")
R3 = Agent("Robot3", (4, 12), "green", "tow hook", None, "active")
R4 = Agent("Robot4", (5, 1), "purple", "saw", None, "active")
R5 = Agent("Robot5", (9, 2), "orange", "screwdriver", None, "active")
R6 = Agent("Robot6", (3, 10), "pink", "mop", None, "charging")
R7 = Agent("Robot7", (5, 7), "blue", "spray nozzle", None, "active")
R8 = Agent("Robot8", (8, 3), "olive", "broom", None, "idle")
R9 = Agent("Robot9", (5, 10), "silver", "front loader", None, "charging")
R10 = Agent("Robot10", (10, 6), "cyan", "vacuum", None, "charging")
R11 = Agent("Robot11", (11, 5), "navy", "lawnmower", None, "charging")
R12 = Agent("Robot12", (1, 6), "yellow", "gripper", None, "active")
R13 = Agent("Robot13", (1, 9), "pink", "tow hook", None, "charging")
R14 = Agent("Robot14", (11, 11), "silver", "saw", None, "idle")
R15 = Agent("Robot15", (6, 11), "orange", "screwdriver", None, "charging")
R16 = Agent("Robot16", (6, 8), "olive", "mop", None, "active")
R17 = Agent("Robot17", (12, 9), "fuchsia", "spray nozzle", None, "idle")
R18 = Agent("Robot18", (4, 5), "black", "broom", None, "active")
R19 = Agent("Robot19", (3, 12), "magenta", "front loader", None, "idle")
R20 = Agent("Robot20", (5, 9), "black", "vacuum", None, "active")
R21 = Agent("Robot21", (9, 7), "magenta", "lawnmower", None, "charging")
R22 = Agent("Robot22", (8, 11), "blue", "gripper", None, "idle")
R23 = Agent("Robot23", (11, 7), "silver", "tow hook", None, "idle")
R24 = Agent("Robot24", (10, 5), "navy", "saw", None, "idle")
R25 = Agent("Robot25", (10, 11), "white", "screwdriver", None, "active")
R26 = Agent("Robot26", (1, 2), "aqua", "mop", None, "idle")
R27 = Agent("Robot27", (2, 1), "white", "spray nozzle", None, "charging")
R28 = Agent("Robot28", (2, 7), "navy", "broom", None, "charging")
R29 = Agent("Robot29", (10, 8), "aqua", "front loader", None, "charging")
R30 = Agent("Robot30", (7, 12), "fuchsia", "vacuum", None, "active")
R31 = Agent("Robot31", (12, 2), "fuchsia", "lawnmower", None, "charging")
R32 = Agent("Robot32", (12, 8), "olive", "gripper", None, "charging")
R33 = Agent("Robot33", (5, 5), "lime", "tow hook", None, "active")
R34 = Agent("Robot34", (8, 4), "black", "saw", None, "active")
R35 = Agent("Robot35", (5, 11), "black", "screwdriver", None, "idle")
R36 = Agent("Robot36", (5, 8), "olive", "mop", None, "active")
R37 = Agent("Robot37", (8, 1), "maroon", "spray nozzle", None, "idle")
R38 = Agent("Robot38", (10, 4), "green", "broom", None, "active")
R39 = Agent("Robot39", (1, 1), "yellow", "front loader", None, "idle")
R40 = Agent("Robot40", (11, 3), "magenta", "vacuum", None, "charging")
R41 = Agent("Robot41", (10, 1), "olive", "lawnmower", None, "charging")
R42 = Agent("Robot42", (10, 7), "teal", "gripper", None, "charging")
R43 = Agent("Robot43", (11, 9), "blue", "tow hook", None, "active")
R44 = Agent("Robot44", (9, 6), "fuchsia", "saw", None, "active")
R45 = Agent("Robot45", (2, 3), "blue", "screwdriver", None, "idle")
R46 = Agent("Robot46", (1, 7), "black", "mop", None, "active")
R47 = Agent("Robot47", (2, 6), "maroon", "spray nozzle", None, "idle")
R48 = Agent("Robot48", (7, 2), "lime", "broom", None, "idle")
R49 = Agent("Robot49", (6, 9), "orange", "front loader", None, "active")
R50 = Agent("Robot50", (7, 8), "red", "vacuum", None, "idle")


robots = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, 
          R11, R12, R13, R14, R15, R16, R17, R18, R19, R20, 
          R21, R22, R23, R24, R25, R26, R27, R28, R29, R30, 
          R31, R32, R33, R34, R35, R36, R37, R38, R39, R40, 
          R41, R42, R43, R44, R45, R46, R47, R48, R49, R50]

# %%
print(robots[0].position)
# Out:
# (12, 4)

# %% [markdown]
# ## Create Tools

# %% [markdown]
# **Helper functions**

# %%
def sort_by_tool(tool_name, robot_list=robots):
    usable_robots = []
    for robot in robot_list:
        if robot.tool_property == tool_name:
            usable_robots.append(robot)
    return usable_robots

def sort_by_availability(robot_list, target_pos):
    available_robots = []
    if robot_list:
        closest_robot = robot_list[0].name
        min_dist = dist_func(robot_list[0].position, target_pos)
        flag = True
        for robot in robot_list:
            if robot._status != "active":
                available_robots.append(robot.name)
                if flag:
                    flag = False
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
                    
                if min_dist > dist_func(robot.position, target_pos):
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
        if available_robots:
            return f"out of available robot: {available_robots}, {closest_robot} is the best suited to solve the task."
    return "no robot with the specified tool to solve the task"

def dist_func(robot_pos, target_pos):
    x_dist = abs(target_pos["x"] - robot_pos[0])
    y_dist = abs(target_pos["y"] - robot_pos[1])
    total_dist = x_dist + y_dist
    return total_dist

def select_known_robot(robot_name, desired_tool, robot_list=robots):
    for robot in robot_list:                
        if robot_name == robot.name:
            if robot._status != "active":
                if desired_tool == robot.tool_property:
                    return f"{robot_name} with the tool property: {robot.tool_property} has been selected to solve the task"
                return f"""{robot_name} is not equipped with the tool property initially selected for task completion. 
                Can {robot_name} with tool property: {robot.tool_property} still solve the task?
                If a list of items with assoicated tool properties is provided, remember to use that as reference.
                In your anwser please stat the initial selected tool and why {robot_name} can/can't solve the task with the tool property: {robot.tool_property}. in this step be strict and try to stay close to the list of items with assoicated tool properties
                """
            return f"{robot_name} is currently active and is not available to solve the task"
    return f"{robot_name} is not a valid robot"

def change_status(robot_name, robot_list=robots, status="idle"):
    for robot in robot_list:
        if robot_name == robot.name:
            old_status = robot._status
            robot.set_status(status)
            return f"{robot.name} has changed status from {old_status} to {status}"

def set_goal(robot_name, position, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.setGoal(position)
            return robot.goal
        
def add_item_to_inventory(robot_name, item_name, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.add_item_invetory(item_name)

# %% [markdown]
# **LLM tools**

# %%
from typing import Annotated, List, Tuple, Union

from langchain_core.tools import tool
from langsmith import trace

@tool
def move_robot(robot_name: str, position: Tuple) -> str:
    """Moves the Specified robot to the desired position"""
    goal = set_goal(robot_name=robot_name, position=position)
    return f"{robot_name} has been moved to the desired position {goal}"

@tool
def grab_or_remove_item(robot_name: str, item_name: str) -> str:
    """makes the specified robot grab/remove the desired item"""
    add_item_to_inventory(robot_name=robot_name, item_name=item_name)
    return f"{robot_name} has grabed/removed the desired item {item_name}"

@tool
def robot_status_change(robot_name: str, status: str):
    """Changes the status of a robot"""
    return change_status(robot_name=robot_name, status=status)

@tool
def robot_selection_tool(desired_robot_tool_property, 
                         item_position) -> str:
    """Finds the most robots with the desired tool property. Remember that the item_position needs to be a dict of x and y coordinates"""
    sorted_robots = sort_by_tool(desired_robot_tool_property)
    return sort_by_availability(sorted_robots, item_position)
@tool
def select_known_robot_tool(robot_name: str, desired_robot_tool_property) -> str:
    """select the specified robot to solve the task. If the robot does not have the desired tool for the task, then it will ask if the robot still can solve the task.
    This tool does not alter the tools a robot has, but will try to use the selected robot although it might not have the desired tool.
    """
    return select_known_robot(robot_name=robot_name, desired_tool=desired_robot_tool_property)

@tool
def agent_response_tool(input: str, response: str) -> str:
    """this is a tool that returns the response to the input"""
    return response

# %% [markdown]
# ## Helper Utilities
#
# We are going to create a few utility functions to make it more concise when we want to:
#
# 1. Create a worker agent.
# 2. Create a supervisor for the sub-graph.
#
# These will simplify the graph compositional code at the end for us so it's easier to see what's going on.

# %%
from typing import Any, Callable, List, Optional, TypedDict, Union

from langchain.agents import AgentExecutor, create_openai_functions_agent, create_tool_calling_agent
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import Runnable
from langchain_core.tools import BaseTool
from langchain_openai import ChatOpenAI

from langgraph.graph import END, StateGraph


def create_agent(
    llm: ChatOpenAI,
    tools: list,
    system_prompt: str,
) -> str:
    """Create a function-calling agent and add it to the graph."""
    system_prompt += """\nWork autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.

    Important!: When giving the final output to the supervisor, give a short summary of what your thought process was when selecting your tools an also the results. Do the summary in bulletpoint format.
    
    EXAMPLE
    Thought process
    - insert process here

    Results:
    - insert results here
    END OF EXAMPLE

    Your other team members (and other teams) will collaborate with you with their own specialties.
    You are chosen for a reason!
    """
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt,
            ),
            MessagesPlaceholder(variable_name="messages"),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )
    agent = create_tool_calling_agent(llm, tools, prompt)
    executor = AgentExecutor(agent=agent, tools=tools)
    return executor


def agent_node(state, agent, name):
    result = agent.invoke(state)
    return {"messages": [HumanMessage(content=result["output"], name=name)]}


def create_team_supervisor(llm: ChatOpenAI, system_prompt, members) -> str:
    """An LLM-based router."""
    options = ["FINISH"] + members
    function_def = {
        "name": "route",
        "description": "Select the next role.",
        "parameters": {
            "title": "routeSchema",
            "type": "object",
            "properties": {
                "next": {
                    "title": "Next",
                    "anyOf": [
                        {"enum": options},
                    ],
                },
                "response": {
                    "type": "string",
                    "description": "The reason behind the choice of member or a description of the task completion to the user."
                }
            },
            "required": ["response", "next"],
        },
    }
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            MessagesPlaceholder(variable_name="messages"),
            (
                "system",
                """Given the conversation above, who should act next? Or should we FINISH? Select one of: {options}. 
                If we should FINISH then decribe the task completion in the following format:
                
                EXAMPLE
                ROBOT NAME;TOOL PROPERTY;ITEM;ITEM POSITION
                EXAMPLE END
                
                ROBOT NAME = (The robot that solved the task i.e Robot22)
                TOOL PROPERTY = (The tool property of ROBOT i.e gripper)
                ITEM = (The item that is being manipulated i.e toolkit)
                ITEM POSITION = (The position of ITEM i.e (11, 8))
                
                Remember to respond exactly as in the example but be mindful of the upper and lower case for the name of the robot, tool property and item. If we should not FINISH then respond with the reasoning behind the choice."""
            ),
        ]
    ).partial(options=str(options), team_members=", ".join(members))
    return (
        prompt
        | llm.bind_functions(functions=[function_def], function_call="route")
        | JsonOutputFunctionsParser()
    )

# %% [markdown]
# ## Define Agent Teams

# %% [markdown]
# **Robot Control Team**
#
# The team will have the ability to control the robots directly using function calling

# %%
import functools
import operator

from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_openai.chat_models import ChatOpenAI
import functools

# Robot Control Team graph state
class RobotControlTeamState(TypedDict):
    # A message is added after each team member finishes
    messages: Annotated[List[BaseMessage], operator.add]
    # The team members are tracked so they are aware of
    # the others' skill-sets
    team_members: List[str]
    # Used to route work. The supervisor calls a function
    # that will update this every time it makes a decision
    next: str
    # The reason behind the member choice
    response: str

# general llm used in all agents
llm = ChatOpenAI(model="gpt-4-1106-preview")
# llm = ChatOpenAI(model="gpt-3.5-turbo-1106")
# llm_test = ChatOpenAI(model="gpt-4-1106-preview")

# agent used to control the actions of the robots
robot_control_agent = create_agent(
    llm,
    [move_robot, grab_or_remove_item, robot_status_change],
    """
    You are an agent that control robots actions using the tools available to you. When the robot is done finishing the task it should always have it's status set to idle.
    remember you are only able to grab/remove the items and not the robots tool property. this is the list of tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].
     which are not to be grabed or removed."""
)

robot_control_node = functools.partial(agent_node, agent=robot_control_agent, name="Controller")

# agent to determine the best suited robot to solve the task
robot_selection_agent = create_agent(
    llm,
    [robot_selection_tool, select_known_robot_tool],
    f"""
    You are a agent with the purpose to select the best suited robot for the task. A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].
    If a specified robot is already selected to solve the task, use select_known_robot_tool.
    Here is an example of that.

    EXAMPLE: 
    task = "Move robot_name to location (2, 11) and sort the recyclables."
    Robot = robot_name
    END EXAMPLE

    remember to select the most apropriate tool_property for the task i.e a gripper for a task where something needs to be picked up.

    here is a list of items, and what tool property can manipulating that item:
    
    toolkit = gripper
    liquid spill = mop
    large debris = gripper, front loader 
    dust = vacuum, broom
    grass = lawnmower
    small debris = broom, vacuum 
    vehicle = tow hook
    construction materials = gripper, front loader, tow hook
    tree branches = saw
    screws = screwdriver
     
    remember that each of the items in the list is a category of it's own
"""
)

robot_selection_node = functools.partial(agent_node, agent=robot_selection_agent, name="Robot_selector")

# agent that answer general question such as "what is the capital of denmark"
misc_agent=create_agent(
    llm,
    [agent_response_tool],
    """
    You are an agent that can answer general questions and messages that doesn't have anything to do with making a robot solve a complex task. When you know the apropriate reponse return the answer to the supervisor.
    """
)

misc_node=functools.partial(agent_node, agent=misc_agent, name="misc_agent")


# This is the supervisor agent tasked with selecting the next worker (agent). the supervisor might select multiple workers before the task given is consitered solved.
supervisor_agent = create_team_supervisor(
    llm,
    """
    You are a supervisor tasked with managing a conversation between the following workers: Controller, Robot_selector, misc_agent.
    Given the following user request, respond with the worker to act next and a response depending if we are FINISH or not.
    Each worker will perform a task and respond with their results and status. If the response from the Robot_selector determines that the robot is not suitable to solve the task, then either finish or make the Robot_selector
    When finished, respond with FINISH.
    """,
    ["Controller", "Robot_selector", "misc_agent"],
)

# %% [markdown]
# **Connect the nodes in the graph**

# %%
#adding the nodes to the graph
robot_control_graph = StateGraph(RobotControlTeamState)
robot_control_graph.add_node("Controller", robot_control_node)
robot_control_graph.add_node("Robot_selector", robot_selection_node)
robot_control_graph.add_node("misc_agent", misc_node)
robot_control_graph.add_node("supervisor", supervisor_agent)

#define the control flow
robot_control_graph.add_edge("Controller", "supervisor")
robot_control_graph.add_edge("Robot_selector", "supervisor")
robot_control_graph.add_edge("misc_agent", "supervisor")
robot_control_graph.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {"Controller": "Controller", "Robot_selector": "Robot_selector", "misc_agent": "misc_agent", "FINISH": END}
)

robot_control_graph.set_entry_point("supervisor")
chain = robot_control_graph.compile()


# The following functions interoperate between the top level graph state
# and the state of the robot control sub-graph
# this makes it so that the states of each graph don't get intermixed
def enter_chain(message: str):
    results = {
        "messages": [HumanMessage(content=message)],
    }
    return results

robot_control_chain = enter_chain | chain

# %%
# # Broom

# R18 = Agent("Robot18", (4, 5), "black", "broom", None, "active")
# R28 = Agent("Robot28", (2, 7), "navy", "broom", None, "charging")
# R38 = Agent("Robot38", (10, 4), "green", "broom", None, "active")
# R48 = Agent("Robot48", (7, 2), "lime", "broom", None, "idle")
# R8 = Agent("Robot8", (8, 3), "olive", "broom", None, "idle")

# # Front Loader

# R19 = Agent("Robot19", (3, 12), "magenta", "front loader", None, "idle")
# R9 = Agent("Robot9", (5, 10), "silver", "front loader", None, "charging")
# R29 = Agent("Robot29", (10, 8), "aqua", "front loader", None, "charging")
# R39 = Agent("Robot39", (1, 1), "yellow", "front loader", None, "idle")
# R49 = Agent("Robot49", (6, 9), "orange", "front loader", None, "active")

# # Gripper

# R2 = Agent("Robot2", (4, 6), "maroon", "gripper", None, "charging")
# R12 = Agent("Robot12", (1, 6), "yellow", "gripper", None, "active")
# R22 = Agent("Robot22", (8, 11), "blue", "gripper", None, "idle")
# R32 = Agent("Robot32", (12, 8), "olive", "gripper", None, "charging")
# R42 = Agent("Robot42", (10, 7), "teal", "gripper", None, "charging")

# # Lawnmower

# R1 = Agent("Robot1", (12, 4), "aqua", "lawnmower", None, "active")
# R11 = Agent("Robot11", (11, 5), "navy", "lawnmower", None, "charging")
# R21 = Agent("Robot21", (9, 7), "magenta", "lawnmower", None, "charging")
# R31 = Agent("Robot31", (12, 2), "fuchsia", "lawnmower", None, "charging")
# R41 = Agent("Robot41", (10, 1), "olive", "lawnmower", None, "charging")

# # Mop

# R6 = Agent("Robot6", (3, 10), "pink", "mop", None, "charging")
# R16 = Agent("Robot16", (6, 8), "olive", "mop", None, "active")
# R26 = Agent("Robot26", (1, 2), "aqua", "mop", None, "idle")
# R36 = Agent("Robot36", (5, 8), "olive", "mop", None, "active")
# R46 = Agent("Robot46", (1, 7), "black", "mop", None, "active")

# # Saw

# R4 = Agent("Robot4", (5, 1), "purple", "saw", None, "active")
# R14 = Agent("Robot14", (11, 11), "silver", "saw", None, "idle")
# R24 = Agent("Robot24", (10, 5), "navy", "saw", None, "idle")
# R34 = Agent("Robot34", (8, 4), "black", "saw", None, "active")
# R44 = Agent("Robot44", (9, 6), "fuchsia", "saw", None, "active")

# # Spray Nozzle

# R7 = Agent("Robot7", (5, 7), "blue", "spray nozzle", None, "active")
# R17 = Agent("Robot17", (12, 9), "fuchsia", "spray nozzle", None, "idle")
# R27 = Agent("Robot27", (2, 1), "white", "spray nozzle", None, "charging")
# R37 = Agent("Robot37", (8, 1), "maroon", "spray nozzle", None, "idle")
# R47 = Agent("Robot47", (2, 6), "maroon", "spray nozzle", None, "idle")

# # Tow Hook

# R3 = Agent("Robot3", (4, 12), "green", "tow hook", None, "active")
# R13 = Agent("Robot13", (1, 9), "pink", "tow hook", None, "charging")
# R23 = Agent("Robot23", (11, 7), "silver", "tow hook", None, "idle")
# R33 = Agent("Robot33", (5, 5), "lime", "tow hook", None, "active")
# R43 = Agent("Robot43", (11, 9), "blue", "tow hook", None, "active")

# # Vacuum

# R10 = Agent("Robot10", (10, 6), "cyan", "vacuum", None, "charging")
# R20 = Agent("Robot20", (5, 9), "black", "vacuum", None, "active")
# R30 = Agent("Robot30", (7, 12), "fuchsia", "vacuum", None, "active")
# R40 = Agent("Robot40", (11, 3), "magenta", "vacuum", None, "charging")
# R50 = Agent("Robot50", (7, 8), "red", "vacuum", None, "idle")

# # screwdriver

# R5 = Agent("Robot5", (9, 2), "orange", "screwdriver", None, "active")
# R15 = Agent("Robot15", (6, 11), "orange", "screwdriver", None, "charging")
# R25 = Agent("Robot25", (10, 11), "white", "screwdriver", None, "active")
# R35 = Agent("Robot35", (5, 11), "black", "screwdriver", None, "idle")
# R45 = Agent("Robot45", (2, 3), "blue", "screwdriver", None, "idle")

# %% [markdown]
# ## Testing the team

# %% [markdown]
# ### Test results

# %%
def task_iteration(file_path):
        task = file_path.readline()
        if not task:
            return False
        return task.strip()

# %%
def clear_txt(path):
    # Clear the file by opening it in write mode and closing it
    with open(path, "w") as file:
        pass

def write_txt(path, string):
    # Open the file in append mode and write the string
    with open(path, "a") as file:
        file.write(string)

def process_dict(d, path):
    output = []

    if 'supervisor' in d:
        supervisor_info = d['supervisor']
        next_step = supervisor_info.get('next', 'N/A')
        response = supervisor_info.get('response', 'N/A')
        if next_step == "FINISH":
            write_txt(path, f"{response}\n")
        output.append(f"Supervisor:\nNext: {next_step}\nresponse: {response}\n---\n")
        print(f"Supervisor:\nNext: {next_step}\nresponse: {response}\n---\n")
        
    if 'Robot_selector' in d:
        robot_selector_info = d.get('Robot_selector', {})
        messages = robot_selector_info.get('messages', [])
        for message in messages:
            content = getattr(message, 'content', 'N/A')
            output.append(f"Robot Selector:\n{content}\n---\n")
            print(f"Robot Selector:\n{content}\n---\n")

    if 'Controller' in d:
        controller_info = d.get('Controller', {})
        messages = controller_info.get('messages', [])
        for message in messages:
            content = getattr(message, 'content', 'N/A')
            output.append(f"Controller:\n{content}\n---\n")
            print(f"Controller:\n{content}\n---\n")
    
    if 'misc_agent' in d:
        misc_agent_info = d.get('misc_agent', {})
        messages = misc_agent_info.get('messages', [])
        for message in messages:
            content = getattr(message, 'content', 'N/A')
            output.append(f"misc_agent:\n{content}\n---\n")
            print(f"misc_agent:\n{content}\n---\n")
    

    return ''.join(output)

# %% [markdown]
# ### Easy tests

# %%
import csv
file_path = "Results\Result_matrix\Easy_matrix.txt"
clear_txt(file_path)
# Open the CSV file once outside the loop for appending data
with open('Results\Raw_output\output_Easy.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=";")

    # Open the task file and read tasks one by one
    with open("Results\Tasks\Easy_tasks_test.txt", 'r') as file:
        i = 1
        while True:
            history = ""
            task = task_iteration(file)
            if not task:
                break
            
            # Print the task number and task to the console
            print(f"{i}. task: {task}")
            print("---")

            # Process each stream associated with the task
            j = 1
            for s in robot_control_chain.stream(
                task, {"recursion_limit": 100}
            ):
                if "__end__" not in s:
                    history += process_dict(s, file_path)
                    j+=1
                if j == 100:
                    # This is to ensure there is a response even though it fails due recursion limit
                    write_txt(file_path, "DNF;DNF;DNF;DNF\n")
                    history += "DNF"
                    break
            i += 1
            
            # Append both task and processed data to the CSV
            writer.writerow([task, history])
# Out:
# 1. task: Move Robot32 to location (2, 9) and remove the toolkit.
# ---
# Supervisor:
# Next: Robot_selector
# response: Determining if Robot32 is suitable for the task of moving to location (2, 9) and removing the toolkit.
# ---
#
# Robot Selector:
# Thought process:
# - The task involved moving the robot to a specific location and removing a toolkit.
# - Based on the provided list, a toolkit can be manipulated using a gripper.
# - Robot32 was chosen because it has the gripper tool property needed for the task.
#
# Results:
# - Robot32, equipped with a gripper, has been selected to move to location (2, 9) and remove the toolkit.
# ---
#
# Supervisor:
# Next: Controller
# response: The Robot_selector has chosen Robot32 with the gripper tool property to perform the task. Now, the Controller needs to execute the movement and toolkit removal instructions.
# ---
#
# Controller:
# Thought process:
# - Received instruction to move Robot32 and remove an item.
# - Used the `move_robot` function to move Robot32 to the specified coordinates.
# - After moving, used the `grab_or_remove_item` function to remove the toolkit as instructed.
# - Set Robot32's status to idle using the `robot_status_change` function after completing the tasks.
#
# Results:
# - Robot32 was successfully moved to location (2, 9).
# - The toolkit was successfully removed by Robot32.
# - Robot32's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot32;gripper;toolkit;(2, 9)
# ---
#
# 2. task: Move Robot6 to location (5, 4) and remove the liquid spill.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting Robot6 to move to location (5, 4) and remove the liquid spill.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task required removing a liquid spill.
# - Selected a robot with a mop tool property as it is suitable for cleaning up liquid spills.
# - Checked available robots with the mop tool property at the specified location.
# - Found that both Robot6 and Robot26 were capable of performing the task.
# - Given the instruction to use Robot6, confirmed that Robot6 had the mop tool property.
# - Selected Robot6 for the task.
#
# Results:
# - Robot6, equipped with a mop, has been selected to move to location (5, 4) and remove the liquid spill.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot6 has been selected for the task. The Controller will now need to command Robot6 to move to the location and perform the spill cleanup.
# ---
#
# Controller:
# Thought process:
# - Received instructions to move Robot6 to a specific location and remove a liquid spill.
# - Used the `move_robot` function to relocate Robot6 to the coordinates (5, 4).
# - Executed the `grab_or_remove_item` function to handle the liquid spill with Robot6.
# - Changed Robot6's status to idle after completing the task using the `robot_status_change` function.
#
# Results:
# - Robot6 was successfully moved to location (5, 4).
# - The liquid spill was removed by Robot6.
# - Robot6's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot6;mop;liquid spill;(5, 4)
# ---
#
# 3. task: Move Robot29 to location (5, 12) and remove the large debris.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting the appropriate robot to move to location (5, 12) and remove the large debris.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task required a robot with a gripper tool property to handle large debris.
# - Used the robot_selection_tool function to find the most suitable robot with a gripper near the location (5, 12).
# - Selected Robot22 as it was the best-suited robot to solve the task.
#
# Results:
# - Robot22, equipped with a gripper tool property, has been selected to move to location (5, 12) and remove the large debris.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot22 has been selected and now requires instruction to proceed with the task.
# ---
#
# Controller:
# Thought process:
# - Received a task to move Robot29 and remove large debris.
# - Used the move_robot function to move Robot29 to the location (5, 12).
# - After reaching the location, used the grab_or_remove_item function to remove the large debris.
#
# Results:
# - Robot29 was successfully moved to the location (5, 12) and removed the large debris.
# - Robot29's status has been set to idle after completing the task.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot29;gripper;large debris;(5, 12)
# ---
#
# 4. task: Move Robot48 to location (6, 6) and remove the dust.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of moving to location (6, 6) and removing dust.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task involves dust removal.
# - Based on the list, selected a robot with a vacuum tool to effectively handle dust.
# - Used the robot_selection_tool function to find the most suitable robot equipped with a vacuum near the specified location.
#
# Results:
# - Robot50 is the best-suited robot to solve the task of removing dust at location (6, 6).
# ---
#
# Supervisor:
# Next: Controller
# response: The Robot_selector has found Robot50 with a vacuum to perform the task. Now, the Controller needs to manage the movement and operation of Robot50 to location (6, 6) for dust removal.
# ---
#
# Controller:
# Thought process:
# - Received task to move Robot48 to a specific location and to remove dust.
# - Used move_robot function to position Robot48 at the coordinates (6, 6).
# - Utilized grab_or_remove_item function to have Robot48 remove dust at the location.
# - Ensured the robot's status was set to idle after task completion using robot_status_change function.
#
# Results:
# - Robot48 was successfully moved to location (6, 6).
# - Dust at the location was removed by Robot48.
# - Robot48's status was set to idle post-task completion.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot48;vacuum;dust;(6, 6)
# ---
#
# 5. task: Move Robot41 to location (1, 8) and remove the grass.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select Robot41 and verify if it is suitable for removing grass at location (1, 8).
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task as grass removal which requires a lawnmower tool.
# - Used robot_selection_tool function to find the best-suited robot near the location (1, 8).
# - Although Robot21 was suggested as the best-suited robot, the task specifically asked for Robot41.
# - Used select_known_robot_tool function to ensure Robot41 has a lawnmower tool.
#
# Results:
# - Robot41, equipped with a lawnmower, has been selected to move to location (1, 8) and remove the grass.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot41 has been selected and is equipped to remove the grass. The Controller will now instruct Robot41 to move to the specified location and perform the task.
# ---
#
# Controller:
# Thought process:
# - Received a task to move Robot41 to a specific location and remove grass.
# - Interpreted the task as requiring the use of a lawnmower tool, which is inherently part of Robot41.
# - Moved Robot41 to the designated position (1, 8) using the move_robot function.
# - Executed the grass removal by making Robot41 grab/remove the grass with the grab_or_remove_item function.
# - Set Robot41's status to idle after completing the task using the robot_status_change function.
#
# Results:
# - Robot41 was successfully moved to location (1, 8).
# - The grass at the location has been removed.
# - Robot41's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot41;lawnmower;grass;(1, 8)
# ---
#
# 6. task: Move Robot10 to location (9, 5) and remove the small debris.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot that can move to location (9, 5) and remove small debris.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task required the removal of small debris.
# - Chose a vacuum as the appropriate tool property for removing small debris.
# - Used the robot_selection_tool function to find the best-suited robots with a vacuum tool near the specified location (9, 5).
# - Robot10 was among the best-suited robots and specifically requested for the task.
# - Selected Robot10 using the select_known_robot_tool function, ensuring it was equipped with a vacuum.
#
# Results:
# - Robot10, equipped with a vacuum, has been selected to move to location (9, 5) and remove the small debris.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot10 has been selected with the appropriate tool. The Controller now needs to command Robot10 to move to the location and perform the task of debris removal.
# ---
#
# Controller:
# Thought process:
# - Received task to move Robot10 to a specific location and remove small debris.
# - First, moved Robot10 to the designated location (9, 5).
# - Following the move, instructed Robot10 to grab/remove the small debris.
# - Ensured that Robot10's status was set to idle once the task was completed.
#
# Results:
# - Robot10 was successfully moved to the location (9, 5).
# - Small debris was removed by Robot10.
# - Robot10's status is now idle, indicating it has completed the task and is ready for further instructions.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot10;vacuum;small debris;(9, 5)
# ---
#
# 7. task: Move Robot13 to location (10, 10) and remove the vehicle.
# ---
# Supervisor:
# Next: Robot_selector
# response: Determining if Robot13 is suitable for the task of moving to location (10, 10) and removing the vehicle.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task requires a robot with a tow hook to remove a vehicle.
# - Used the robot_selection_tool function to find the most suited robot with the tow hook property near the specified location.
# - Upon learning that Robot13 and Robot23 were available, and Robot23 was suggested as the best suited, I still selected Robot13 as specified in the task.
#
# Results:
# - Robot13 has been selected and equipped with a tow hook to remove the vehicle at location (10, 10).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot13 has been selected and is equipped with the necessary tool. The Controller will now manage the robot's movement and execution of the task.
# ---
#
# Controller:
# Thought process:
# - Received instruction to move Robot13 and remove a vehicle.
# - Utilized the move_robot function to relocate Robot13 as per the coordinates provided.
# - Employed the grab_or_remove_item function to ensure Robot13 removed the vehicle.
# - Updated Robot13's status to idle using the robot_status_change function after completion of the task.
#
# Results:
# - Robot13 successfully moved to location (10, 10).
# - The vehicle at the location has been removed by Robot13.
# - Robot13's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot13;tow hook;vehicle;(10, 10)
# ---
#
# 8. task: Move Robot23 to location (8, 2) and remove the construction materials.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting a robot capable of moving to location (8, 2) and removing construction materials.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task involves removing construction materials.
# - Recognized that construction materials can be manipulated using a gripper, front loader, or tow hook.
# - Chose the gripper as the appropriate tool property for the task.
# - Used the robot_selection_tool function to find the best-suited robot with the gripper tool near the specified location (8, 2).
# - Robot42 was determined to be the best-suited robot for the task.
# - Selected Robot42 using the select_known_robot_tool function to ensure it was equipped with a gripper to accomplish the task.
#
# Results:
# - Robot42 with the gripper tool property has been successfully selected to move to location (8, 2) and remove the construction materials.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot42 has been selected with the appropriate tool property. The Controller should now take over to move Robot42 to the specified location and oversee the removal of the construction materials.
# ---
#
# Controller:
# Thought process:
# - Received a task to move a robot and remove an item.
# - Identified Robot23 as the robot to perform the task.
# - Determined the robot's destination coordinates as (8, 2).
# - Recognized the need to remove construction materials, which implies using the robot's gripper tool.
# - Used the `move_robot` function to move Robot23 to the designated position.
# - Used the `grab_or_remove_item` function for Robot23 to remove the construction materials.
# - Set the robot's status to idle using the `robot_status_change` function after task completion.
#
# Results:
# - Robot23 was successfully moved to position (8, 2).
# - Robot23 removed the construction materials at the location.
# - Robot23's status was set to idle as per the protocol.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot42;gripper;construction materials;(8, 2)
# ---
#
# 9. task: Move Robot24 to location (11, 8) and remove the tree branches.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of moving to location (11, 8) and removing tree branches.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task involves removing tree branches, which requires a saw.
# - Used the robot_selection_tool function to find the best-suited robot with a saw near the specified location (11, 8).
# - Robot14 was identified as the best-suited robot, but Robot24 was specifically requested.
# - Used the select_known_robot_tool function to confirm if Robot24 could perform the task with a saw.
#
# Results:
# - Robot24 has been selected and confirmed to have the saw tool property, making it capable of removing the tree branches at location (11, 8).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot24 has been confirmed to have the necessary tool for the task. Now the Controller needs to manage the robot's movement and task execution at the specified location.
# ---
#
# Controller:
# Thought process:
# - Received instructions to move Robot24 to a specific location and remove tree branches.
# - Used the `move_robot` function to move Robot24 to the location (11, 8).
# - After moving Robot24, the `grab_or_remove_item` function was used to remove the tree branches.
# - Set Robot24's status to idle using the `robot_status_change` function after completing the task.
#
# Results:
# - Robot24 was successfully moved to location (11, 8).
# - Tree branches were removed by Robot24.
# - Robot24's status was set to idle after finishing the task.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot24;saw;tree branches;(11, 8)
# ---
#
# 10. task: Move Robot15 to location (3, 8) and remove the screws.
# ---
# Supervisor:
# Next: Robot_selector
# response: Determining if Robot15 is suitable for moving to location (3, 8) and removing screws.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task requires a robot to move to a location and remove screws.
# - Recognized that the appropriate tool for removing screws is a screwdriver.
# - Selected Robot15 as it was specified in the task and ensured it has a screwdriver tool property suitable for the job.
#
# Results:
# - Robot15, equipped with a screwdriver, has been selected to move to location (3, 8) and remove the screws.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot15 has been selected and is equipped with the necessary tool. The Controller should now orchestrate the movement and operation of Robot15 to complete the task.
# ---
#
# Controller:
# Thought process:
# - Received instructions to move Robot15 and remove screws.
# - Used the move_robot function to move Robot15 to the specified location (3, 8).
# - After moving, used the grab_or_remove_item function to remove the screws as instructed.
# - Finally, set Robot15's status to idle as required after completing the task.
#
# Results:
# - Robot15 was successfully moved to location (3, 8).
# - The screws were removed by Robot15.
# - Robot15's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot15;screwdriver;screws;(3, 8)
# ---

# %% [markdown]
# ### Medium tests

# %%
import csv
file_path = "Results\Result_matrix\Medium_matrix.txt"
clear_txt(file_path)
# Open the CSV file once outside the loop for appending data
with open('Results\Raw_output\output_Medium.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=";")

    # Open the task file and read tasks one by one
    with open("Results\Tasks\Medium_tasks_test.txt", 'r') as file:
        i = 1
        while True:
            history = ""
            task = task_iteration(file)
            if not task:
                break
            
            # Print the task number and task to the console
            print(f"{i}. task: {task}")
            print("---")

            # Process each stream associated with the task
            j= 1
            for s in robot_control_chain.stream(
                task, {"recursion_limit": 100}
            ):
                if "__end__" not in s:
                    history += process_dict(s, file_path)
                    j+=1
                if j == 100:
                    # This is to ensure there is a response even though it fails due recursion limit
                    write_txt(file_path, "DNF;DNF;DNF;DNF\n")
                    history += "DNF"
                    break
            i += 1
            
            # Append both task and processed data to the CSV
            writer.writerow([task, history])
# Out:
# 1. task: Move to location (9, 5) and remove the toolkit.
# ---
# Supervisor:
# Next: Robot_selector
# response: A robot needs to be selected that can move to the specified location and remove the toolkit.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task involves removing a toolkit.
# - Recognized that a gripper is the appropriate tool for picking up a toolkit.
# - Used the robot_selection_tool function to find the best-suited robot with a gripper to remove the toolkit at the specified location (9, 5).
#
# Results:
# - Robot42 has been selected as the best-suited robot with a gripper to remove the toolkit at the specified location.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot42 has been selected to perform the task. The Controller will now instruct Robot42 to move to location (9, 5) and remove the toolkit.
# ---
#
# Controller:
# Thought process:
# - Received command to move to a location and remove an item.
# - Selected an appropriate robot with a gripper (Robot42).
# - Executed the move to the specified location (9, 5).
# - Removed the toolkit as instructed.
# - Set the robot's status to idle after task completion.
#
# Results:
# - Robot42 successfully moved to location (9, 5).
# - Toolkit removed by Robot42.
# - Robot42's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot42;gripper;toolkit;(9, 5)
# ---
#
# 2. task: Move to location (3, 8) and remove the liquid spill.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of navigating to the location (3, 8) and equipped to remove a liquid spill.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task involves removing a liquid spill.
# - Selected the "mop" tool property as it is appropriate for cleaning up liquid spills.
# - Utilized the `robot_selection_tool` function to find the most suitable robot with a mop tool near the specified location (3, 8).
#
# Results:
# - Robot6 has been chosen as the best-suited robot for the task of removing the liquid spill at location (3, 8).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot6 has been selected to remove the liquid spill at location (3, 8). The Controller must now command Robot6 to execute the task.
# ---
#
# Controller:
# Thought process:
# - Received a task to move to a location and remove a liquid spill.
# - Identified the need to move the robot to the specified location before addressing the spill.
# - Chose to use the mop tool property implicitly as it is suited for cleaning liquid spills.
# - Executed the move action to bring the robot to the required location.
# - Performed the grab/remove action to clean the spill.
# - Set the robot status to idle upon completion of the task.
#
# Results:
# - Robot6 was moved to location (3, 8).
# - Robot6 removed the liquid spill at the location.
# - Robot6's status was set to idle after finishing the task.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot6;mop;liquid spill;(3, 8)
# ---
#
# 3. task: Move to location (1, 4) and remove the large debris.
# ---
# Supervisor:
# Next: Robot_selector
# response: The task requires selecting a robot capable of moving to the specified location and removing large debris.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task as removal of large debris.
# - Selected 'front loader' as the appropriate tool for handling large debris.
# - Used the robot_selection_tool function to find the best-suited robot with a 'front loader' at the given location.
#
# Results:
# - Robot39 has been selected as the best-suited robot to move to location (1, 4) and remove the large debris.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot39 has been selected to perform the task. Now the Controller will guide Robot39 to location (1, 4) and execute the removal of the large debris.
# ---
#
# Controller:
# Thought process:
# - Received instructions to move to location (1, 4) and remove large debris.
# - Used 'move_robot' to send Robot39 to the specified location.
# - Employed 'grab_or_remove_item' for Robot39 to handle the large debris removal.
# - Set Robot39's status to 'idle' after the task completion using 'robot_status_change'.
#
# Results:
# - Robot39 successfully moved to location (1, 4).
# - Removed the large debris at the location.
# - Robot39 is now set to idle status.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot39;front loader;large debris;(1, 4)
# ---
#
# 4. task: Move to location (6, 5) and remove the dust.
# ---
# Supervisor:
# Next: Robot_selector
# response: The task requires moving to a specific location and removing dust. We need to select a robot that is capable of navigating to the location and performing cleaning tasks.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task required removing dust.
# - Chose a vacuum as the appropriate tool for dust removal.
# - Used the robot selection tool to find the best-suited robot with a vacuum near the coordinates (6, 5).
#
# Results:
# - Robot50 was selected as the best-suited robot to remove the dust at location (6, 5).
# ---
#
# Supervisor:
# Next: Controller
# response: The Robot_selector has chosen Robot50 with a vacuum to perform the task. The Controller will now instruct Robot50 to move to location (6, 5) and remove the dust.
# ---
#
# Controller:
# Thought process:
# - Received a command to move to a location and remove dust.
# - Selected Robot50 based on the robot selector's recommendation.
# - Moved Robot50 to the coordinates (6, 5).
# - Used Robot50 to grab/remove the dust at the location.
# - Set Robot50's status to idle after completing the task.
#
# Results:
# - Robot50 was successfully moved to (6, 5).
# - Dust was removed by Robot50 at the location.
# - Robot50 is now set to idle status.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot50;vacuum;dust;(6, 5)
# ---
#
# 5. task: Move to location (9, 5) and remove the grass.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of moving to the specified location and removing grass.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task of removing grass, which requires a robot with a lawnmower tool property.
# - Used the `robot_selection_tool` function to find the most suitable robot with a lawnmower near the specified location (9, 5).
#
# Results:
# - Robot11 was selected as the best-suited robot to remove the grass at location (9, 5).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot11 has been selected to remove the grass. The Controller will now command Robot11 to move to the location (9, 5) and execute the task.
# ---
#
# Controller:
# Thought process:
# - Decided that a robot with a lawnmower tool is required for removing grass.
# - Moved the robot with the lawnmower tool to the specified location (9, 5).
# - Removed the grass at the location using the robot.
# - Set the robot's status to idle after completing the task.
#
# Results:
# - Robot11 successfully moved to location (9, 5).
# - Grass at location (9, 5) has been removed.
# - Robot11's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot11;lawnmower;grass;(9, 5)
# ---
#
# 6. task: Move to location (5, 12) and remove the small debris.
# ---
# Supervisor:
# Next: Robot_selector
# response: Determine which robot is suitable for moving to location (5, 12) and removing the small debris.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task involved removing small debris.
# - Selected the vacuum tool property as appropriate for small debris removal.
# - Used the robot selection tool function to find the best-suited robot with the vacuum tool property at the specified location.
#
# Results:
# - Robot50 was identified as the best-suited robot to remove small debris at location (5, 12).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot50 has been selected to perform the task. The Controller will now direct Robot50 to move to location (5, 12) and remove the small debris using its vacuum tool.
# ---
#
# Controller:
# Thought process:
# - Determined that the task required moving to a location and removing small debris.
# - Moved Robot50 to the desired location (5, 12) using the move_robot function.
# - Instructed Robot50 to remove the small debris using the grab_or_remove_item function.
# - Set Robot50's status to idle after completing the task.
#
# Results:
# - Robot50 successfully moved to location (5, 12).
# - Small debris was removed by Robot50 at the location.
# - Robot50's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot50;vacuum;small debris;(5, 12)
# ---
#
# 7. task: Move to location (11, 12) and remove the vehicle.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of moving to location (11, 12) and removing the vehicle.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task as requiring a tow hook to remove a vehicle.
# - Used the robot selection tool to find the best-suited robot with a tow hook near the specified location (11, 12).
# - The system provided two available robots and selected Robot23 as the best suited for the task.
#
# Results:
# - Robot23 has been selected to move to location (11, 12) and remove the vehicle.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot23 has been selected to complete the task. The Controller will now direct Robot23 to the specified location and oversee the vehicle removal process.
# ---
#
# Controller:
# Thought process:
# - Received instructions to move a robot to a specific location and remove a vehicle.
# - Selected Robot23 because it has a tow hook, which is suitable for the vehicle removal task.
# - Used the move_robot function to place Robot23 at the coordinates (11, 12).
# - Employed the grab_or_remove_item function to have Robot23 remove the vehicle.
# - Changed the status of Robot23 to idle after completing the task.
#
# Results:
# - Robot23 was successfully moved to location (11, 12).
# - Robot23 removed the vehicle as instructed.
# - Robot23's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot23;tow hook;vehicle;(11, 12)
# ---
#
# 8. task: Move to location (12, 1) and remove the construction materials.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot suitable for moving to location (12, 1) and removing construction materials.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task involves removing construction materials.
# - Selected the "gripper" tool as it's suitable for handling construction materials.
#
# Results:
# - Robot32 is chosen for the task because it is best suited with the "gripper" tool to remove construction materials at the specified location (12, 1).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot32 with the gripper tool has been chosen to perform the task. The Controller will now need to provide instructions to the robot to execute the task.
# ---
#
# Controller:
# Thought process:
# - Needed to first move the robot to the specified location to handle the task.
# - After moving, the robot had to grab or remove the construction materials.
# - Ensured that the robot's status was set to idle after completing the task.
#
# Results:
# - Robot32 was successfully moved to location (12, 1).
# - Robot32 grabbed or removed the construction materials at the location.
# - Robot32's status was set to idle after finishing the task.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot32;gripper;construction materials;(12, 1)
# ---
#
# 9. task: Move to location (8, 12) and remove the tree branches.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of moving to the specified location and removing tree branches.
# ---
#
# Robot Selector:
# Thought process:
# - Identified task of removing tree branches, which requires a saw.
# - Utilized the robot selection tool to find the best-suited robot with a saw based on the location (8, 12).
#
# Results:
# - Robot14 has been selected as the best-suited robot for removing tree branches at location (8, 12) with a saw.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot14 has been selected and needs to be directed to the location (8, 12) to remove the tree branches.
# ---
#
# Controller:
# Thought process:
# - The task required movement to a specific location and the removal of tree branches.
# - I used the move_robot function to move the robot to the location (8, 12).
# - After arriving at the location, I used the grab_or_remove_item function to remove the tree branches.
# - I then set the robot's status back to idle using the robot_status_change function to ensure it is ready for the next task.
#
# Results:
# - Robot14 was successfully moved to location (8, 12).
# - Robot14 removed the tree branches as requested.
# - Robot14's status is now set to idle, indicating it has completed the task and is ready for further instructions.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot14;saw;tree branches;(8, 12)
# ---
#
# 10. task: Move to location (3, 5) and remove the screws.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select a robot capable of moving to a specified location and removing screws.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task requires removing screws.
# - Recognized that a screwdriver is the appropriate tool for dealing with screws.
# - Used robot_selection_tool function to find the best-suited robot with a screwdriver near the specified location (3, 5).
#
# Results:
# - Robot45 has been selected as it is best suited to remove the screws at the given location.
# ---
#
# Supervisor:
# Next: Controller
# response: The Robot_selector has chosen Robot45 as suitable for the task. Now, the Controller should take over to guide Robot45 to the specified location and oversee the screw removal process.
# ---
#
# Controller:
# Thought process:
# - Required to move to a specific location and remove an item.
# - A robot with a screwdriver should move to location (3, 5) and then remove screws.
# - After task completion, the robot's status should be set to idle.
#
# Results:
# - Robot45 was moved to position (3, 5).
# - Robot45 removed the screws.
# - Robot45's status set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot45;screwdriver;screws;(3, 5)
# ---

# %% [markdown]
# ### Hard tests

# %%
import csv
file_path = "Results\Result_matrix\Hard_matrix.txt"
clear_txt(file_path)
# Open the CSV file once outside the loop for appending data
with open('Results\Raw_output\output_Hard.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=";")

    # Open the task file and read tasks one by one
    with open("Results\Tasks\Hard_tasks_test.txt", 'r') as file:
        i = 1
        while True:
            history = ""
            task = task_iteration(file)
            if not task:
                break
            
            # Print the task number and task to the console
            print(f"{i}. task: {task}")
            print("---")

            # Process each stream associated with the task
            j = 1
            for s in robot_control_chain.stream(
                task, {"recursion_limit": 100}
            ):
                if "__end__" not in s:
                    history += process_dict(s, file_path)
                    j+=1
                if j == 100:
                    # This is to ensure there is a response even though it fails due recursion limit
                    write_txt(file_path, "DNF;DNF;DNF;DNF\n")
                    history += "DNF"
                    break
            i += 1
            
            # Append both task and processed data to the CSV
            writer.writerow([task, history])
# Out:
# 1. task: Move Robot40 to location (4, 8) and remove the toolkit.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select Robot40 and verify if it is suitable for the task of moving to location (4, 8) and removing the toolkit.
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is required to remove a toolkit according to the provided list of items with associated tool properties.
# - "Vacuum" is not suitable for manipulating a toolkit as it is meant for cleaning dust and small debris, not for picking up solid items like a toolkit.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: The initial robot selection was not suitable for the task due to an incorrect tool property. A new robot with the appropriate 'gripper' tool needs to be selected to move Robot40 to location (4, 8) and remove the toolkit.
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is required to remove a toolkit according to the provided list of items with associated tool properties.
# - "Vacuum" is not suitable for manipulating a toolkit as it is meant for cleaning dust and small debris, not for picking up solid items like a toolkit.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Since Robot40 is not equipped with the appropriate tool for the task, we need to select a different robot that has a 'gripper' to perform the task of moving to location (4, 8) and removing the toolkit.
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is required to remove a toolkit according to the provided list of items with associated tool properties.
# - "Vacuum" is not suitable for manipulating a toolkit as it is meant for cleaning dust and small debris, not for picking up solid items like a toolkit.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot40 is equipped with a vacuum, which is not suitable for the task. A robot with a gripper tool needs to be selected to remove the toolkit.
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is required to remove a toolkit according to the provided list of items with associated tool properties.
# - "Vacuum" is not suitable for manipulating a toolkit as it is meant for cleaning dust and small debris, not for picking up solid items like a toolkit.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot40 is equipped with a vacuum, which is not suitable for the task. We need to select a different robot with a gripper tool to move the toolkit to location (4, 8).
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is required to remove a toolkit according to the provided list of items with associated tool properties.
# - "Vacuum" is not suitable for manipulating a toolkit as it is meant for cleaning dust and small debris, not for picking up solid items like a toolkit.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Since Robot40 is equipped with a vacuum and cannot complete the task, we need to find an alternative robot with a gripper tool to move the toolkit to the desired location.
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is necessary to manipulate a toolkit according to the provided list of items with associated tool properties.
# - The "vacuum" tool property is suitable for cleaning dust and small debris. It is not designed for picking up or manipulating solid items like a toolkit.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot40 is equipped with a vacuum and cannot complete the task requiring a gripper. Another robot with the appropriate tool must be selected.
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property "vacuum" because:
#
# - The initial selected tool was a "gripper", which is necessary to manipulate a toolkit according to the provided list of items with associated tool properties.
# - The "vacuum" tool property is suitable for cleaning dust and small debris. It is not designed for picking up or manipulating solid items like a toolkit.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot40;vacuum;toolkit;(4, 8)
# ---
#
# 2. task: Move Robot40 to location (6, 2) and remove the liquid spill.
# ---
# Supervisor:
# Next: Robot_selector
# response: Determining the suitable robot to remove the liquid spill at location (6, 2).
# ---
#
# Robot Selector:
# Robot40 cannot solve the task with the tool property: vacuum because the initial selected tool for removing a liquid spill is a mop, and Robot40 is equipped with a vacuum, which is not suitable for cleaning up liquids according to the list of items with associated tool properties.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot40 is not equipped with the correct tool for the task. A new robot selection is necessary to find one with a mop to clean the liquid spill.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task requires removing a liquid spill.
# - Recognized that the appropriate tool for removing a liquid spill is a mop.
# - Checked if Robot40 could perform the task, but it has a vacuum, which is not suitable for this task.
# - Searched for robots with a mop tool property near the location (6, 2).
#
# Results:
# - Robot26 has been selected as the best-suited robot with a mop to remove the liquid spill at location (6, 2).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot26 has been selected to perform the task. Controller will now instruct Robot26 to move to location (6, 2) and remove the liquid spill using its mop.
# ---
#
# Controller:
# Thought process:
# - Realized that a robot with a mop is needed to clean a liquid spill.
# - Identified that Robot40 has a vacuum, which is not suitable for the task.
# - Selected Robot26, which has a mop, to perform the task.
# - Moved Robot26 to the location (6, 2) and instructed it to remove the liquid spill.
# - Set Robot26's status to idle after the task was completed.
#
# Results:
# - Robot26 successfully moved to location (6, 2).
# - Robot26 removed the liquid spill.
# - Robot26's status is now idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot26;mop;liquid spill;(6, 2)
# ---
#
# 3. task: Move Robot9 to location (12, 3) and remove the large debris.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting a robot to move to location (12, 3) and remove the large debris.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the need for a gripper to handle large debris as per the toolkit provided.
# - Used the robot_selection_tool function to find the most appropriate robot with a gripper near the specified coordinates (12, 3).
# - Robot32 was determined to be the best-suited robot for the task.
#
# Results:
# - Robot32, equipped with a gripper, has been selected for the task of removing large debris at location (12, 3).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot32 has been selected and now the Controller must provide instructions for Robot32 to move to location (12, 3) and remove the large debris.
# ---
#
# Controller:
# Thought process:
# - The task required moving a robot to a specified location and removing an item.
# - Robot9 was moved to the location (12, 3) as the first step.
# - Subsequently, Robot9 was directed to grab/remove the large debris at the new location.
# - Finally, Robot9's status was changed to idle, indicating the completion of the task.
#
# Results:
# - Robot9 moved to location (12, 3).
# - Large debris was removed by Robot9.
# - Robot9's status is now idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot32;gripper;large debris;(12, 3)
# ---
#
# 4. task: Move Robot35 to location (2, 11) and remove the dust.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting the appropriate robot to move to location (2, 11) and remove the dust.
# ---
#
# Robot Selector:
# Thought process:
# - The task requires dust removal at location (2, 11).
# - The appropriate tools for dust removal are vacuum or broom, according to the provided list of items and associated tool properties.
# - Robot selection tool identified Robot50 as the best-suited robot with a vacuum for the task.
# - Robot35, which was initially selected for the task, does not have a vacuum but is equipped with a screwdriver.
#
# Results:
# - Robot35 cannot solve the task with a screwdriver, as this tool is not suitable for dust removal based on the list provided. The task requires a vacuum or broom, neither of which Robot35 possesses. Therefore, the task must be reassigned to Robot50, which has the appropriate vacuum tool property.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot35 is not equipped with the necessary tools for dust removal. We need to reassign the task to Robot50, which has a vacuum suitable for the task.
# ---
#
# Robot Selector:
# Initial selected tool: vacuum
#
# Robot35 cannot solve the task with the tool property: screwdriver because the task requires removing dust. According to the list of items with associated tool properties, the appropriate tools for dust removal are vacuum or broom. A screwdriver is not suitable for cleaning and therefore cannot be used to remove dust.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot35 is not equipped with the appropriate tool for dust removal. We need to reassign the task to a suitable robot with either a vacuum or broom.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task requires dust removal at location (2, 11).
# - Determined that the appropriate tools for dust removal are either a vacuum or broom.
# - Used the robot_selection_tool to find the best-suited robot with a vacuum for the task.
# - Found that Robot50 is the best candidate among available robots.
# - Selected Robot50 with the vacuum tool property to solve the task.
#
# Results:
# - Robot50 has been selected to move to location (2, 11) and remove the dust using its vacuum tool property.
# ---
#
# Supervisor:
# Next: Controller
# response: The Robot_selector has identified that Robot35 is not suitable for the task and has selected Robot50 with a vacuum to perform the task. The next step is for the Controller to manage Robot50's movement and dust removal at the specified location.
# ---
#
# Controller:
# Thought process:
# - Recognized the task required dust removal at a specific location.
# - Identified that Robot50, equipped with a vacuum, is suitable for dust removal.
# - Moved Robot50 to the location (2, 11).
# - Used Robot50 to grab/remove the dust.
# - Set Robot50's status to idle after completion.
#
# Results:
# - Robot50 successfully moved to location (2, 11) and removed the dust.
# - Robot50's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot50;vacuum;dust;(2, 11)
# ---
#
# 5. task: Move Robot26 to location (12, 1) and remove the grass.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting the appropriate robot capable of moving to the specified location and removing grass.
# ---
#
# Robot Selector:
# Robot26 cannot solve the task with the tool property: mop because the task requires a lawnmower to remove grass, and a mop is not suitable for this task according to the list of items with associated tool properties.
#
# Thought process:
# - Identified the need for a lawnmower to remove grass at the specified location.
# - Used robot_selection_tool to find the best-suited robots with a lawnmower.
# - Robot31 was suggested as the best-suited robot for the task.
# - Attempted to select Robot26 for the task, but it was equipped with a mop, which is not appropriate for grass removal.
#
# Results:
# - Robot26 cannot complete the task with its current tool (mop) as it is not suited for grass removal.
# - Robot31 is the best-suited robot with the proper lawnmower tool to complete the task.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot26 is not equipped with the correct tool for grass removal. Robot_selector will need to select Robot31 or another suitable robot with a lawnmower to complete the task.
# ---
#
# Robot Selector:
# Robot26 cannot solve the task with the tool property: mop because the task requires a lawnmower to remove grass, and a mop is not suitable for this task according to the list of items with associated tool properties.
#
# Thought process:
# - Identified the need for a lawnmower to remove grass.
# - Checked if Robot26 had the required lawnmower tool.
# - Determined that Robot26 has a mop, which is not suitable for grass removal.
#
# Results:
# - Robot26 cannot complete the task with its current tool (mop) as it is not suited for grass removal.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: The Robot_selector should attempt to find a suitable robot with the correct tool property, a lawnmower, to complete the task of removing grass at location (12, 1).
# ---
#
# Robot Selector:
# Thought process:
# - The task required a robot with a lawnmower to remove grass.
# - Used the robot_selection_tool to identify the best-suited robot equipped with a lawnmower.
#
# Results:
# - Robot31 has been identified as the best-suited robot for removing grass at location (12, 1).
# ---
#
# Supervisor:
# Next: Controller
# response: Since Robot26 is not equipped with the necessary tool to remove grass, the Controller needs to assign Robot31, which has the required lawnmower, to complete the task.
# ---
#
# Controller:
# Thought process:
# - Identified the need for a lawnmower to complete the task.
# - Selected Robot31, which is equipped with a lawnmower, for the task.
# - Moved Robot31 to the specified location.
# - Made Robot31 remove the grass.
# - Set Robot31's status back to idle after completing the task.
#
# Results:
# - Robot31 was successfully moved to location (12, 1).
# - Robot31 removed the grass as required.
# - Robot31's status is now idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot31;lawnmower;grass;(12, 1)
# ---
#
# 6. task: Move Robot41 to location (4, 11) and remove the small debris.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting the appropriate robot to move to location (4, 11) and remove the small debris.
# ---
#
# Robot Selector:
# Robot41 cannot solve the task with the tool property: lawnmower because according to the list of items with associated tool properties, the task of removing small debris requires either a broom or a vacuum. The lawnmower is suitable for cutting grass and not for removing debris. Consequently, Robot41 is not equipped with the appropriate tool for this task.
#
# Thought process:
# - Identified that the task involves removing small debris.
# - Consulted the list of items with associated tool properties to find that a vacuum is suitable for small debris.
# - Searched for the best-suited robot using the robot selection tool with the desired property "vacuum" and the item's position.
# - Selected Robot50 as the most suitable robot for the task according to the available options.
# - Checked if Robot41, which was initially selected, could perform the task with its equipped tool, a lawnmower.
# - Concluded that Robot41 with a lawnmower cannot complete the task as it does not align with the required tool properties for small debris removal.
#
# Results:
# - Robot50 has been identified as the best-suited robot for the task with a vacuum to remove small debris.
# - Robot41 with a lawnmower cannot perform the task as it is not equipped with the appropriate tool for removing small debris.
# ---
#
# Supervisor:
# Next: misc_agent
# response: The Robot_selector has determined that Robot41 is not suitable for the task due to its tool property. The task requires a robot with either a broom or a vacuum. The Robot_selector recommended Robot50 with a vacuum for the task. The misc_agent should now verify the availability of Robot50 and coordinate its movement to location (4, 11) to perform the debris removal.
# ---
#
# misc_agent:
# The task you've mentioned involves moving a robot to a specific location and removing small debris. However, my capabilities are focused on answering questions and providing responses; I am not able to directly control or assign tasks to robots.
#
# If you are looking for assistance with a different kind of question or need information that doesn't involve the physical task of moving a robot and removing debris, please let me know, and I'll be happy to help.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot_selector needs to select a suitable robot for the task as Robot41 with a lawnmower cannot complete it.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task requirement to remove small debris.
# - Based on the provided list, recognized that a vacuum is suitable for small debris.
# - Used the robot selection tool to find the most suitable robot equipped with a vacuum, near the specified location (4, 11).
#
# Results:
# - Robot50 has been selected as the best-suited robot for the task of removing small debris at location (4, 11).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot50 has been selected by the Robot_selector as the suitable robot equipped with a vacuum to remove the small debris at location (4, 11). The Controller should now act to move Robot50 to the specified location and oversee the task completion.
# ---
#
# Controller:
# Thought process:
# - Identified that Robot41's tool, a lawnmower, is not suitable for removing debris.
# - Selected Robot50, which is equipped with a vacuum, a suitable tool for the task.
# - Moved Robot50 to the location (4, 11).
# - Used Robot50 to grab/remove the small debris.
# - Set Robot50's status to idle after the task was completed.
#
# Results:
# - Robot50 successfully moved to the location (4, 11).
# - Small debris at the location was removed by Robot50.
# - Robot50's status is now idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot50;vacuum;small debris;(4, 11)
# ---
#
# 7. task: Move Robot2 to location (9, 1) and remove the vehicle.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select Robot2 and ensure it is equipped to remove a vehicle at location (9, 1).
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task required a robot with a tow hook to remove a vehicle.
# - Used the robot selection tool to find the best-suited robot with a tow hook near the given location (9, 1).
# - Selected Robot23 as it is the best suited for the task according to the available data.
#
# Results:
# - Robot23, equipped with a tow hook, has been selected to move to location (9, 1) and remove the vehicle.
# ---
#
# Supervisor:
# Next: Controller
# response: The Robot_selector has chosen Robot23 equipped with a tow hook for the task. Now, the Controller must command Robot23 to move to the specified location and execute the vehicle removal.
# ---
#
# Controller:
# Thought process:
# - Received instructions to move Robot2 to a specific location and remove a vehicle.
# - Executed the move_robot function to reposition Robot2 to the coordinates (9, 1).
# - Used the grab_or_remove_item function to remove the vehicle at the new location.
# - Changed Robot2's status to idle using the robot_status_change function upon completion of the tasks.
#
# Results:
# - Robot2 successfully moved to coordinates (9, 1).
# - The vehicle at the location has been removed by Robot2.
# - Robot2's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot23;tow hook;vehicle;(9, 1)
# ---
#
# 8. task: Move Robot28 to location (11, 6) and remove the construction materials.
# ---
# Supervisor:
# Next: Robot_selector
# response: Select Robot28 and verify if it's suitable for the task of moving to location (11, 6) and removing construction materials.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task involved removing construction materials, which can be handled with a gripper, front loader, or tow hook.
# - Chose to use the gripper tool property for efficiency in handling construction materials.
# - Searched for the most suitable robot with the gripper tool property near the specified location (11, 6).
# - Selected Robot42 as it was determined to be the best suited robot to solve the task with the gripper tool property.
#
# Results:
# - Robot42, equipped with a gripper, has been tasked with moving to location (11, 6) to remove the construction materials.
# ---
#
# Supervisor:
# Next: Controller
# response: Robot42 has been selected to perform the task. The Controller will now instruct Robot42 to move to the location and remove the construction materials.
# ---
#
# Controller:
# Thought process:
# - Received a task to move a robot to a specific location and remove construction materials.
# - Verified that Robot28 does not have a specified tool property that must be used for this task.
# - Moved Robot28 to the position (11, 6) as requested.
# - Instructed Robot28 to grab or remove the construction materials at the location.
# - After completion of the task, set Robot28's status to idle to indicate it's ready for the next command.
#
# Results:
# - Robot28 successfully moved to location (11, 6).
# - Robot28 removed the construction materials at the specified location.
# - Robot28's status is now set to idle, indicating it's ready for further tasks.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot28;gripper;construction materials;(11, 6)
# ---
#
# 9. task: Move Robot39 to location (6, 1) and remove the tree branches.
# ---
# Supervisor:
# Next: Robot_selector
# response: We need to select an appropriate robot capable of moving to the location and removing tree branches.
# ---
#
# Robot Selector:
# Thought process:
# - Identified the task required removing tree branches, which is best done with a saw.
# - Used the robot_selection_tool to find the most suitable robot with a saw, given the location (6, 1).
#
# Results:
# - Robot24 has been selected as the best-suited robot to remove the tree branches at location (6, 1).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot24 has been selected to remove the tree branches at location (6, 1). The Controller needs to move Robot24 to the specified location and oversee the task execution.
# ---
#
# Controller:
# Thought process:
# - Received the task to move a robot to a specific location and remove tree branches.
# - Selected Robot24 for the task since it has a saw tool, which is suitable for cutting branches.
# - Used the `move_robot` function to move Robot24 to the location (6, 1).
# - Used the `grab_or_remove_item` function to remove the tree branches.
# - Changed the status of Robot24 to idle after completing the task using `robot_status_change`.
#
# Results:
# - Robot24 was successfully moved to location (6, 1).
# - Tree branches were removed by Robot24.
# - Robot24's status is now set to idle.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot24;saw;tree branches;(6, 1)
# ---
#
# 10. task: Move Robot28 to location (2, 8) and remove the screws.
# ---
# Supervisor:
# Next: Robot_selector
# response: Selecting the appropriate robot to move to location (2, 8) and remove the screws.
# ---
#
# Robot Selector:
# Initial selected tool: screwdriver
# Robot28 cannot solve the task with the tool property: broom because the task requires a screwdriver to remove screws, and a broom is not suitable for this purpose. The list of items with associated tool properties indicates that screws need a screwdriver, which is different from the broom that Robot28 is equipped with.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot28 is not equipped with the right tool for the task. A new robot with the correct tool needs to be selected to move to location (2, 8) and remove the screws.
# ---
#
# Robot Selector:
# Initial selected tool: screwdriver
# Robot28 cannot solve the task with the tool property: broom because the task requires a screwdriver to remove screws, and a broom is not suitable for this purpose. The list of items with associated tool properties indicates that screws need a screwdriver, which is different from the broom that Robot28 is equipped with.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot28 is not equipped with the correct tool for the task. We need to select a different robot that has a screwdriver.
# ---
#
# Robot Selector:
# Initial selected tool: screwdriver
# Robot28 cannot solve the task with the tool property: broom because the task requires a screwdriver to remove screws, and a broom is not suitable for this purpose. The list of items with associated tool properties indicates that screws need a screwdriver, which is different from the broom that Robot28 is equipped with.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot28 is not suitable for the task as it has a broom instead of a screwdriver. The Robot_selector should attempt to find another robot with the correct tool property to complete the task.
# ---
#
# Robot Selector:
# Initial selected tool: screwdriver
# Robot28 cannot solve the task with the tool property: broom because the task requires a screwdriver to remove screws. According to the list of items with associated tool properties, a screwdriver is necessary to manipulate screws, and a broom is not suitable for this purpose. Therefore, Robot28 with a broom cannot perform the task of removing screws.
# ---
#
# Supervisor:
# Next: Robot_selector
# response: Robot28 is not suitable with its current tool. Select a different robot equipped with a screwdriver to complete the task.
# ---
#
# Robot Selector:
# Thought process:
# - Identified that the task requires a screwdriver to remove screws.
# - Determined that the initially selected robot, Robot28, is not equipped with a screwdriver but instead has a broom, and thus cannot perform the task.
# - Utilized the robot selection tool to find a robot with a screwdriver available for the specified location.
#
# Results:
# - Robot45, equipped with a screwdriver, is the best suited to solve the task of removing screws at location (2, 8).
# ---
#
# Supervisor:
# Next: Controller
# response: Robot45 is equipped with the necessary tool for the task. The Controller should now direct Robot45 to move to location (2, 8) and remove the screws.
# ---
#
# Controller:
# Thought process:
# - Understood that the task required a screwdriver to remove screws.
# - Recognized that Robot28, which has a broom, could not perform the task.
# - Selected Robot45, which is equipped with a screwdriver, as the suitable robot for the task.
# - Directed Robot45 to move to the specified location (2, 8).
# - Instructed Robot45 to grab/remove the screws.
# - Set Robot45's status to idle after completing the task.
#
# Results:
# - Robot45 successfully moved to location (2, 8).
# - Robot45 removed the screws as required.
# - Robot45 is now set to idle status, indicating the completion of the task.
# ---
#
# Supervisor:
# Next: FINISH
# response: Robot45;screwdriver;screws;(2, 8)
# ---

# %%
# for s in robot_control_chain.stream(
#     "Move Robot2 to location (2, 4) and pick up the toolkit.", {"recursion_limit": 100}
# ):
#     if "__end__" not in s:
#         process_dict(s)
#         print("---")

# %% [markdown]
# ## Visualize graph

# %%
# chain.get_graph().draw_png()
