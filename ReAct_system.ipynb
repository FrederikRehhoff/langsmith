# %%
# %%capture --no-stderr
# %pip install -U langchain langimport os langchainhub
# Out:
# ERROR: Could not find a version that satisfies the requirement langimport (from versions: none)
# ERROR: No matching distribution found for langimport
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Initialize environment variables

# %%
import os
os.environ["OPENAI_API_KEY"] = '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'
os.environ["LANGCHAIN_API_KEY"] = 'ls__c0f826e0c4514d678c5fdec4a48e6b92'
os.environ["TAVILY_API_KEY"] = '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'

# %%
# %pip install langchainhub
# Out:
# Requirement already satisfied: langchainhub in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (0.1.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0.20240403)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from google.colab import userdata
import getpass
import os



def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass(f"Please provide your {var}")

_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("LANGCHAIN_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
# os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")
# os.environ["LANGCHAIN_API_KEY"] = userdata.get("LANGCHAIN_API_KEY")

# Optional, add tracing in LangSmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "ReAct"

# %% [markdown]
# ## Initialize dummy robots
#
# This code is the simplified version of the actual agent code. This is only to show that the tools for the llm is working with the robot class

# %%
from typing import Tuple
import random

class Agent(object):
    def __init__(self, name, position, color, tool_property, inventory, status="idle"):
        self._name = name
        self._position = position
        self._color = color
        self._goal = None
        self._status = status
        self.tool_property = tool_property
        self._inventory = []
        

    def setGoal(self, goal):
        """Sets the Goal for the robot"""
        self._goal = goal
        self.set_status("active")


    def set_status(self, status="idle"):
        if status in ["idle", "active", "charging"]:
            old_status = self._status
            self._status = status
            if self._status == "idle":
                self._goal = None
    
    def add_item_invetory(self, item):
        self._inventory.append(item)

    @property
    def tool_property(self) -> str:
        """agent tool i.e gripper"""
        return self._tool_property
    
    @tool_property.setter
    def tool_property(self, new_tool):
        self._tool_property = new_tool

    @property
    def inventory(self) -> list:
        """ An agents inventory """
        return self._inventory

    @property
    def position(self) -> Tuple[int, int]:
        """ The position of the agent """
        return self._position

    @position.setter
    def position(self, new_position: Tuple[int, int]):
        """ Set the new position

        :new_position: The new node id

        """
        self._position = new_position

    @property
    def name(self) -> str:
        """ The name of the agent """
        return self._name

    @name.setter
    def name(self, new_name: str):
        """ Sets a new name for the agent

        :new_name: The new name for the agent

        """
        self._name = new_name

    @property
    def color(self) -> str:
        """ The color of the agent """
        return self._color

    @color.setter
    def color(self, new_color: str):
        """ Sets a new color for the agent

        :new_goal: The new color for the agent

        """
        self._color = new_color

    @property
    def goal(self) -> Tuple[int, int]:
        """ The goal of the agent """
        return self._goal

    @goal.setter
    def goal(self, new_goal: Tuple[int, int]):
        """ Set the new goal

        :new_goal: The new goal node id

        """
        self._goal = new_goal

# %%
# Available tools is: lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum
# define agents:  ('name', placement: (x,y), 'color', Property, inventory)
R1 = Agent("Robot1", (12, 4), "aqua", "lawnmower", None, "active")
R2 = Agent("Robot2", (4, 6), "maroon", "gripper", None, "charging")
R3 = Agent("Robot3", (4, 12), "green", "tow hook", None, "active")
R4 = Agent("Robot4", (5, 1), "purple", "saw", None, "active")
R5 = Agent("Robot5", (9, 2), "orange", "screwdriver", None, "active")
R6 = Agent("Robot6", (3, 10), "pink", "mop", None, "charging")
R7 = Agent("Robot7", (5, 7), "blue", "spray nozzle", None, "active")
R8 = Agent("Robot8", (8, 3), "olive", "broom", None, "idle")
R9 = Agent("Robot9", (5, 10), "silver", "front loader", None, "charging")
R10 = Agent("Robot10", (10, 6), "cyan", "vacuum", None, "charging")
R11 = Agent("Robot11", (11, 5), "navy", "lawnmower", None, "charging")
R12 = Agent("Robot12", (1, 6), "yellow", "gripper", None, "active")
R13 = Agent("Robot13", (1, 9), "pink", "tow hook", None, "charging")
R14 = Agent("Robot14", (11, 11), "silver", "saw", None, "idle")
R15 = Agent("Robot15", (6, 11), "orange", "screwdriver", None, "charging")
R16 = Agent("Robot16", (6, 8), "olive", "mop", None, "active")
R17 = Agent("Robot17", (12, 9), "fuchsia", "spray nozzle", None, "idle")
R18 = Agent("Robot18", (4, 5), "black", "broom", None, "active")
R19 = Agent("Robot19", (3, 12), "magenta", "front loader", None, "idle")
R20 = Agent("Robot20", (5, 9), "black", "vacuum", None, "active")
R21 = Agent("Robot21", (9, 7), "magenta", "lawnmower", None, "charging")
R22 = Agent("Robot22", (8, 11), "blue", "gripper", None, "idle")
R23 = Agent("Robot23", (11, 7), "silver", "tow hook", None, "idle")
R24 = Agent("Robot24", (10, 5), "navy", "saw", None, "idle")
R25 = Agent("Robot25", (10, 11), "white", "screwdriver", None, "active")
R26 = Agent("Robot26", (1, 2), "aqua", "mop", None, "idle")
R27 = Agent("Robot27", (2, 1), "white", "spray nozzle", None, "charging")
R28 = Agent("Robot28", (2, 7), "navy", "broom", None, "charging")
R29 = Agent("Robot29", (10, 8), "aqua", "front loader", None, "charging")
R30 = Agent("Robot30", (7, 12), "fuchsia", "vacuum", None, "active")
R31 = Agent("Robot31", (12, 2), "fuchsia", "lawnmower", None, "charging")
R32 = Agent("Robot32", (12, 8), "olive", "gripper", None, "charging")
R33 = Agent("Robot33", (5, 5), "lime", "tow hook", None, "active")
R34 = Agent("Robot34", (8, 4), "black", "saw", None, "active")
R35 = Agent("Robot35", (5, 11), "black", "screwdriver", None, "idle")
R36 = Agent("Robot36", (5, 8), "olive", "mop", None, "active")
R37 = Agent("Robot37", (8, 1), "maroon", "spray nozzle", None, "idle")
R38 = Agent("Robot38", (10, 4), "green", "broom", None, "active")
R39 = Agent("Robot39", (1, 1), "yellow", "front loader", None, "idle")
R40 = Agent("Robot40", (11, 3), "magenta", "vacuum", None, "charging")
R41 = Agent("Robot41", (10, 1), "olive", "lawnmower", None, "charging")
R42 = Agent("Robot42", (10, 7), "teal", "gripper", None, "charging")
R43 = Agent("Robot43", (11, 9), "blue", "tow hook", None, "active")
R44 = Agent("Robot44", (9, 6), "fuchsia", "saw", None, "active")
R45 = Agent("Robot45", (2, 3), "blue", "screwdriver", None, "idle")
R46 = Agent("Robot46", (1, 7), "black", "mop", None, "active")
R47 = Agent("Robot47", (2, 6), "maroon", "spray nozzle", None, "idle")
R48 = Agent("Robot48", (7, 2), "lime", "broom", None, "idle")
R49 = Agent("Robot49", (6, 9), "orange", "front loader", None, "active")
R50 = Agent("Robot50", (7, 8), "red", "vacuum", None, "idle")


robots = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, 
          R11, R12, R13, R14, R15, R16, R17, R18, R19, R20, 
          R21, R22, R23, R24, R25, R26, R27, R28, R29, R30, 
          R31, R32, R33, R34, R35, R36, R37, R38, R39, R40, 
          R41, R42, R43, R44, R45, R46, R47, R48, R49, R50]

# Extracting used coordinates from the robot definitions and generating a list of coordinates not in use within (12, 12) space.
used_coordinates = []
for robot in robots:
    used_coordinates.append(robot.position)

# Generating all possible coordinates within a 12x12 space
all_coordinates = [(x, y) for x in range(1, 13) for y in range(1, 13)]

# Finding the coordinates not in use
unused_coordinates = [coord for coord in all_coordinates if coord not in used_coordinates]
total = len(unused_coordinates) + len(robots)
if total == 12*12:
    print("correct number of unsued positions")
    print(unused_coordinates)
else:
    print("incorrect number of unsued positions")
# Out:
# correct number of unsued positions
# [(1, 3), (1, 4), (1, 5), (1, 8), (1, 10), (1, 11), (1, 12), (2, 2), (2, 4), (2, 5), (2, 8), (2, 9), (2, 10), (2, 11), (2, 12), (3, 1), (3, 2), (3, 3), (3, 4), (3, 5), (3, 6), (3, 7), (3, 8), (3, 9), (3, 11), (4, 1), (4, 2), (4, 3), (4, 4), (4, 7), (4, 8), (4, 9), (4, 10), (4, 11), (5, 2), (5, 3), (5, 4), (5, 6), (5, 12), (6, 1), (6, 2), (6, 3), (6, 4), (6, 5), (6, 6), (6, 7), (6, 10), (6, 12), (7, 1), (7, 3), (7, 4), (7, 5), (7, 6), (7, 7), (7, 9), (7, 10), (7, 11), (8, 2), (8, 5), (8, 6), (8, 7), (8, 8), (8, 9), (8, 10), (8, 12), (9, 1), (9, 3), (9, 4), (9, 5), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (10, 2), (10, 3), (10, 9), (10, 10), (10, 12), (11, 1), (11, 2), (11, 4), (11, 6), (11, 8), (11, 10), (11, 12), (12, 1), (12, 3), (12, 5), (12, 6), (12, 7), (12, 10), (12, 11), (12, 12)]

# %% [markdown]
# ## Create Tools

# %% [markdown]
# **Helper functions**

# %%
def sort_by_tool(tool_name, robot_list=robots):
    usable_robots = []
    for robot in robot_list:
        if robot.tool_property == tool_name:
            usable_robots.append(robot)
    return usable_robots

def sort_by_availability(robot_list, target_pos):
    available_robots = []
    if robot_list:
        closest_robot = robot_list[0].name
        min_dist = dist_func(robot_list[0].position, target_pos)
        flag = True
        for robot in robot_list:
            if robot._status != "active":
                available_robots.append(robot.name)
                if flag:
                    flag = False
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
                    
                if min_dist > dist_func(robot.position, target_pos):
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
        if available_robots:
            return f"out of available robot: {available_robots}, {closest_robot} is the best suited to solve the task."
    return "no robot with the specified tool to solve the task"

def dist_func(robot_pos, target_pos):
    x_dist = abs(target_pos["x"] - robot_pos[0])
    y_dist = abs(target_pos["y"] - robot_pos[1])
    total_dist = x_dist + y_dist
    return total_dist

def select_known_robot(robot_name, desired_tool, robot_list=robots):
    for robot in robot_list:                
        if robot_name == robot.name:
            if robot._status != "active":
                if desired_tool == robot.tool_property:
                    return f"{robot_name} with the tool property: {robot.tool_property} has been selected to solve the task."
                return f"""{robot_name} is not equipped with the tool property initially selected for task completion. 
                Can {robot_name} with tool property: {robot.tool_property} still solve the task?
                If a list of items with assoicated tool properties is provided, remember to use that as reference.
                In your anwser please stat the initial selected tool and why {robot_name} can/can't solve the task with the tool property: {robot.tool_property}. in this step be strict and try to stay close to the list of items with assoicated tool properties
                """
            return f"{robot_name} is currently active and is not available to solve the task"
    return f"{robot_name} is not a valid robot"

def change_status(robot_name, robot_list=robots, status="idle"):
    for robot in robot_list:
        if robot_name == robot.name:
            old_status = robot._status
            robot.set_status(status)
            return f"{robot.name} has changed status from {old_status} to {status}"

def set_goal(robot_name: str, position: Tuple, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.setGoal(position)
            return robot.goal
        
def add_item_to_inventory(robot_name, item_name, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.add_item_invetory(item_name)

# %% [markdown]
# **LLM tools**

# %%
from typing import Annotated, List, Tuple, Union

from langchain_core.tools import tool
from langsmith import trace

from langchain_core.pydantic_v1 import BaseModel, Field


class desired_robot_tool_property(BaseModel):
    """Inputs to the tools."""

    desired_robot_tool_property: str = Field(
        description="The desired tool property which is requied to solve the task given"
    )


@tool
def move_robot(robot_name: str, position: Tuple) -> str:
    """Moves the Specified robot to the desired position"""
    goal = set_goal(robot_name=robot_name, position=position)
    return f"{robot_name} has been moved to the desired position {goal}"

@tool
def grab_or_remove_item(robot_name: str, item_name: str) -> str:
    """makes the specified robot grab/remove the desired item"""
    add_item_to_inventory(robot_name=robot_name, item_name=item_name)
    return f"{robot_name} has grabed/removed the desired item {item_name}"

@tool
def robot_status_change(robot_name: str, status: str):
    """Changes the status of a robot"""
    return change_status(robot_name=robot_name, status=status)

@tool
def robot_selection_tool(desired_robot_tool_property, 
                         item_position) -> str:
    """Finds the most robots with the desired tool property. Remember that the item_position needs to be a dict of x and y coordinates"""
    sorted_robots = sort_by_tool(desired_robot_tool_property)
    return sort_by_availability(sorted_robots, item_position)
@tool
def select_known_robot_tool(robot_name: str, desired_robot_tool_property) -> str:
    """select the specified robot to solve the task. If the robot does not have the desired tool for the task, then it will ask if the robot still can solve the task.
    This tool does not alter the tools a robot has, but will try to use the selected robot although it might not have the desired tool.
    """
    return select_known_robot(robot_name=robot_name, desired_tool=desired_robot_tool_property)

@tool
def agent_response_tool(input: str, response: str) -> str:
    """this is a tool that returns the response to the input"""
    return response


control_tools = [move_robot, grab_or_remove_item, robot_status_change]
selection_tools = [robot_selection_tool, select_known_robot_tool]
misc_tools = [agent_response_tool]

# %% [markdown]
# ## Define our Execution Agent + state
#
# Let's now start by defining the state the track for this agent.
#
# First, we will need to track the current plan. Let's represent that as a list of strings.
#
# Next, we should track previously executed steps. Let's represent that as a list of tuples (these tuples will contain the step and then the result)
#
# Finally, we need to have some state to represent the final response as well as the original input.

# %%
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import List, Tuple, Annotated, TypedDict
import operator


class PlanExecute(TypedDict):
    input: str
    plan: List[str]
    current_step: str
    # Used to route work. The supervisor calls a function
    # that will update this every time it makes a decision
    next: str
    # The reason behind the member choice
    reasoning: str
    past_steps: Annotated[List[Tuple], operator.add]
    response: List[str]
    robot_name: str
    tool_property: str
    item: str
    item_position: Tuple[int]

# %% [markdown]
# Now we will create the execution agent(s) we want to use to execute tasks.

# %%
from typing import Any, Callable, List, Optional, TypedDict, Union

from langchain.agents import AgentExecutor, create_openai_tools_agent, create_tool_calling_agent
from langgraph.prebuilt import create_agent_executor
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import Runnable
from langchain_core.tools import BaseTool
from langchain_openai import ChatOpenAI

from langgraph.graph import END, StateGraph

def create_executor_agent(
    llm: ChatOpenAI,
    tools: list,
    system_prompt: str,
) -> str:
    """Create a function-calling agent and add it to the graph."""
    system_prompt += """\nWork autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.
    """

    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt,
            ),
            MessagesPlaceholder(variable_name="chat_history", optional=True),
            (
                "human",
                "{input}",
            ),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )

    agent = create_tool_calling_agent(llm, tools, prompt)
    executor = create_agent_executor(agent, tools)
    return executor

def create_team_supervisor(llm: ChatOpenAI, system_prompt, members) -> str:
    """An LLM-based router."""
    options = members
    function_def = {
        "name": "route",
        "description": "Select the next role.",
        "parameters": {
            "title": "routeSchema",
            "type": "object",
            "properties": {
                "next": {
                    "title": "Next",
                    "anyOf": [
                        {"enum": options},
                    ],
                },
                "reasoning": {
                    "type": "string",
                    "description": "The reason behind the choice of member"
                }
            },
            "required": ["reasoning", "next"],
        },
    }
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            (
                "human",
                "{current_step}",
            ),
            (
                "system",
                "Given the conversation above, who should act next? Select one of: {options}, and remember to give reasoning behind the choice",
            ),
        ]
    ).partial(options=str(options), team_members=", ".join(members))
    return (
        prompt
        | llm.bind_functions(functions=[function_def], function_call="route")
        | JsonOutputFunctionsParser()
    )

# %%
import functools

# Choose the LLM that will drive the agent

# ----- GPT-3.5 -----
# llm_agents = ChatOpenAI(model="gpt-3.5-turbo-1106")
# llm_planner = ChatOpenAI(model="gpt-3.5-turbo-1106")

# ----- GPT-4 -------
llm_agents = ChatOpenAI(model="gpt-4-1106-preview")
llm_planner = ChatOpenAI(model="gpt-4-1106-preview")



control_agent = create_executor_agent(
    llm_agents, 
    control_tools, 
    """
    You are an agent that control robots actions using the tools available to you.
    remember you are only able to grab/remove the items and not the robots tool property. this is the list of tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].
     which are not to be grabed or removed.
    """
    )


robot_selector_agent = create_executor_agent(
    llm_agents,
    selection_tools,
    """
    You are a agent with the purpose to select the best suited robot for the task. A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].
    If a specified robot is already selected to solve the task, use select_known_robot_tool.
    Here is an example of that.

    EXAMPLE: 
    task = "Move robot_name to location (2, 11) and sort the recyclables."
    Robot = robot_name
    END EXAMPLE

    remember to select the most apropriate tool_property for the task i.e a gripper for a task where something needs to be picked up.

    here is a list of items, and what tool property can manipulating that item:
    
    toolkit = gripper
    liquid spill = mop
    large debris = gripper, front loader 
    dust = vacuum, broom
    grass = lawnmower
    small debris = broom, vacuum 
    vehicle = tow hook
    construction materials = gripper, front loader, tow hook
    tree branches = saw
    screws = screwdriver

    remember that each of the items in the list is a category of it's own
    
"""
)


misc_agent = create_executor_agent(
    llm_agents,
    misc_tools,
    """
    You are an agent that can answer general questions and messages that doesn't have anything to do with making a robot solve a complex task.
    """
)


supervisor_agent = create_team_supervisor(
    llm_agents,
    """
    You are a supervisor tasked with routing the current_step to the following workers: Controller, Robot_selector, misc_agent.
    Given the following user request, respond with the worker to act next and the reason behind the choice.
    The selected worker will perform the current_step.

    Controller:
    Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

    tool functionality:
        - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
        - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
        - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

    Robot_selector:
    Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

    tool functionality:
        - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
        - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    misc_agent:
    Reponsible for anwsering more generic questions with tool: [agent_response_tool].
    
    """,
    ["Controller", "Robot_selector", "misc_agent"],
)

# %%
# robot_selector_agent.invoke(
#     {"input": ["Which robot should solve the task located at (6, 6)? The task requires a gripper"], "chat_history": []}
# )

# %% [markdown]
# ## Planning Step
#
# Let's now think about creating the planning step. This will use function calling to create a plan.

# %%
from langchain_core.pydantic_v1 import BaseModel


class Plan(BaseModel):
    """Plan to follow in future"""

    steps: List[str] = Field(
        description="different steps to follow, should be in sorted order"
    )
    current_step: str = Field(
        description="the first step to follow as per the steps variable"
    )

# %%
from langchain.chains.openai_functions import create_structured_output_runnable
from langchain_core.prompts import ChatPromptTemplate

control_tools = [move_robot, grab_or_remove_item, robot_status_change]
selection_tools = [robot_selection_tool, select_known_robot_tool]
misc_tools = [agent_response_tool]

planner_prompt = ChatPromptTemplate.from_template(
"""For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

When making the plan, keep in mind the executor agents capabilities:

Controller:
Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

tool functionality:
    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

Robot_selector:
Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

tool functionality:
    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    Here is an example of a task with and without a specified robot.
    
    EXAMPLE WITH SPECIFIED ROBOT:
     - Move Robot22 to location (6, 1) and remove the toolkit.

    EXAMPLE WITHOUT SPECIFIED ROBOT:
     - Move to location (9, 4) and remove the construction materials.

misc_agent:
Reponsible for anwsering more generic questions with tool: [agent_response_tool].

If there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.

When designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.

A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].

{objective}"""
)
planner = create_structured_output_runnable(
    Plan, llm_planner, planner_prompt
)

# %%
# planner.invoke(
#     {"objective": "Move to location (5, 4) and sweep the fallen leaves."}
# )

# %% [markdown]
# ## Re-Plan Step
#
# Now, let's create a step that re-does the plan based on the result of the previous step.

# %%
from langchain.chains.openai_functions import create_openai_fn_runnable


class Response(BaseModel):
    """Response to user."""
    robot_name: str = Field(
        description="The robot that solved the task i.e Robot22"
    )
    tool_property: str = Field(
        description="The tool property of {robot_name} i.e gripper"
    )
    item: str = Field(
        description="The item that is being manipulated i.e toolkit"
    )
    item_position: str = Field(
        description="The position of {item} i.e (11, 8)"
    )
    response: str


replanner_prompt = ChatPromptTemplate.from_template(
"""For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

When making the plan, keep in mind the executor agents capabilities:

Controller:
Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

tool functionality:
    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

Robot_selector:
Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

tool functionality:
    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    Here is an example of a task with and without a specified robot.
    
    EXAMPLE WITH SPECIFIED ROBOT:
     - Move Robot22 to location (6, 1) and remove the toolkit.

    EXAMPLE WITHOUT SPECIFIED ROBOT:
     - Move to location (9, 4) and remove the construction materials.

misc_agent:
Reponsible for anwsering more generic questions with tool: [agent_response_tool].

If there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.

When designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.

A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].

Your objective was this:
{input}

Your original plan was this:
{plan}

You have currently done the follow steps:
{past_steps}

Update your plan accordingly. If no more steps are needed and you can return to the user, then respond to the user. Otherwise, fill out the plan. Only add steps to the plan that still NEED to be done. Do not return previously done steps as part of the plan.
Remember to fill out the response to the user completely.
"""
)


replanner = create_openai_fn_runnable(
    [Plan, Response],
    llm_planner,
    replanner_prompt,
)

# %% [markdown]
# ## Create the Graph
#
# We can now create the graph!

# %%
def clear_txt(path):
    # Clear the file by opening it in write mode and closing it
    with open(path, "w") as file:
        pass

def write_txt(path, string):
    # Open the file in append mode and write the string
    with open(path, "a") as file:
        file.write(string)

# %%
file_name = "temp_react.txt"

async def controller_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await control_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def robot_selector_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await robot_selector_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def misc_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await misc_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def plan_step(state: PlanExecute):
    plan = await planner.ainvoke({"objective": state["input"]})
    return {"plan": plan.steps, "current_step": plan.current_step}


async def replan_step(state: PlanExecute):
    output = await replanner.ainvoke(state)
    if isinstance(output, Response):
        # return {"response": output.response}
        write_txt(file_name, f"{output.robot_name};{output.tool_property};{output.item};{output.item_position}\n")
        return {"response": output.response, "robot_name": output.robot_name, "tool_property": output.tool_property, "item": output.item, "item_position": output.item_position}
    else:
        return {"plan": output.steps, "current_step": output.current_step}


def should_end(state: PlanExecute):
    if "response" in state and state["response"]:
        return True
    else:
        return False

# %%
from langgraph.graph import StateGraph, END

workflow = StateGraph(PlanExecute)

# Add the plan node
workflow.add_node("planner", plan_step)

# Add supervisor node
workflow.add_node("supervisor", supervisor_agent)

# Add the execution step nodes
workflow.add_node("Controller", controller_execute_step)
workflow.add_node("Robot_selector", robot_selector_execute_step)
workflow.add_node("misc_agent", misc_execute_step)

# Add a replan node
workflow.add_node("replanner", replan_step)

# Define the starting node
workflow.set_entry_point("planner")

# From plan we go to supervisor
workflow.add_edge("planner", "supervisor")

# Supervisor select one of the executor nodes
workflow.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {"Controller": "Controller", "Robot_selector": "Robot_selector", "misc_agent": "misc_agent"}
)

# The executor nodes return to the replanner
workflow.add_edge("Controller", "replanner")
workflow.add_edge("Robot_selector", "replanner")
workflow.add_edge("misc_agent", "replanner")

# If task not completed then replan and go to the supervisor
workflow.add_conditional_edges(
    "replanner",
    # Next, we pass in the function that will determine which node is called next.
    should_end,
    {
        # If `tools`, then we call the tool node.
        True: END,
        False: "supervisor",
    },
)

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable
app = workflow.compile()

# %% [markdown]
# ### Test results

# %%
def task_iteration(file_path):
        task = file_path.readline()
        if not task:
            return False
        return task.strip()

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def process_ReAct_response(name, response):
    output = []

    if name == "planner":
        print(f"{name}:\n  plan:")
        output.append(f"{name}:\n    plan:")
        for step in response["plan"]:
            print(f"    {step}")
            output.append(f"        {step}")
        next_step = response["current_step"]
        print(f"  current step:\n     {next_step}\n---\n")
        output.append(f"    current step:\n       {next_step}\n---\n")

    elif name == "replanner":
        if "plan" in response and response["plan"]:
            print(f"{name}:\n    plan:")
            output.append(f"{name}:\n    plan:")
            for step in response["plan"]:
                print(f"        {step}")
                output.append(f"        {step}")
            next_step = response["current_step"]
            print(f"    current step:\n        {next_step}\n---\n")
            output.append(f"    current step:\n        {next_step}\n---\n")
        elif "response" in response and response["response"]:
            response = response["response"]
            print(f"{name}:\n    response:\n        {response}\n---\n")
            output.append(f"{name}:\n    response:\n        {response}\n---\n")

    elif name == "supervisor":
        print(f"{name}:\n   next agent: {response['next']}\n   reason: {response['reasoning']}\n---\n")
        output.append(f"{name}:\n   next agent: {response['next']}\n   reason: {response['reasoning']}\n---\n")

    else:
        past_steps = response["past_steps"]
        print(f"{name}:\n   past steps: {past_steps}\n---\n")
        output.append(f"{name}:\n   past steps: {past_steps}\n---\n")

    return output

# %% [markdown]
# ## Easy test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Results\Result_matrix\Easy_react_matrix.txt"
clear_txt(file_name)

with open("Results\Tasks\Easy_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 100}
        inputs = {"input": task}
        i = 1
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
            if i == 49:
                # This is to ensure there is a response even though the it fails due recursion limit
                write_txt(file_name, "DNF;DNF;DNF;DNF\n")
                history.extend("DNF")
                break
            i+=1

        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('Results\Raw_output\output_Easy_react.xlsx')
# Out:
# 1. task: Move Robot32 to location (2, 9) and remove the toolkit.
# ---
# planner:
#   plan:
#     Select Robot32 using the select_known_robot_tool and verify it has the gripper tool property to remove the toolkit.
#     Move Robot32 to location (2, 9) using the move_robot tool.
#     Remove the toolkit from location (2, 9) using the grab_or_remove_item tool.
#     Change Robot32 status to idle using the robot_status_change tool.
#   current step:
#      Select Robot32 using the select_known_robot_tool and verify it has the gripper tool property to remove the toolkit.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The task requires verifying if a specific robot (Robot32) has the necessary tool property (gripper) to perform a task (remove the toolkit). The Robot_selector has the select_known_robot_tool which is used to determine if the specified robot is equipped with a tool property capable of solving the objective. Therefore, the Robot_selector is the appropriate worker to act next.
# ---
#
# Robot_selector:
#    past steps: ('Select Robot32 using the select_known_robot_tool and verify it has the gripper tool property to remove the toolkit.', 'Robot32 has been successfully selected and verified to have the gripper tool property to remove the toolkit.')
# ---
#
# replanner:
#     plan:
#         Move Robot32 to location (2, 9) using the move_robot tool.
#         Remove the toolkit from location (2, 9) using the grab_or_remove_item tool.
#         Change Robot32 status to idle using the robot_status_change tool.
#     current step:
#         Move Robot32 to location (2, 9) using the move_robot tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a particular robot (Robot32) to be moved to a specific location (2, 9). The Controller is responsible for controlling the robots, which includes moving them to designated positions using the move_robot tool. Since the robot is already specified, there is no need for the Robot_selector to act. Therefore, the Controller is the correct worker to route the current_step to in order to execute the move_robot command.
# ---
#
# Controller:
#    past steps: ('Move Robot32 to location (2, 9) using the move_robot tool.', 'Robot32 has been successfully moved to the desired position (2, 9).')
# ---
#
# replanner:
#     plan:
#         Remove the toolkit from location (2, 9) using the grab_or_remove_item tool.
#         Change Robot32 status to idle using the robot_status_change tool.
#     current step:
#         Remove the toolkit from location (2, 9) using the grab_or_remove_item tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action (removing an item) and the location of the item. Since the Controller is responsible for actions directly controlling the robots, such as using the 'grab_or_remove_item' tool, the Controller is the appropriate worker to act next to execute this task.
# ---
#
# Controller:
#    past steps: ('Remove the toolkit from location (2, 9) using the grab_or_remove_item tool.', 'The toolkit from location (2, 9) has been successfully removed.')
# ---
#
# replanner:
#     plan:
#         Change Robot32 status to idle using the robot_status_change tool.
#     current step:
#         Change Robot32 status to idle using the robot_status_change tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task requires using the 'robot_status_change' tool to change the status of Robot32 to idle. The Controller is responsible for controlling the robots with a set of tools, which includes the 'robot_status_change' tool.
# ---
#
# Controller:
#    past steps: ('Change Robot32 status to idle using the robot_status_change tool.', "Robot32's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The toolkit has been successfully removed from location (2, 9) by Robot32 equipped with the gripper tool property. Robot32's status has been set to idle, and the task is now complete.
# ---
#
# 2. task: Move Robot6 to location (5, 4) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use select_known_robot_tool with Robot6 and 'mop' to check if the robot is equipped with a tool property capable of cleaning liquid spills.
#     Use move_robot with 'Robot6' and the position (5, 4) to move the robot to the location of the liquid spill.
#     Use grab_or_remove_item with 'Robot6' and 'liquid spill' to clean up the liquid spill.
#     Use robot_status_change with 'Robot6' and 'idle' to set the robot status once the task is complete.
#   current step:
#      Use select_known_robot_tool with Robot6 and 'mop' to check if the robot is equipped with a tool property capable of cleaning liquid spills.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies a certain robot (Robot6) and a required tool property ('mop') to check if the robot can perform a specific task (cleaning liquid spills). The Robot_selector is responsible for verifying if the specified robot is equipped with the necessary tool property to accomplish the task, using the select_known_robot_tool. Therefore, the Robot_selector should act next to carry out this verification.
# ---
#
# Robot_selector:
#    past steps: ("Use select_known_robot_tool with Robot6 and 'mop' to check if the robot is equipped with a tool property capable of cleaning liquid spills.", 'Robot6, equipped with a mop, has been selected to clean liquid spills.')
# ---
#
# replanner:
#     plan:
#         Use move_robot with 'Robot6' and the position (5, 4) to move the robot to the location of the liquid spill.
#         Use grab_or_remove_item with 'Robot6' and 'liquid spill' to clean up the liquid spill.
#         Use robot_status_change with 'Robot6' and 'idle' to set the robot status once the task is complete.
#     current step:
#         Use move_robot with 'Robot6' and the position (5, 4) to move the robot to the location of the liquid spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested to use the 'move_robot' tool with a specified robot 'Robot6' and a given position (5, 4) to move the robot to the location of the liquid spill. Since the 'move_robot' tool is under the Controller's set of tools and the robot is already specified, the Controller is the correct worker to act next to perform the current_step of moving the robot to the desired location.
# ---
#
# Controller:
#    past steps: ("Use move_robot with 'Robot6' and the position (5, 4) to move the robot to the location of the liquid spill.", 'Robot6 has been moved to the position (5, 4).')
# ---
#
# replanner:
#     plan:
#         Use grab_or_remove_item with 'Robot6' and 'liquid spill' to clean up the liquid spill.
#         Use robot_status_change with 'Robot6' and 'idle' to set the robot status once the task is complete.
#     current step:
#         Use grab_or_remove_item with 'Robot6' and 'liquid spill' to clean up the liquid spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the robot ('Robot6') and the action to be taken ('grab_or_remove_item' with 'liquid spill'). Since the robot and the action are clearly defined, the Controller is the appropriate worker to execute the command using the provided tools.
# ---
#
# Controller:
#    past steps: ("Use grab_or_remove_item with 'Robot6' and 'liquid spill' to clean up the liquid spill.", 'Robot6 has successfully handled the liquid spill.')
# ---
#
# replanner:
#     plan:
#         Use robot_status_change with 'Robot6' and 'idle' to set the robot status once the task is complete.
#     current step:
#         Use robot_status_change with 'Robot6' and 'idle' to set the robot status once the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with a set of tools, including the robot_status_change tool. Since the user request specifically mentions using the robot_status_change tool to set the status of 'Robot6' to 'idle' after the task is complete, the Controller is the correct worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Use robot_status_change with 'Robot6' and 'idle' to set the robot status once the task is complete.", "Robot6's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         The task is complete. Robot6 equipped with a mop has successfully cleaned the liquid spill at location (5, 4) and is now set to idle status.
# ---
#
# 3. task: Move Robot29 to location (5, 12) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify if Robot29 is equipped with a tool property capable of solving the objective, such as a front loader, to remove large debris.
#     Use the move_robot function to move Robot29 to the desired position at (5, 12).
#     Use the grab_or_remove_item function to have Robot29 remove the large debris from location (5, 12).
#     Use the robot_status_change function to set Robot29's status to idle after the removal of the large debris is complete.
#   current step:
#      Use the select_known_robot_tool to verify if Robot29 is equipped with a tool property capable of solving the objective, such as a front loader, to remove large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector should be utilized to verify if Robot29 has the necessary tool property, such as a front loader, for the specific objective of removing large debris. The select_known_robot_tool is designed for this purpose when a specific robot is mentioned in the objective.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to verify if Robot29 is equipped with a tool property capable of solving the objective, such as a front loader, to remove large debris.', 'Robot29 is equipped with a front loader and has been selected to remove the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot29 to the desired position at (5, 12).
#         Use the grab_or_remove_item function to have Robot29 remove the large debris from location (5, 12).
#         Use the robot_status_change function to set Robot29's status to idle after the removal of the large debris is complete.
#     current step:
#         Use the move_robot function to move Robot29 to the desired position at (5, 12).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically involves moving a robot, which is a task that falls under the responsibilities of the Controller. The Controller has the tool 'move_robot' which is designed to move the selected robot to a given position. Since the robot name 'Robot29' and the desired position coordinates (5, 12) are provided, the Controller is the correct worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function to move Robot29 to the desired position at (5, 12).', 'Robot29 has been successfully moved to the desired position at (5, 12).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to have Robot29 remove the large debris from location (5, 12).
#         Use the robot_status_change function to set Robot29's status to idle after the removal of the large debris is complete.
#     current step:
#         Use the grab_or_remove_item function to have Robot29 remove the large debris from location (5, 12).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to be taken (grab_or_remove_item) and the robot to execute it (Robot29), so the Controller is the appropriate worker to carry out this task as it has the tools to control the robots and perform the required action.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to have Robot29 remove the large debris from location (5, 12).', 'Robot29 has successfully removed the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function to set Robot29's status to idle after the removal of the large debris is complete.
#     current step:
#         Use the robot_status_change function to set Robot29's status to idle after the removal of the large debris is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, including changing their status. Since the request is to use the robot_status_change function to set Robot29's status to idle after completing a task, the Controller is the appropriate worker to carry out this action.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function to set Robot29's status to idle after the removal of the large debris is complete.", "Robot29's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot29 equipped with a front loader has successfully moved to location (5, 12) and removed the large debris. The robot's status is now set to idle, completing the objective.
# ---
#
# 4. task: Move Robot48 to location (6, 6) and remove the dust.
# ---
# planner:
#   plan:
#     Use the 'select_known_robot_tool' tool with Robot48 and the tool property 'vacuum' to confirm that Robot48 is equipped for dust removal.
#     Use the 'move_robot' tool with Robot48 to move it to location (6, 6).
#     Use the 'grab_or_remove_item' tool with Robot48 to remove the dust at location (6, 6).
#     Use the 'robot_status_change' tool to set Robot48's status to 'idle' after the task is complete.
#   current step:
#      Use the 'select_known_robot_tool' tool with Robot48 and the tool property 'vacuum' to confirm that Robot48 is equipped for dust removal.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies a robot (Robot48) and a desired tool property ('vacuum') necessary for a task (dust removal). As per the definition, the 'select_known_robot_tool' should be used to confirm if the specified robot is equipped with the required tool property. The Robot_selector is responsible for using the 'select_known_robot_tool', hence it should be the next to act.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'select_known_robot_tool' tool with Robot48 and the tool property 'vacuum' to confirm that Robot48 is equipped for dust removal.", "The initial selected tool for Robot48 was 'vacuum' for the task of dust removal. However, Robot48 is not equipped with a vacuum. The alternative tool property Robot48 has is a 'broom'. According to the list of items with associated tool properties, a broom can also be used for dust removal. Therefore, Robot48 can still solve the task using the broom to remove dust.")
# ---
#
# replanner:
#     plan:
#         Use the 'move_robot' tool with Robot48 to move it to location (6, 6).
#         Use the 'grab_or_remove_item' tool with Robot48 to remove the dust at location (6, 6) using the broom.
#         Use the 'robot_status_change' tool to set Robot48's status to 'idle' after the task is complete.
#     current step:
#         Use the 'move_robot' tool with Robot48 to move it to location (6, 6).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specifically requested to use the 'move_robot' tool with Robot48 to move it to a particular location (6, 6). The Controller is responsible for controlling the robots with a set of tools which includes 'move_robot'. Therefore, the Controller is the appropriate worker to act next to carry out this task.
# ---
#
# Controller:
#    past steps: ("Use the 'move_robot' tool with Robot48 to move it to location (6, 6).", 'Robot48 has been successfully moved to position (6, 6).')
# ---
#
# replanner:
#     plan:
#         Use the 'grab_or_remove_item' tool with Robot48 to remove the dust at location (6, 6) using the broom.
#         Use the 'robot_status_change' tool to set Robot48's status to 'idle' after the task is complete.
#     current step:
#         Use the 'grab_or_remove_item' tool with Robot48 to remove the dust at location (6, 6) using the broom.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving a particular robot, Robot48, to remove an item, which is dust in this case, at a specific location using a tool, which is a broom. Since the robot is already specified, there is no need for the Robot_selector. The Controller is responsible for controlling robots to perform actions such as 'grab_or_remove_item' which matches the user request. Therefore, the Controller should act next to execute the 'grab_or_remove_item' tool with Robot48.
# ---
#
# Controller:
#    past steps: ("Use the 'grab_or_remove_item' tool with Robot48 to remove the dust at location (6, 6) using the broom.", 'Robot48 has successfully removed the dust at location (6, 6) using the broom.')
# ---
#
# replanner:
#     plan:
#         Use the 'robot_status_change' tool to set Robot48's status to 'idle' after the task is complete.
#     current step:
#         Use the 'robot_status_change' tool to set Robot48's status to 'idle' after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The 'robot_status_change' tool is within the Controller's set of tools, and the user request is to use this specific tool to change Robot48's status to 'idle' after the task is complete. Therefore, the Controller is the correct worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the 'robot_status_change' tool to set Robot48's status to 'idle' after the task is complete.", "Robot48's status has been updated to 'idle' after completing the task.")
# ---
#
# replanner:
#     response:
#         Robot48 was successfully moved to location (6, 6) and has removed the dust using its broom. The robot's status is now set to idle, and the task is complete.
# ---
#
# 5. task: Move Robot41 to location (1, 8) and remove the grass.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with 'Robot41' as robot_name and 'lawnmower' as desired_robot_tool_property to ensure Robot41 is equipped to remove grass.
#     Use the move_robot tool with 'Robot41' as robot_name and (1, 8) as the desired_position to move Robot41 to the correct location.
#     Use the grab_or_remove_item tool with 'Robot41' as robot_name and 'grass' as the item_name to remove the grass at location (1, 8).
#     Use the robot_status_change tool with 'Robot41' as robot_name and 'idle' as status to set Robot41's status after completing the task.
#   current step:
#      Use the select_known_robot_tool with 'Robot41' as robot_name and 'lawnmower' as desired_robot_tool_property to ensure Robot41 is equipped to remove grass.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to use the 'select_known_robot_tool' to confirm if 'Robot41' has the 'lawnmower' tool property necessary for removing grass. The Robot_selector is responsible for determining if a specified robot is equipped with the desired tool property to complete a task.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with 'Robot41' as robot_name and 'lawnmower' as desired_robot_tool_property to ensure Robot41 is equipped to remove grass.", 'Robot41, equipped with a lawnmower, has been selected to remove the grass.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool with 'Robot41' as robot_name and (1, 8) as the desired_position to move Robot41 to the correct location.
#         Use the grab_or_remove_item tool with 'Robot41' as robot_name and 'grass' as the item_name to remove the grass at location (1, 8).
#         Use the robot_status_change tool with 'Robot41' as robot_name and 'idle' as status to set Robot41's status after completing the task.
#     current step:
#         Use the move_robot tool with 'Robot41' as robot_name and (1, 8) as the desired_position to move Robot41 to the correct location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically asks to use the 'move_robot' tool with 'Robot41' as the robot_name and coordinates (1, 8) as the desired_position. The 'Controller' is responsible for controlling the robots and has access to the 'move_robot' tool which can move a selected robot to a given position.
# ---
#
# Controller:
#    past steps: ("Use the move_robot tool with 'Robot41' as robot_name and (1, 8) as the desired_position to move Robot41 to the correct location.", 'Robot41 has been successfully moved to the position (1, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with 'Robot41' as robot_name and 'grass' as the item_name to remove the grass at location (1, 8).
#         Use the robot_status_change tool with 'Robot41' as robot_name and 'idle' as status to set Robot41's status after completing the task.
#     current step:
#         Use the grab_or_remove_item tool with 'Robot41' as robot_name and 'grass' as the item_name to remove the grass at location (1, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots using specific tools. Since the user request involves using the 'grab_or_remove_item' tool with a specified robot name ('Robot41') and an item name ('grass'), the Controller is the correct worker to perform this action as it falls within their set of tools. There is no need for the Robot_selector as the robot is already specified, and the request is not a generic question that would require the misc_agent.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item tool with 'Robot41' as robot_name and 'grass' as the item_name to remove the grass at location (1, 8).", 'Robot41 has grabbed/removed the grass and has been moved to the location (1, 8).')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool with 'Robot41' as robot_name and 'idle' as status to set Robot41's status after completing the task.
#     current step:
#         Use the robot_status_change tool with 'Robot41' as robot_name and 'idle' as status to set Robot41's status after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, which includes using the robot_status_change tool to set a robot's status. Since the task is to set Robot41's status to 'idle' after completing its task, the Controller is the appropriate worker to perform this action.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool with 'Robot41' as robot_name and 'idle' as status to set Robot41's status after completing the task.", "Robot41's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot41, equipped with a lawnmower, has moved to location (1, 8) and removed the grass. The robot's status is now set to idle.
# ---
#
# 6. task: Move Robot10 to location (9, 5) and remove the small debris.
# ---
# planner:
#   plan:
#     Select Robot10 using the select_known_robot_tool and verify it has a gripper tool property capable of removing small debris.
#     Move Robot10 to location (9, 5) using the move_robot tool.
#     Remove the small debris using the grab_or_remove_item tool with Robot10.
#     Change Robot10's status to idle using the robot_status_change tool.
#   current step:
#      Select Robot10 using the select_known_robot_tool and verify it has a gripper tool property capable of removing small debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies a particular robot (Robot10) and requires verification of its capability (having a gripper tool property capable of removing small debris). The Robot_selector is the appropriate worker to use the select_known_robot_tool to determine if Robot10 is equipped with the necessary tool property to fulfill the objective.
# ---
#
# Robot_selector:
#    past steps: ('Select Robot10 using the select_known_robot_tool and verify it has a gripper tool property capable of removing small debris.', 'The initial selected tool for Robot10 was a gripper, which is suited for removing small debris. However, Robot10 is equipped with a vacuum tool property. According to the list of items with associated tool properties, a vacuum can also be used for small debris. Therefore, Robot10 with the vacuum tool property can still solve the task of removing small debris.')
# ---
#
# replanner:
#     plan:
#         Move Robot10 to location (9, 5) using the move_robot tool.
#         Remove the small debris using the grab_or_remove_item tool with Robot10.
#         Change Robot10's status to idle using the robot_status_change tool.
#     current step:
#         Move Robot10 to location (9, 5) using the move_robot tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of moving a specific robot, named Robot10, to a designated location (9, 5). The Controller is responsible for controlling the robots and has the tool 'move_robot' which is used to move a selected robot to a given position. Since the robot's name and the desired position are provided, the Controller is the appropriate worker to carry out this task using the 'move_robot' tool.
# ---
#
# Controller:
#    past steps: ('Move Robot10 to location (9, 5) using the move_robot tool.', 'Robot10 has been successfully moved to the desired position (9, 5).')
# ---
#
# replanner:
#     plan:
#         Remove the small debris using the grab_or_remove_item tool with Robot10.
#         Change Robot10's status to idle using the robot_status_change tool.
#     current step:
#         Remove the small debris using the grab_or_remove_item tool with Robot10.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies both the action to be performed (remove small debris) and the robot to do it (Robot10). Since the Controller is responsible for controlling the robots and the specified tool to use is 'grab_or_remove_item', which is one of the Controller's tools, the Controller is the correct worker to route the current_step to in order to execute the task.
# ---
#
# Controller:
#    past steps: ('Remove the small debris using the grab_or_remove_item tool with Robot10.', 'Robot10 has successfully grabbed/removed the small debris.')
# ---
#
# replanner:
#     plan:
#         Change Robot10's status to idle using the robot_status_change tool.
#     current step:
#         Change Robot10's status to idle using the robot_status_change tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, which includes changing their status using the robot_status_change tool. The current request is to change Robot10's status to idle, which falls under the Controller's set of tools.
# ---
#
# Controller:
#    past steps: ("Change Robot10's status to idle using the robot_status_change tool.", "Robot10's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot10, equipped with a vacuum tool property, has moved to location (9, 5) and removed the small debris. Robot10's status is now set to idle.
# ---
#
# 7. task: Move Robot13 to location (10, 10) and remove the vehicle.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot13 and the 'tow hook' tool property to ensure Robot13 is equipped to remove the vehicle.
#     Move Robot13 to location (10, 10) using the move_robot tool with the parameters 'Robot13' as the robot_name and '(10, 10)' as the desired_position.
#     Remove the vehicle using the grab_or_remove_item tool with the parameters 'Robot13' as the robot_name and 'vehicle' as the item_name.
#     Change Robot13's status to idle using the robot_status_change tool with the parameters 'Robot13' as the robot_name and 'idle' as the status.
#   current step:
#      Use the select_known_robot_tool with Robot13 and the 'tow hook' tool property to ensure Robot13 is equipped to remove the vehicle.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies that Robot13 should be checked for a specific tool property ('tow hook') to remove the vehicle. The Robot_selector is the worker equipped with the select_known_robot_tool that can be used to confirm if Robot13 has the necessary tool property to accomplish the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot13 and the 'tow hook' tool property to ensure Robot13 is equipped to remove the vehicle.", 'Robot13, equipped with a tow hook, has been selected to remove the vehicle.')
# ---
#
# replanner:
#     plan:
#         Move Robot13 to location (10, 10) using the move_robot tool with the parameters 'Robot13' as the robot_name and '(10, 10)' as the desired_position.
#         Remove the vehicle using the grab_or_remove_item tool with the parameters 'Robot13' as the robot_name and 'vehicle' as the item_name.
#         Change Robot13's status to idle using the robot_status_change tool with the parameters 'Robot13' as the robot_name and 'idle' as the status.
#     current step:
#         Move Robot13 to location (10, 10) using the move_robot tool with the parameters 'Robot13' as the robot_name and '(10, 10)' as the desired_position.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to move a specified robot (Robot13) to a specific location (10, 10). The Controller is responsible for controlling the robots with a set of tools, including the 'move_robot' tool which is used to move a selected robot to a given position. Since the robot name and the desired position are provided, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ("Move Robot13 to location (10, 10) using the move_robot tool with the parameters 'Robot13' as the robot_name and '(10, 10)' as the desired_position.", 'Robot13 has been successfully moved to the location (10, 10).')
# ---
#
# replanner:
#     plan:
#         Remove the vehicle using the grab_or_remove_item tool with the parameters 'Robot13' as the robot_name and 'vehicle' as the item_name.
#         Change Robot13's status to idle using the robot_status_change tool with the parameters 'Robot13' as the robot_name and 'idle' as the status.
#     current step:
#         Remove the vehicle using the grab_or_remove_item tool with the parameters 'Robot13' as the robot_name and 'vehicle' as the item_name.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of 'grab_or_remove_item' tool with 'Robot13' as the robot_name and 'vehicle' as the item_name. Since the Controller is responsible for controlling the robots with a set of tools which includes 'grab_or_remove_item', the Controller is the appropriate worker to perform the current_step of removing the vehicle using the specified robot.
# ---
#
# Controller:
#    past steps: ("Remove the vehicle using the grab_or_remove_item tool with the parameters 'Robot13' as the robot_name and 'vehicle' as the item_name.", 'The vehicle has been successfully grabbed/removed by Robot13.')
# ---
#
# replanner:
#     plan:
#         Change Robot13's status to idle using the robot_status_change tool with the parameters 'Robot13' as the robot_name and 'idle' as the status.
#     current step:
#         Change Robot13's status to idle using the robot_status_change tool with the parameters 'Robot13' as the robot_name and 'idle' as the status.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, including changing their status with the robot_status_change tool. Since the task is to change Robot13's status to idle, the Controller is the appropriate worker to perform this action.
# ---
#
# Controller:
#    past steps: ("Change Robot13's status to idle using the robot_status_change tool with the parameters 'Robot13' as the robot_name and 'idle' as the status.", "Robot13's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         The vehicle has been successfully removed from location (10, 10) and Robot13 is now set to idle status.
# ---
#
# 8. task: Move Robot23 to location (8, 2) and remove the construction materials.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify that Robot23 is equipped with a 'front loader' tool property, as this is suitable for removing construction materials.
#     Use the move_robot function to move Robot23 to location (8, 2).
#     Use the grab_or_remove_item function to remove the construction materials from location (8, 2).
#     Use the robot_status_change function to set Robot23's status to 'idle' after the removal of the construction materials is complete.
#   current step:
#      Use the select_known_robot_tool to verify that Robot23 is equipped with a 'front loader' tool property, as this is suitable for removing construction materials.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for selecting the correct robot and verifying its equipment. The user has requested to use the 'select_known_robot_tool' to verify that Robot23 is equipped with a 'front loader' tool property, which falls under the Robot_selector's responsibilities.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool to verify that Robot23 is equipped with a 'front loader' tool property, as this is suitable for removing construction materials.", "The initial selected tool for Robot23 was a 'front loader,' which is appropriate for removing construction materials. However, Robot23 is not equipped with a 'front loader' but with a 'tow hook.' According to the list of items with associated tool properties, a 'tow hook' is also suitable for handling construction materials. Therefore, Robot23 with a 'tow hook' can still solve the task of removing construction materials.")
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot23 to location (8, 2).
#         Use the grab_or_remove_item function to remove the construction materials from location (8, 2).
#         Use the robot_status_change function to set Robot23's status to 'idle' after the removal of the construction materials is complete.
#     current step:
#         Use the move_robot function to move Robot23 to location (8, 2).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to use the move_robot function to move a specific robot, Robot23, to a specified location, which is (8, 2). The Controller is responsible for controlling the robots with a set of tools that include the move_robot function. Therefore, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function to move Robot23 to location (8, 2).', 'Robot23 has been moved to the location (8, 2).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to remove the construction materials from location (8, 2).
#         Use the robot_status_change function to set Robot23's status to 'idle' after the removal of the construction materials is complete.
#     current step:
#         Use the grab_or_remove_item function to remove the construction materials from location (8, 2).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically asks to use the 'grab_or_remove_item' function to remove construction materials from a certain location. This function is within the Controller's set of tools, which makes the Controller the correct worker to act next and perform the current_step.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to remove the construction materials from location (8, 2).', 'The construction materials have been removed from location (8, 2).')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function to set Robot23's status to 'idle' after the removal of the construction materials is complete.
#     current step:
#         Use the robot_status_change function to set Robot23's status to 'idle' after the removal of the construction materials is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The request is to use the 'robot_status_change' function to set the status of a specific robot (Robot23) to 'idle'. This function is within the Controller's set of tools, and the Controller is responsible for controlling the robots, including changing their status.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function to set Robot23's status to 'idle' after the removal of the construction materials is complete.", "Robot23's status has been set to 'idle' after the completion of the construction materials removal task.")
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot23, equipped with a tow hook, has removed the construction materials from location (8, 2) and is now set to 'idle' status.
# ---
#
# 9. task: Move Robot24 to location (11, 8) and remove the tree branches.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot24 and the 'saw' tool property to verify if Robot24 is equipped to remove tree branches.
#     If Robot24 is not equipped with a 'saw', select a different robot using robot_selection_tool with the 'saw' tool property and the item position (11, 8).
#     Use the move_robot function with the appropriate robot name and the desired position (11, 8).
#     Use the grab_or_remove_item function with the robot name and 'tree branches' as the item name to remove the tree branches.
#     Set the robot's status to idle using the robot_status_change function with the robot name and 'idle' status.
#   current step:
#      Use the select_known_robot_tool with Robot24 and the 'saw' tool property to verify if Robot24 is equipped to remove tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector should act next because the user has specified a particular robot, Robot24, and requires a check for a specific tool property, 'saw'. The select_known_robot_tool is designed to determine if the specified robot has the required tool property to complete the task, which in this case is removing tree branches.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot24 and the 'saw' tool property to verify if Robot24 is equipped to remove tree branches.", 'Robot24 is equipped with a saw and has been selected to remove the tree branches.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot24 and the desired position (11, 8).
#         Use the grab_or_remove_item function with Robot24 and 'tree branches' as the item name to remove the tree branches.
#         Set Robot24's status to idle using the robot_status_change function with Robot24 and 'idle' status.
#     current step:
#         Use the move_robot function with Robot24 and the desired position (11, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user's request is to use the 'move_robot' function to move a specific robot, Robot24, to a desired position (11, 8). This is a direct instruction involving the control of a robot's movement, which falls under the responsibilities of the Controller. The Controller has the 'move_robot' tool needed to execute this task.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot24 and the desired position (11, 8).', 'Robot24 has been successfully moved to the position (11, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot24 and 'tree branches' as the item name to remove the tree branches.
#         Set Robot24's status to idle using the robot_status_change function with Robot24 and 'idle' status.
#     current step:
#         Use the grab_or_remove_item function with Robot24 and 'tree branches' as the item name to remove the tree branches.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specifically requested the use of the 'grab_or_remove_item' function with 'Robot24' and 'tree branches' as the item name. The Controller is responsible for controlling the robots with a set of tools that includes 'grab_or_remove_item'. Since the robot name and item name are provided, the Controller is the appropriate worker to execute the function and remove the tree branches.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot24 and 'tree branches' as the item name to remove the tree branches.", 'Robot24 has successfully grabbed/removed the tree branches.')
# ---
#
# replanner:
#     plan:
#         Set Robot24's status to idle using the robot_status_change function with Robot24 and 'idle' status.
#     current step:
#         Set Robot24's status to idle using the robot_status_change function with Robot24 and 'idle' status.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for using the 'robot_status_change' function to alter the status of a robot. Since the user request specifically asks to set Robot24's status to 'idle', the Controller is the appropriate worker to execute this function.
# ---
#
# Controller:
#    past steps: ("Set Robot24's status to idle using the robot_status_change function with Robot24 and 'idle' status.", "Robot24's status has been set to idle.")
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot24, equipped with a saw, has removed the tree branches at location (11, 8). The robot's status is now set to idle.
# ---
#
# 10. task: Move Robot15 to location (3, 8) and remove the screws.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot15 and screwdriver to ensure Robot15 is equipped with a tool capable of removing screws.
#     Use the move_robot function with Robot15 and the coordinates (3, 8) to move Robot15 to the desired location.
#     Use the grab_or_remove_item function with Robot15 and the item name 'screws' to remove the screws from the location.
#     Use the robot_status_change function with Robot15 and set the status to 'idle' after the task is completed.
#   current step:
#      Use the select_known_robot_tool with Robot15 and screwdriver to ensure Robot15 is equipped with a tool capable of removing screws.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the use of the select_known_robot_tool to check if Robot15 is equipped with a screwdriver. The Robot_selector is responsible for using the select_known_robot_tool, hence it should act next.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool with Robot15 and screwdriver to ensure Robot15 is equipped with a tool capable of removing screws.', 'Robot15, equipped with a screwdriver, has been selected to remove screws.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot15 and the coordinates (3, 8) to move Robot15 to the desired location.
#         Use the grab_or_remove_item function with Robot15 and the item name 'screws' to remove the screws from the location.
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the task is completed.
#     current step:
#         Use the move_robot function with Robot15 and the coordinates (3, 8) to move Robot15 to the desired location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving the movement of a robot (Robot15) to a specific position (coordinates 3, 8). The 'move_robot' function falls under the Controller's tools, thus the Controller is the appropriate worker to perform the current step.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot15 and the coordinates (3, 8) to move Robot15 to the desired location.', 'Robot15 has been successfully moved to the desired position at coordinates (3, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot15 and the item name 'screws' to remove the screws from the location.
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the task is completed.
#     current step:
#         Use the grab_or_remove_item function with Robot15 and the item name 'screws' to remove the screws from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action 'grab_or_remove_item' which is a function controlled by the Controller. The robot name 'Robot15' and the item name 'screws' are provided, so the Controller can directly use the 'grab_or_remove_item' tool to remove the screws from the location where Robot15 is currently positioned.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot15 and the item name 'screws' to remove the screws from the location.", 'Robot15 has successfully grabbed or removed the screws from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the task is completed.
#     current step:
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the task is completed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'robot_status_change' function to set the status of Robot15 to 'idle' after the task is completed. The 'Controller' is responsible for controlling the robots with a set of tools, which includes the 'robot_status_change' function. Therefore, the Controller is the appropriate worker to carry out this function as per the user's request.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot15 and set the status to 'idle' after the task is completed.", "The status of Robot15 has been successfully changed to 'idle'.")
# ---
#
# replanner:
#     response:
#         Robot15, equipped with a screwdriver, has successfully moved to location (3, 8) and removed the screws. The robot's status has been set to 'idle' after the completion of the task.
# ---

# %% [markdown]
# ## Medium test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Results\Result_matrix\Medium_react_matrix.txt"
clear_txt(file_name)

with open("Results\Tasks\Medium_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 100}
        inputs = {"input": task}
        i = 1
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
            if i == 50:
                # This is to ensure there is a response even though the it fails due recursion limit
                write_txt(file_name, "DNF;DNF;DNF;DNF\n")
                history.extend("DNF")
                break
            i+=1
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('Results\Raw_output\output_Medium_react.xlsx')
# Out:
# 1. task: Move to location (9, 5) and remove the toolkit.
# ---
# planner:
#   plan:
#     Select a robot equipped with a gripper tool property using the robot_selection_tool with 'gripper' as the desired_robot_tool_property and (9, 5) as the item_position.
#     Move the selected robot to location (9, 5) using the move_robot function with the robot's name and the desired_position (9, 5).
#     Grab or remove the toolkit at location (9, 5) using the grab_or_remove_item function with the robot's name and 'toolkit' as the item_name.
#     Change the robot's status to 'idle' using the robot_status_change function with the robot's name and 'idle' as the status.
#   current step:
#      Select a robot equipped with a gripper tool property using the robot_selection_tool with 'gripper' as the desired_robot_tool_property and (9, 5) as the item_position.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for selecting the correct robot for a task when no specific robot is mentioned in the objective. Since the user request involves selecting a robot with a 'gripper' tool property and an item position is provided, the Robot_selector should use the robot_selection_tool to determine the best suited robot for the task.
# ---
#
# Robot_selector:
#    past steps: ("Select a robot equipped with a gripper tool property using the robot_selection_tool with 'gripper' as the desired_robot_tool_property and (9, 5) as the item_position.", 'Robot42 is the best suited to solve the task with its gripper tool property, located at position (9, 5).')
# ---
#
# replanner:
#     plan:
#         Move Robot42 to location (9, 5) using the move_robot function with 'Robot42' as the robot name and the desired_position (9, 5).
#         Grab or remove the toolkit at location (9, 5) using the grab_or_remove_item function with 'Robot42' as the robot name and 'toolkit' as the item_name.
#         Change Robot42's status to 'idle' using the robot_status_change function with 'Robot42' as the robot name and 'idle' as the status.
#     current step:
#         Move Robot42 to location (9, 5) using the move_robot function with 'Robot42' as the robot name and the desired_position (9, 5).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to move a specific robot, Robot42, to a certain location (9, 5). As the Controller is responsible for controlling the robots and has the 'move_robot' tool, which is required for this task, the Controller should act next to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Move Robot42 to location (9, 5) using the move_robot function with 'Robot42' as the robot name and the desired_position (9, 5).", 'Robot42 has been successfully moved to the position (9, 5).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with 'Robot42' as the robot name and 'toolkit' as the item_name to remove the toolkit at location (9, 5).
#         Change Robot42's status to 'idle' using the robot_status_change function with 'Robot42' as the robot name and 'idle' as the status.
#     current step:
#         Use the grab_or_remove_item function with 'Robot42' as the robot name and 'toolkit' as the item_name to remove the toolkit at location (9, 5).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of 'grab_or_remove_item' function with 'Robot42' and 'toolkit' specified, which is a task directly under the Controller's responsibilities. The Controller has the tools necessary to execute this action.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with 'Robot42' as the robot name and 'toolkit' as the item_name to remove the toolkit at location (9, 5).", 'The toolkit at location (9, 5) has been successfully removed by Robot42.')
# ---
#
# replanner:
#     plan:
#         Change Robot42's status to 'idle' using the robot_status_change function with 'Robot42' as the robot name and 'idle' as the status.
#     current step:
#         Change Robot42's status to 'idle' using the robot_status_change function with 'Robot42' as the robot name and 'idle' as the status.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically asks for changing a robot's status to 'idle', which falls under the responsibilities of the Controller. The Controller has the required tool 'robot_status_change' to perform this action on Robot42.
# ---
#
# Controller:
#    past steps: ("Change Robot42's status to 'idle' using the robot_status_change function with 'Robot42' as the robot name and 'idle' as the status.", "Robot42's status has been changed to 'idle'.")
# ---
#
# replanner:
#     response:
#         The toolkit at location (9, 5) has been successfully removed by Robot42, and Robot42's status has been changed to 'idle'. The task is complete.
# ---
#
# 2. task: Move to location (3, 8) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use robot_selection_tool with the tool property 'mop' or 'vacuum' to determine the best suited robot to clean the liquid spill at location (3, 8).
#     Move the selected robot to location (3, 8) using move_robot.
#     Remove the liquid spill by using grab_or_remove_item with the selected robot.
#     Change the robot's status to 'idle' using robot_status_change after the liquid spill is removed.
#   current step:
#      Use robot_selection_tool with the tool property 'mop' or 'vacuum' to determine the best suited robot to clean the liquid spill at location (3, 8).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves selecting the best suited robot to clean a liquid spill using specific tool properties ('mop' or 'vacuum'). The Robot_selector is responsible for determining the most appropriate robot when no specific robot is mentioned in the objective. The robot_selection_tool should be used for this purpose as it selects a robot based on the desired robot tool property and the item position, which in this case relates to the cleaning task at a specific location.
# ---
#
# Robot_selector:
#    past steps: ("Use robot_selection_tool with the tool property 'mop' or 'vacuum' to determine the best suited robot to clean the liquid spill at location (3, 8).", 'Robot6 is the best suited to clean the liquid spill at location (3, 8) using its mop tool property.')
# ---
#
# replanner:
#     plan:
#         Move Robot6 to location (3, 8) using move_robot.
#         Remove the liquid spill by using grab_or_remove_item with Robot6.
#         Change Robot6's status to 'idle' using robot_status_change after the liquid spill is removed.
#     current step:
#         Move Robot6 to location (3, 8) using move_robot.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to move a specific robot, Robot6, to a specific location (3, 8). The Controller is responsible for controlling the robots with a set of tools, including the 'move_robot' tool which is specifically used to move a selected robot to a given position. Since the robot name and desired position are both provided, the Controller is the appropriate worker to carry out this action without the need for robot selection or further assistance from the misc_agent.
# ---
#
# Controller:
#    past steps: ('Move Robot6 to location (3, 8) using move_robot.', 'Robot6 has been moved to the desired position (3, 8).')
# ---
#
# replanner:
#     plan:
#         Remove the liquid spill by using grab_or_remove_item with Robot6.
#         Change Robot6's status to 'idle' using robot_status_change after the liquid spill is removed.
#     current step:
#         Remove the liquid spill by using grab_or_remove_item with Robot6.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action 'grab_or_remove_item' and the robot to use, 'Robot6'. Since the Controller is responsible for controlling the robots and executing actions such as 'grab_or_remove_item', it is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ('Remove the liquid spill by using grab_or_remove_item with Robot6.', 'The liquid spill has been successfully handled by Robot6.')
# ---
#
# replanner:
#     plan:
#         Change Robot6's status to 'idle' using robot_status_change after the liquid spill is removed.
#     current step:
#         Change Robot6's status to 'idle' using robot_status_change after the liquid spill is removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots and has the tool 'robot_status_change' which is needed to change Robot6's status to 'idle' after the completion of a task, such as removing a liquid spill. Since the specific task of changing the robot's status has been mentioned, the Controller is the correct worker to act next.
# ---
#
# Controller:
#    past steps: ("Change Robot6's status to 'idle' using robot_status_change after the liquid spill is removed.", "Robot6 has removed the liquid spill and its status is now set to 'idle'.")
# ---
#
# replanner:
#     response:
#         The liquid spill at location (3, 8) has been successfully cleaned by Robot6, and the robot's status is now set to 'idle'. No further actions are required.
# ---
#
# 3. task: Move to location (1, 4) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool to select the best suited robot based on the 'front loader' or 'gripper' tool property and proximity to location (1, 4).
#     Move the selected robot to location (1, 4) using the move_robot function.
#     Use the grab_or_remove_item function to have the robot remove the large debris at location (1, 4).
#     Change the robot's status to idle using the robot_status_change function after the removal of the large debris is complete.
#   current step:
#      Use the robot_selection_tool to select the best suited robot based on the 'front loader' or 'gripper' tool property and proximity to location (1, 4).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to select the best suited robot based on certain tool properties ('front loader' or 'gripper') and proximity to a location. The Robot_selector is responsible for selecting the correct robot using the robot_selection_tool, which is designed for determining the best suited robot based on tool properties and other criteria such as location. Therefore, the Robot_selector should use the robot_selection_tool to fulfill this request.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool to select the best suited robot based on the 'front loader' or 'gripper' tool property and proximity to location (1, 4).", "The best suited robots for the task based on the desired tool properties and proximity to location (1, 4) are:\n\n- Robot39 with the 'front loader' tool property.\n- Robot2 with the 'gripper' tool property.")
# ---
#
# replanner:
#     plan:
#         Move Robot39 or Robot2 to location (1, 4) using the move_robot function.
#         Use the grab_or_remove_item function to have the robot remove the large debris at location (1, 4).
#         Change the robot's status to idle using the robot_status_change function after the removal of the large debris is complete.
#     current step:
#         Move Robot39 or Robot2 to location (1, 4) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a clear action involving the movement of a robot to a specific location. Since the Controller is responsible for controlling the robots with tools that include the 'move_robot' function, it is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Move Robot39 or Robot2 to location (1, 4) using the move_robot function.', 'Robot39 has been moved to the desired position (1, 4).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to have Robot39 remove the large debris at location (1, 4).
#         Change Robot39's status to idle using the robot_status_change function after the removal of the large debris is complete.
#     current step:
#         Use the grab_or_remove_item function to have Robot39 remove the large debris at location (1, 4).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions using the 'grab_or_remove_item' function to have Robot39 remove the large debris at a given location. This function is within the set of tools controlled by the Controller. Since the specific robot (Robot39) and the action (remove the large debris) are already identified, there is no need for robot selection or miscellaneous actions at this point.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to have Robot39 remove the large debris at location (1, 4).', 'Robot39 has successfully grabbed or removed the large debris.')
# ---
#
# replanner:
#     plan:
#         Change Robot39's status to idle using the robot_status_change function after the removal of the large debris is complete.
#     current step:
#         Change Robot39's status to idle using the robot_status_change function after the removal of the large debris is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving a specific robot (Robot39) and the use of the 'robot_status_change' function to change its status to idle after completing a task. The Controller is responsible for controlling the robots with tools that include 'robot_status_change', and since the specific robot and action are clearly identified, there is no need to select or identify a robot, which means the Robot_selector's role is not required at this step. The misc_agent is also not needed as the request doesn't involve answering generic questions.
# ---
#
# Controller:
#    past steps: ("Change Robot39's status to idle using the robot_status_change function after the removal of the large debris is complete.", "Robot39's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot39 equipped with a front loader has moved to location (1, 4) and removed the large debris. The robot's status has been set to idle.
# ---
#
# 4. task: Move to location (6, 5) and remove the dust.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool to determine the best suited robot with a cleaning tool property to move to location (6, 5).
#     Move the selected robot to location (6, 5) using the move_robot function.
#     Grab or remove the dust at location (6, 5) using grab_or_remove_item function with the selected robot.
#     Set the robot's status to idle using robot_status_change function after the dust has been removed.
#   current step:
#      Use the robot_selection_tool to determine the best suited robot with a cleaning tool property to move to location (6, 5).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The task requires selecting the best suited robot with a specific tool property, in this case a cleaning tool, to move to a specified location. The Robot_selector is responsible for this task using the robot_selection_tool, which is designed to select the best robot for the job when no specific robot is mentioned in the objective.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to determine the best suited robot with a cleaning tool property to move to location (6, 5).', 'There is no robot available with a specific "cleaning" tool property to move to location (6, 5). However, I can select a robot based on more specific cleaning needs such as vacuuming dust, mopping liquid spills, or sweeping small debris. Please provide more details about the type of cleaning required for an accurate robot selection.')
# ---
#
# replanner:
#     plan:
#         Specify the cleaning requirement as removing dust with a vacuum to the robot_selection_tool.
#         Move the selected robot with vacuuming capabilities to location (6, 5) using the move_robot function.
#         Remove the dust at location (6, 5) using the grab_or_remove_item function with the selected robot.
#         Set the robot's status to idle using the robot_status_change function after the dust has been removed.
#     current step:
#         Specify the cleaning requirement as removing dust with a vacuum to the robot_selection_tool.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves finding a robot equipped with the appropriate tool (a vacuum) for a specific task (removing dust). This falls under the responsibility of the Robot_selector, who will use the robot_selection_tool to determine the best suited robot for the objective.
# ---
#
# Robot_selector:
#    past steps: ('Specify the cleaning requirement as removing dust with a vacuum to the robot_selection_tool.', 'Robot40 is the best suited to solve the task of removing dust with a vacuum.')
# ---
#
# replanner:
#     plan:
#         Move Robot40 with vacuuming capabilities to location (6, 5) using the move_robot function.
#         Remove the dust at location (6, 5) using the grab_or_remove_item function with Robot40.
#         Set Robot40's status to idle using the robot_status_change function after the dust has been removed.
#     current step:
#         Move Robot40 with vacuuming capabilities to location (6, 5) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a particular robot ('Robot40') with a desired capability ('vacuuming capabilities') and a specific task ('move to location (6, 5)'). The Controller is responsible for controlling the robots with tools including the 'move_robot' function that is requested to be used. Since the robot has been specified and its task is to move to a certain location, the Controller is the appropriate worker to execute this task.
# ---
#
# Controller:
#    past steps: ('Move Robot40 with vacuuming capabilities to location (6, 5) using the move_robot function.', 'Robot40 with vacuuming capabilities has been moved to the location (6, 5).')
# ---
#
# replanner:
#     plan:
#         Remove the dust at location (6, 5) using the grab_or_remove_item function with Robot40.
#         Set Robot40's status to idle using the robot_status_change function after the dust has been removed.
#     current step:
#         Remove the dust at location (6, 5) using the grab_or_remove_item function with Robot40.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action (remove dust) and the location (6, 5) as well as the robot to be used (Robot40) and the function (grab_or_remove_item). Since all the information needed to perform the task is provided, including the specific robot and function to use, the Controller is the appropriate worker to execute the current_step using the provided tools.
# ---
#
# Controller:
#    past steps: ('Remove the dust at location (6, 5) using the grab_or_remove_item function with Robot40.', 'The dust at location (6, 5) has been removed by Robot40.')
# ---
#
# replanner:
#     plan:
#         Set Robot40's status to idle using the robot_status_change function.
#     current step:
#         Set Robot40's status to idle using the robot_status_change function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: Since the task is to set Robot40's status to idle using the robot_status_change function, the Controller is the appropriate worker for this job. The Controller is responsible for controlling robots and has access to the robot_status_change tool, which is needed to change the status of a robot.
# ---
#
# Controller:
#    past steps: ("Set Robot40's status to idle using the robot_status_change function.", "Robot40's status has been set to idle.")
# ---
#
# replanner:
#     response:
#         The dust at location (6, 5) has been successfully removed by Robot40, which is now set to idle status.
# ---
#
# 5. task: Move to location (9, 5) and remove the grass.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool with the 'lawnmower' tool property and the item_position (9, 5) to select the most suitable robot for grass removal.
#     Use the move_robot function with the robot selected in step 1 to move it to location (9, 5).
#     Use the grab_or_remove_item function with the robot from step 1 to remove the grass at location (9, 5).
#     Use the robot_status_change function with the robot from step 1 to set its status to 'idle' after the grass removal is complete.
#   current step:
#      Use the robot_selection_tool with the 'lawnmower' tool property and the item_position (9, 5) to select the most suitable robot for grass removal.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to use the 'robot_selection_tool' with a specific tool property ('lawnmower') and a given item position (9, 5) to select the most suitable robot for the task of grass removal. The Robot_selector is the appropriate worker for this task as they are responsible for selecting the correct robot based on the required properties and position.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with the 'lawnmower' tool property and the item_position (9, 5) to select the most suitable robot for grass removal.", 'The most suitable robot for grass removal at the position (9, 5) is Robot11, which is equipped with a lawnmower.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot11 to move it to location (9, 5).
#         Use the grab_or_remove_item function with Robot11 to remove the grass at location (9, 5).
#         Use the robot_status_change function with Robot11 to set its status to 'idle' after the grass removal is complete.
#     current step:
#         Use the move_robot function with Robot11 to move it to location (9, 5).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions the use of the 'move_robot' function with 'Robot11' to move it to location (9, 5). The Controller is responsible for controlling the robots and has the tool 'move_robot' to perform this task. Since the robot name and desired position are provided, no robot selection is necessary, and the Controller is the correct worker to act next to execute the move operation.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot11 to move it to location (9, 5).', 'Robot11 has been successfully moved to the location (9, 5).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot11 to remove the grass at location (9, 5).
#         Use the robot_status_change function with Robot11 to set its status to 'idle' after the grass removal is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot11 to remove the grass at location (9, 5).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots' actions, including using tools like grab_or_remove_item. Since the user request specifically mentions the action of removing an item ('grass') at a certain location with a designated robot ('Robot11'), the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function with Robot11 to remove the grass at location (9, 5).', 'Robot11 has successfully removed the grass.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot11 to set its status to 'idle' after the grass removal is complete.
#     current step:
#         Use the robot_status_change function with Robot11 to set its status to 'idle' after the grass removal is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions the use of the 'robot_status_change' function to set Robot11's status to 'idle' after completing a task. Since the Controller is responsible for controlling the robots and has access to the 'robot_status_change' tool, it is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot11 to set its status to 'idle' after the grass removal is complete.", "Robot11's status has been successfully changed to idle after completing the grass removal task.")
# ---
#
# replanner:
#     response:
#         Robot11, equipped with a lawnmower, has successfully removed the grass at location (9, 5) and is now set to idle status.
# ---
#
# 6. task: Move to location (5, 12) and remove the small debris.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool to determine the best-suited robot with the tool property capable of removing small debris, such as a vacuum, broom, or front loader.
#     Move the selected robot to location (5, 12) using the move_robot tool.
#     Remove the small debris at location (5, 12) by using the grab_or_remove_item tool with the selected robot.
#     Change the robot's status to idle using the robot_status_change tool after the objective is complete.
#   current step:
#      Use the robot_selection_tool to determine the best-suited robot with the tool property capable of removing small debris, such as a vacuum, broom, or front loader.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: Since the user request specifies the need to determine the best-suited robot for a task (removing small debris) and no particular robot has been specified, the Robot_selector should be used. The 'robot_selection_tool' is designed to select the appropriate robot based on a desired tool property and the item position, which in this case relates to a tool that can handle small debris removal.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to determine the best-suited robot with the tool property capable of removing small debris, such as a vacuum, broom, or front loader.', 'The best-suited robot for removing small debris using a vacuum is Robot40.')
# ---
#
# replanner:
#     plan:
#         Move Robot40 to location (5, 12) using the move_robot tool.
#         Remove the small debris at location (5, 12) by using the grab_or_remove_item tool with Robot40.
#         Change Robot40's status to idle using the robot_status_change tool after the small debris has been removed.
#     current step:
#         Move Robot40 to location (5, 12) using the move_robot tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to move a particular robot, Robot40, to a specific location (5, 12). The Controller is responsible for controlling the robots with tools including 'move_robot'. Since the robot is specified and the desired action is directly related to controlling the robot's movement, the Controller is the correct worker to carry out this current_step.
# ---
#
# Controller:
#    past steps: ('Move Robot40 to location (5, 12) using the move_robot tool.', 'Robot40 has been successfully moved to the desired position (5, 12).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with Robot40 to remove the small debris at location (5, 12).
#         Change Robot40's status to idle using the robot_status_change tool after the small debris has been removed.
#     current step:
#         Use the grab_or_remove_item tool with Robot40 to remove the small debris at location (5, 12).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action involving a particular robot (Robot40) and a task (remove the small debris at location (5, 12)). The Controller is responsible for controlling the robots with tools like 'grab_or_remove_item', which is exactly the tool needed to perform the task. There is no need to select a robot as it has already been specified, and the task does not involve answering generic questions, so the misc_agent is not needed.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item tool with Robot40 to remove the small debris at location (5, 12).', 'Robot40 has successfully grabbed or removed the small debris.')
# ---
#
# replanner:
#     plan:
#         Change Robot40's status to idle using the robot_status_change tool after the small debris has been removed.
#     current step:
#         Change Robot40's status to idle using the robot_status_change tool after the small debris has been removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request involves using the 'robot_status_change' tool to change Robot40's status to idle after a task is completed. The 'robot_status_change' tool is within the Controller's set of tools, making the Controller the correct worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Change Robot40's status to idle using the robot_status_change tool after the small debris has been removed.", 'Robot40 has removed the small debris and its status is now set to idle.')
# ---
#
# replanner:
#     response:
#         The small debris at location (5, 12) has been successfully removed by Robot40, and its status has been set to idle. The task is now complete.
# ---
#
# 7. task: Move to location (11, 12) and remove the vehicle.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool with the 'tow hook' tool property to determine the best-suited robot for removing a vehicle at location (11, 12).
#     Use the move_robot function to move the selected robot to location (11, 12).
#     Use the grab_or_remove_item function to remove the vehicle from location (11, 12).
#     Use the robot_status_change function to set the robot's status to idle after the removal of the vehicle is complete.
#   current step:
#      Use the robot_selection_tool with the 'tow hook' tool property to determine the best-suited robot for removing a vehicle at location (11, 12).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The request specifies the need to use the robot_selection_tool with the 'tow hook' tool property to determine the best-suited robot for a task. This falls under the responsibilities of the Robot_selector, who is equipped with the tools to select the correct robot based on the desired properties and the location of the item.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with the 'tow hook' tool property to determine the best-suited robot for removing a vehicle at location (11, 12).", 'The best-suited robot to remove a vehicle at location (11, 12) is Robot23, as it is equipped with a tow hook.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot23 to location (11, 12).
#         Use the grab_or_remove_item function to remove the vehicle from location (11, 12) with Robot23.
#         Use the robot_status_change function to set Robot23's status to idle after the removal of the vehicle is complete.
#     current step:
#         Use the move_robot function to move Robot23 to location (11, 12).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested to move a specific robot, Robot23, to a new location. The Controller is responsible for controlling the robots and has the 'move_robot' tool that is needed to fulfill this request. Therefore, the Controller is the appropriate worker to act next to carry out the move_robot function.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function to move Robot23 to location (11, 12).', 'Robot23 has been successfully moved to the location (11, 12).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to have Robot23 remove the vehicle from location (11, 12).
#         Use the robot_status_change function to set Robot23's status to idle after the removal of the vehicle is complete.
#     current step:
#         Use the grab_or_remove_item function to have Robot23 remove the vehicle from location (11, 12).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'grab_or_remove_item' function to have a specific robot, Robot23, remove the vehicle from a specific location. Since the Controller is responsible for controlling the robots with tools that include 'grab_or_remove_item', and the specific robot is already identified, the Controller is the correct worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to have Robot23 remove the vehicle from location (11, 12).', 'The vehicle at location (11, 12) has been removed by Robot23.')
# ---
#
# replanner:
#     plan:
#         Set Robot23's status to idle after the removal of the vehicle is complete.
#     current step:
#         Set Robot23's status to idle after the removal of the vehicle is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: Since the request explicitly mentions Robot23, which implies that the robot is already known, the Controller is responsible for performing actions on specified robots. The task involves setting the robot's status to 'idle', which is one of the functionalities of the Controller's 'robot_status_change' tool. Therefore, the Controller should act next to change Robot23's status to idle after it has completed the removal of the vehicle.
# ---
#
# Controller:
#    past steps: ("Set Robot23's status to idle after the removal of the vehicle is complete.", 'Robot23 has successfully grabbed/removed the vehicle and its status has been changed to idle.')
# ---
#
# replanner:
#     response:
#         The vehicle at location (11, 12) has been successfully removed by Robot23.
# ---
#
# 8. task: Move to location (12, 1) and remove the construction materials.
# ---
# planner:
#   plan:
#     Use robot_selection_tool to determine the best suited robot with the appropriate tool property, such as a front loader, to move to location (12, 1) and remove the construction materials.
#     Move the selected robot to location (12, 1) using the move_robot function.
#     Remove the construction materials from the location using the grab_or_remove_item function.
#     Change the robot's status to idle using the robot_status_change function after the task is complete.
#   current step:
#      Use robot_selection_tool to determine the best suited robot with the appropriate tool property, such as a front loader, to move to location (12, 1) and remove the construction materials.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The request involves selecting the best suited robot with the appropriate tool property, which is a task for the Robot_selector using the robot_selection_tool, as no specific robot has been mentioned in the objective.
# ---
#
# Robot_selector:
#    past steps: ('Use robot_selection_tool to determine the best suited robot with the appropriate tool property, such as a front loader, to move to location (12, 1) and remove the construction materials.', 'The best suited robot to move to location (12, 1) and remove the construction materials with a front loader is Robot29.')
# ---
#
# replanner:
#     plan:
#         Move Robot29 to location (12, 1) using the move_robot function.
#         Remove the construction materials from location (12, 1) using the grab_or_remove_item function.
#         Change Robot29's status to idle using the robot_status_change function after the task is complete.
#     current step:
#         Move Robot29 to location (12, 1) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested a specific action that involves moving a robot (Robot29) to a new position (12, 1). The Controller is responsible for controlling the robots with the tool 'move_robot', which is used to move a selected robot to a given position. Since the robot's name and the desired position are provided, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Move Robot29 to location (12, 1) using the move_robot function.', 'Robot29 has been moved to the desired position (12, 1).')
# ---
#
# replanner:
#     plan:
#         Remove the construction materials from location (12, 1) using the grab_or_remove_item function.
#         Change Robot29's status to idle using the robot_status_change function after the task is complete.
#     current step:
#         Remove the construction materials from location (12, 1) using the grab_or_remove_item function.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: Since the user request specifies an action (remove construction materials) and a location ((12, 1)) but does not specify which robot to use, the Robot_selector should act next. The Robot_selector can use the robot_selection_tool to determine the best suited robot to perform the task of removing construction materials from the specified location.
# ---
#
# Robot_selector:
#    past steps: ('Remove the construction materials from location (12, 1) using the grab_or_remove_item function.', 'Robot32 with a gripper tool has been selected to remove the construction materials from location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot29 to remove the construction materials from location (12, 1).
#         Change Robot29's status to idle using the robot_status_change function after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot29 to remove the construction materials from location (12, 1).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'grab_or_remove_item' function with a particular robot, Robot29, to remove construction materials from a specific location. The Controller is responsible for this action because the 'grab_or_remove_item' is one of the tools under the Controller's responsibility.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function with Robot29 to remove the construction materials from location (12, 1).', 'Robot29 has successfully removed the construction materials from location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Change Robot29's status to idle using the robot_status_change function after the task is complete.
#     current step:
#         Change Robot29's status to idle using the robot_status_change function after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, which includes the capability to change a robot's status using the robot_status_change tool. The user request specifically asks to change Robot29's status to idle, which falls under the Controller's set of tools.
# ---
#
# Controller:
#    past steps: ("Change Robot29's status to idle using the robot_status_change function after the task is complete.", 'The status of Robot29 has been changed to idle.')
# ---
#
# replanner:
#     response:
#         The construction materials at location (12, 1) have been successfully removed and Robot29's status has been set to idle. The task is complete.
# ---
#
# 9. task: Move to location (8, 12) and remove the tree branches.
# ---
# planner:
#   plan:
#     Use robot_selection_tool(desired_robot_tool_property='saw', item_position=(8, 12)) to select the best suited robot equipped with a saw for removing tree branches.
#     Use move_robot(robot_name, desired_position=(8, 12)) to move the selected robot to the location of the tree branches.
#     Use grab_or_remove_item(robot_name, item_name='tree branches') to remove the tree branches from the location.
#     Use robot_status_change(robot_name, status='idle') to set the robot's status to idle after the tree branches are removed.
#   current step:
#      Use robot_selection_tool(desired_robot_tool_property='saw', item_position=(8, 12)) to select the best suited robot equipped with a saw for removing tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for selecting the correct robot for the task. Since the objective specifies the need for a robot with a saw to remove tree branches and the position of the item, the robot_selection_tool should be used to determine the best suited robot for this task.
# ---
#
# Robot_selector:
#    past steps: ("Use robot_selection_tool(desired_robot_tool_property='saw', item_position=(8, 12)) to select the best suited robot equipped with a saw for removing tree branches.", 'The best suited robot equipped with a saw for removing tree branches at position (8, 12) is Robot14.')
# ---
#
# replanner:
#     plan:
#         Use move_robot(robot_name='Robot14', desired_position=(8, 12)) to move Robot14 to the location of the tree branches.
#         Use grab_or_remove_item(robot_name='Robot14', item_name='tree branches') to remove the tree branches from the location.
#         Use robot_status_change(robot_name='Robot14', status='idle') to set Robot14's status to idle after the tree branches are removed.
#     current step:
#         Use move_robot(robot_name='Robot14', desired_position=(8, 12)) to move Robot14 to the location of the tree branches.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user requested a specific action to move a robot, which falls under the responsibility of the Controller. The 'move_robot' tool is used to move a specified robot to a given position, and the user has provided both the robot name ('Robot14') and the desired position ((8, 12)). Therefore, the Controller is the correct worker to carry out this action.
# ---
#
# Controller:
#    past steps: ("Use move_robot(robot_name='Robot14', desired_position=(8, 12)) to move Robot14 to the location of the tree branches.", 'Robot14 has been successfully moved to the location at coordinates (8, 12).')
# ---
#
# replanner:
#     plan:
#         Use grab_or_remove_item(robot_name='Robot14', item_name='tree branches') to remove the tree branches from the location.
#         Use robot_status_change(robot_name='Robot14', status='idle') to set Robot14's status to idle after the tree branches are removed.
#     current step:
#         Use grab_or_remove_item(robot_name='Robot14', item_name='tree branches') to remove the tree branches from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a direct action involving a specific robot, Robot14, and an item, 'tree branches'. Since the Controller is responsible for controlling the robots and their interactions with items, and the action 'grab_or_remove_item' is one of the tools the Controller has, the Controller should perform the current step of removing the tree branches using Robot14.
# ---
#
# Controller:
#    past steps: ("Use grab_or_remove_item(robot_name='Robot14', item_name='tree branches') to remove the tree branches from the location.", 'The tree branches have been successfully removed from the location by Robot14.')
# ---
#
# replanner:
#     plan:
#         Use robot_status_change(robot_name='Robot14', status='idle') to set Robot14's status to idle after the tree branches are removed.
#     current step:
#         Use robot_status_change(robot_name='Robot14', status='idle') to set Robot14's status to idle after the tree branches are removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with tools including 'robot_status_change'. Since the request involves setting Robot14's status to 'idle' after completing a task, the Controller is the appropriate worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Use robot_status_change(robot_name='Robot14', status='idle') to set Robot14's status to idle after the tree branches are removed.", 'Robot14 has successfully removed the tree branches and is now set to idle status.')
# ---
#
# replanner:
#     response:
#         The tree branches at location (8, 12) have been successfully removed by Robot14 equipped with a saw. Robot14 is now set to idle status.
# ---
#
# 10. task: Move to location (3, 5) and remove the screws.
# ---
# planner:
#   plan:
#     Select a robot equipped with a screwdriver using robot_selection_tool('screwdriver', (3, 5)).
#     Move the selected robot to location (3, 5) using move_robot(robot_name, (3, 5)).
#     Remove the screws using grab_or_remove_item(robot_name, 'screws').
#     Set the robot status to idle using robot_status_change(robot_name, 'idle').
#   current step:
#      Select a robot equipped with a screwdriver using robot_selection_tool('screwdriver', (3, 5)).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request requires the selection of a robot that is equipped with a screwdriver and is needed at the position (3, 5). The Robot_selector is responsible for selecting the correct robot with the desired properties, in this case using the tool robot_selection_tool. Since the request is to find the appropriate robot with a specific tool property (screwdriver) and not to control an already selected robot, the Robot_selector is the suitable worker to act next.
# ---
#
# Robot_selector:
#    past steps: ("Select a robot equipped with a screwdriver using robot_selection_tool('screwdriver', (3, 5)).", 'The best-suited robot to solve the task, equipped with a screwdriver and located at position (3, 5), is Robot45.')
# ---
#
# replanner:
#     plan:
#         Move Robot45 to location (3, 5) using move_robot('Robot45', (3, 5)).
#         Remove the screws using grab_or_remove_item('Robot45', 'screws').
#         Set Robot45 status to idle using robot_status_change('Robot45', 'idle').
#     current step:
#         Move Robot45 to location (3, 5) using move_robot('Robot45', (3, 5)).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action to move a specific robot, Robot45, to a new location. Since the Controller is responsible for controlling robots and the move_robot tool is specifically designed to move a selected robot to a given position, the Controller is the appropriate worker to carry out this action.
# ---
#
# Controller:
#    past steps: ("Move Robot45 to location (3, 5) using move_robot('Robot45', (3, 5)).", 'Robot45 has been successfully moved to the location (3, 5).')
# ---
#
# replanner:
#     plan:
#         Remove the screws using grab_or_remove_item('Robot45', 'screws').
#         Set Robot45 status to idle using robot_status_change('Robot45', 'idle').
#     current step:
#         Remove the screws using grab_or_remove_item('Robot45', 'screws').
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to remove screws using the tool 'grab_or_remove_item' and identifies the robot 'Robot45' to perform the action. The Controller is responsible for controlling the robots and using the tools 'move_robot', 'grab_or_remove_item', and 'robot_status_change'. Since the tool and robot are specified, the Controller is the appropriate worker to execute the current_step.
# ---
#
# Controller:
#    past steps: ("Remove the screws using grab_or_remove_item('Robot45', 'screws').", 'The screws have been successfully grabbed/removed by Robot45.')
# ---
#
# replanner:
#     plan:
#         Set Robot45 status to idle using robot_status_change('Robot45', 'idle').
#     current step:
#         Set Robot45 status to idle using robot_status_change('Robot45', 'idle').
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to set the status of a specific robot (Robot45) to idle. This task falls under the responsibilities of the Controller, who has the tool 'robot_status_change' to change the current status of the robot. Therefore, the Controller is the correct worker to perform the current_step of setting Robot45's status to idle.
# ---
#
# Controller:
#    past steps: ("Set Robot45 status to idle using robot_status_change('Robot45', 'idle').", "Robot45's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         The screws at location (3, 5) have been successfully removed by Robot45, which is now set to idle status.
# ---

# %% [markdown]
# ## Hard test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Results\Result_matrix\Hard_react_matrix.txt"
clear_txt(file_name)

with open("Results\Tasks\Hard_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 100}
        inputs = {"input": task}
        i = 1
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
                    
            if i == 50:
                # This is to ensure there is a response even though the it fails due recursion limit
                write_txt(file_name, "DNF;DNF;DNF;DNF\n")
                history.extend("DNF")
                break
            i+=1
        
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('Results\Raw_output\output_Hard_react.xlsx')
# Out:
# 1. task: Move Robot40 to location (4, 8) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with 'Robot40' as the robot_name and 'gripper' as the desired_robot_tool_property to ensure Robot40 is equipped to remove the toolkit.
#     Use the move_robot tool with 'Robot40' as the robot_name and (4, 8) as the desired_position to move Robot40 to the correct location.
#     Use the grab_or_remove_item tool with 'Robot40' as the robot_name and 'toolkit' as the item_name to remove the toolkit from the location.
#     Use the robot_status_change tool with 'Robot40' as the robot_name and 'idle' as the status to set Robot40's status to idle after completing the objective.
#   current step:
#      Use the select_known_robot_tool with 'Robot40' as the robot_name and 'gripper' as the desired_robot_tool_property to ensure Robot40 is equipped to remove the toolkit.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies a need to verify if Robot40 is equipped with the necessary tool property ('gripper') to remove the toolkit. The Robot_selector is responsible for this task using the 'select_known_robot_tool' function with the specified parameters.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with 'Robot40' as the robot_name and 'gripper' as the desired_robot_tool_property to ensure Robot40 is equipped to remove the toolkit.", 'The initial selected tool was a "gripper," which is suitable for handling a toolkit according to the provided list of items with associated tool properties. However, Robot40 is equipped with a "vacuum," which is not suitable for picking up a toolkit as it is designed to clean dust and small debris. Therefore, Robot40 cannot solve the task with its current tool property: vacuum.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with 'gripper' as the desired_robot_tool_property and (4, 8) as the item_position to select a new robot that is equipped to remove the toolkit.
#         Use the move_robot tool with the newly selected robot's name and (4, 8) as the desired_position to move the robot to the correct location.
#         Use the grab_or_remove_item tool with the newly selected robot's name and 'toolkit' as the item_name to remove the toolkit from the location.
#         Use the robot_status_change tool with the newly selected robot's name and 'idle' as the status to set the robot's status to idle after completing the objective.
#     current step:
#         Use the robot_selection_tool with 'gripper' as the desired_robot_tool_property and (4, 8) as the item_position to select a new robot that is equipped to remove the toolkit.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the use of the robot_selection_tool to select a new robot equipped with a 'gripper' to remove an item at position (4, 8). The Robot_selector is responsible for selecting the correct robot using their tools, and in this case, the robot_selection_tool is the appropriate tool for the job.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with 'gripper' as the desired_robot_tool_property and (4, 8) as the item_position to select a new robot that is equipped to remove the toolkit.", 'The best suited robot to remove the toolkit is Robot2.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool with Robot2's name and (4, 8) as the desired_position to move the robot to the correct location.
#         Use the grab_or_remove_item tool with Robot2's name and 'toolkit' as the item_name to remove the toolkit from the location.
#         Use the robot_status_change tool with Robot2's name and 'idle' as the status to set the robot's status to idle after completing the objective.
#     current step:
#         Use the move_robot tool with Robot2's name and (4, 8) as the desired_position to move the robot to the correct location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions using the move_robot tool with Robot2's name and a given position (4, 8). Since the Controller is responsible for controlling the robots and the move_robot tool is one of the Controller's tools, the Controller should act next to perform the task of moving Robot2 to the desired position.
# ---
#
# Controller:
#    past steps: ("Use the move_robot tool with Robot2's name and (4, 8) as the desired_position to move the robot to the correct location.", 'Robot2 has been successfully moved to the desired position (4, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with Robot2's name and 'toolkit' as the item_name to remove the toolkit from the location.
#         Use the robot_status_change tool with Robot2's name and 'idle' as the status to set the robot's status to idle after completing the objective.
#     current step:
#         Use the grab_or_remove_item tool with Robot2's name and 'toolkit' as the item_name to remove the toolkit from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to use the 'grab_or_remove_item' tool with a given robot name, 'Robot2', and an item name, 'toolkit'. This is a direct command that falls under the Controller's responsibility, as they are equipped with the tools to control robots, including the 'grab_or_remove_item' function. Therefore, the Controller should act next to perform the current step of removing the toolkit from the location using Robot2.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item tool with Robot2's name and 'toolkit' as the item_name to remove the toolkit from the location.", 'Robot2 has successfully grabbed or removed the toolkit.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool with Robot2's name and 'idle' as the status to set the robot's status to idle after completing the objective.
#     current step:
#         Use the robot_status_change tool with Robot2's name and 'idle' as the status to set the robot's status to idle after completing the objective.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested the use of the robot_status_change tool to set Robot2's status to 'idle', which is a direct action for controlling a robot. The Controller is responsible for controlling robots and has the robot_status_change tool necessary to perform this task.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool with Robot2's name and 'idle' as the status to set the robot's status to idle after completing the objective.", "Robot2's status has been successfully changed to idle after completing the objective.")
# ---
#
# replanner:
#     response:
#         The toolkit at location (4, 8) has been successfully removed by Robot2, which was equipped with a gripper. Robot2's status has been set to idle after completing the objective.
# ---
#
# 2. task: Move Robot40 to location (6, 2) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot40 and 'mop' as the desired_robot_tool_property to ensure Robot40 is equipped with a mop to clean the liquid spill.
#     Use the move_robot tool with 'Robot40' as the robot_name and (6, 2) as the desired_position to move Robot40 to the location of the liquid spill.
#     Use the grab_or_remove_item tool with 'Robot40' as the robot_name and 'liquid spill' as the item_name to remove the liquid spill from the location.
#     Use the robot_status_change tool with 'Robot40' as the robot_name and 'idle' as the status to set Robot40's status to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot40 and 'mop' as the desired_robot_tool_property to ensure Robot40 is equipped with a mop to clean the liquid spill.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to verify if Robot40 is equipped with a mop to handle a liquid spill. The Robot_selector is responsible for selecting the correct robot and confirming its equipment using the select_known_robot_tool. Therefore, the Robot_selector should use this tool with 'Robot40' as the robot name and 'mop' as the desired_robot_tool_property to ensure that Robot40 can perform the cleaning task.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot40 and 'mop' as the desired_robot_tool_property to ensure Robot40 is equipped with a mop to clean the liquid spill.", 'The initial selected tool for cleaning a liquid spill was a "mop" as it is the appropriate tool property for dealing with liquid spills. However, Robot40 is equipped with a "vacuum." According to the list of items and associated tool properties, a vacuum is suitable for dealing with dust and small debris, not liquid spills. Therefore, Robot40 with a vacuum cannot effectively solve the task of cleaning a liquid spill, as it requires a mop to do so according to the provided references.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with 'mop' as the desired_robot_tool_property and (6, 2) as the item_position to select the correct robot equipped with a mop.
#         Once the appropriate robot is selected, use the move_robot tool with the newly selected robot's name and (6, 2) as the desired_position to move the robot to the location of the liquid spill.
#         Use the grab_or_remove_item tool with the newly selected robot's name and 'liquid spill' as the item_name to clean up the liquid spill from the location.
#         Use the robot_status_change tool with the newly selected robot's name and 'idle' as the status to set the robot's status to idle after the task is complete.
#     current step:
#         Use the robot_selection_tool with 'mop' as the desired_robot_tool_property and (6, 2) as the item_position to select the correct robot equipped with a mop.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to select a robot equipped with a specific tool property ('mop') and provides an item position. Since the task involves selecting the correct robot based on a desired tool property and no specific robot is mentioned, the Robot_selector should use the robot_selection_tool to determine the best-suited robot for the job.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with 'mop' as the desired_robot_tool_property and (6, 2) as the item_position to select the correct robot equipped with a mop.", 'The best-suited robot to solve the task with a mop at the position (6, 2) is Robot6.')
# ---
#
# replanner:
#     plan:
#         Move Robot6 to location (6, 2) using the move_robot tool.
#         Remove the liquid spill at location (6, 2) using the grab_or_remove_item tool with 'liquid spill' as the item_name.
#         Set Robot6's status to idle using the robot_status_change tool with 'idle' as the status.
#     current step:
#         Move Robot6 to location (6, 2) using the move_robot tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a robot (Robot6) and a desired action (move to location (6, 2)) that aligns with the Controller's move_robot tool capability. There's no need to select a robot as it has already been specified, and the task doesn't involve answering a generic question, therefore the Controller is the appropriate worker to act next.
# ---
#
# Controller:
#    past steps: ('Move Robot6 to location (6, 2) using the move_robot tool.', 'Robot6 has been moved to the desired position (6, 2).')
# ---
#
# replanner:
#     plan:
#         Remove the liquid spill at location (6, 2) using the grab_or_remove_item tool with Robot6 and 'liquid spill' as the item_name.
#         Set Robot6's status to idle using the robot_status_change tool with Robot6 as the robot_name and 'idle' as the status.
#     current step:
#         Remove the liquid spill at location (6, 2) using the grab_or_remove_item tool with Robot6 and 'liquid spill' as the item_name.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to remove a liquid spill at a certain location using the 'grab_or_remove_item' tool with a specific robot named Robot6. Since the robot to perform the task is already determined, there is no need for the Robot_selector to select a robot. The Controller is responsible for controlling robots and has the 'grab_or_remove_item' tool required to perform the task. Therefore, the Controller should be the one to act next to carry out the removal of the liquid spill.
# ---
#
# Controller:
#    past steps: ("Remove the liquid spill at location (6, 2) using the grab_or_remove_item tool with Robot6 and 'liquid spill' as the item_name.", 'The liquid spill at location (6, 2) has been successfully handled by Robot6.')
# ---
#
# replanner:
#     plan:
#         Set Robot6's status to idle using the robot_status_change tool with Robot6 as the robot_name and 'idle' as the status.
#     current step:
#         Set Robot6's status to idle using the robot_status_change tool with Robot6 as the robot_name and 'idle' as the status.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task requires the use of the robot_status_change tool, which is within the Controller's set of tools. The specific action to be performed is setting Robot6's status to idle, and the Controller is responsible for direct control actions on robots, including changing their status.
# ---
#
# Controller:
#    past steps: ("Set Robot6's status to idle using the robot_status_change tool with Robot6 as the robot_name and 'idle' as the status.", "Robot6's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The liquid spill at location (6, 2) has been successfully removed by Robot6, and the robot's status has been set to idle. The task is complete.
# ---
#
# 3. task: Move Robot9 to location (12, 3) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot9 and 'front loader' to ensure Robot9 is equipped to remove large debris.
#     Use the move_robot tool with Robot9 to move it to location (12, 3).
#     Use the grab_or_remove_item tool with Robot9 to remove the large debris at location (12, 3).
#     Use the robot_status_change tool with Robot9 to set its status to 'idle' after the removal of the debris is complete.
#   current step:
#      Use the select_known_robot_tool with Robot9 and 'front loader' to ensure Robot9 is equipped to remove large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request explicitly asks to use the 'select_known_robot_tool' with Robot9 and 'front loader' to verify if the robot is equipped to handle the task of removing large debris. This falls under the responsibility of the Robot_selector, who has access to the 'select_known_robot_tool' which is used to determine if a specified robot has the necessary tool property for a given objective.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot9 and 'front loader' to ensure Robot9 is equipped to remove large debris.", 'Robot9 has been selected and is equipped with a front loader to remove the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool with Robot9 to move it to location (12, 3).
#         Use the grab_or_remove_item tool with Robot9 to remove the large debris at location (12, 3).
#         Use the robot_status_change tool with Robot9 to set its status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the move_robot tool with Robot9 to move it to location (12, 3).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested a specific action to be performed by a robot, which includes moving Robot9 to a given location. The Controller is responsible for controlling the robots using tools such as move_robot. Since the specific robot name and desired position are provided, no robot selection is needed, and the action falls directly under the Controller's responsibilities.
# ---
#
# Controller:
#    past steps: ('Use the move_robot tool with Robot9 to move it to location (12, 3).', 'Robot9 has been successfully moved to the position (12, 3).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with Robot9 to remove the large debris at location (12, 3).
#         Use the robot_status_change tool with Robot9 to set its status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the grab_or_remove_item tool with Robot9 to remove the large debris at location (12, 3).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action for a specified robot, Robot9, to remove an item, which is 'large debris' at a specific location (12, 3). The Controller is responsible for controlling the robots with a set of tools, one of which is 'grab_or_remove_item'. Since the specific robot and action are already identified in the request, the Controller is the appropriate worker to perform the current_step using the 'grab_or_remove_item' tool to remove the item as instructed.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item tool with Robot9 to remove the large debris at location (12, 3).', 'Robot9 has successfully grabbed/removed the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool with Robot9 to set its status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the robot_status_change tool with Robot9 to set its status to 'idle' after the removal of the debris is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots and using tools such as robot_status_change. Since the task involves setting a robot's status to 'idle' after the completion of a task, the Controller is the appropriate worker to perform this current_step using the robot_status_change tool.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool with Robot9 to set its status to 'idle' after the removal of the debris is complete.", "Robot9's status has been successfully changed to 'idle' after the completion of the debris removal.")
# ---
#
# replanner:
#     response:
#         The task is complete. Robot9 with a front loader has successfully moved to location (12, 3) and removed the large debris. The robot's status has been set to 'idle' following the completion of the task.
# ---
#
# 4. task: Move Robot35 to location (2, 11) and remove the dust.
# ---
# planner:
#   plan:
#     Use the 'select_known_robot_tool' to verify if Robot35 is equipped with a tool property capable of removing dust (e.g., vacuum, broom).
#     Use the 'move_robot' function to move Robot35 to location (2, 11).
#     Use the 'grab_or_remove_item' function to remove the dust from the location using Robot35.
#     Use the 'robot_status_change' function to set the status of Robot35 to idle after the task is completed.
#   current step:
#      Use the 'select_known_robot_tool' to verify if Robot35 is equipped with a tool property capable of removing dust (e.g., vacuum, broom).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The 'select_known_robot_tool' is a tool that belongs to the Robot_selector. It is used to determine if a specified robot is equipped with a tool property capable of solving the objective. In this case, the user has requested to verify if Robot35 has a tool property for removing dust, such as a vacuum or broom, which is precisely what the 'select_known_robot_tool' is designed to do.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'select_known_robot_tool' to verify if Robot35 is equipped with a tool property capable of removing dust (e.g., vacuum, broom).", 'The initial selected tool property for removing dust was a vacuum. However, Robot35 is equipped with a screwdriver, which is not suitable for removing dust according to the list of items with associated tool properties. The screwdriver is designed for manipulating screws, not for dust removal tasks. Therefore, Robot35 cannot solve the task of removing dust with its current tool property: screwdriver.')
# ---
#
# replanner:
#     plan:
#         Use the 'robot_selection_tool' to determine the best suited robot to solve the objective of removing dust.
#         Use the 'move_robot' function to move the selected robot to location (2, 11).
#         Use the 'grab_or_remove_item' function to remove the dust from the location using the selected robot.
#         Use the 'robot_status_change' function to set the status of the selected robot to idle after the task is completed.
#     current step:
#         Use the 'robot_selection_tool' to determine the best suited robot to solve the objective of removing dust.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves selecting the best suited robot for a specific objective, which is removing dust. Since no specific robot is mentioned and the objective is clear, the Robot_selector should use the 'robot_selection_tool' to determine the best suited robot to accomplish the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'robot_selection_tool' to determine the best suited robot to solve the objective of removing dust.", 'The best suited robot to remove dust is Robot40, which is equipped with a vacuum tool.')
# ---
#
# replanner:
#     plan:
#         Use the 'move_robot' function to move Robot40 to location (2, 11).
#         Use the 'grab_or_remove_item' function to remove the dust from location (2, 11) using Robot40.
#         Use the 'robot_status_change' function to set the status of Robot40 to idle after the task is completed.
#     current step:
#         Use the 'move_robot' function to move Robot40 to location (2, 11).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested a specific action that falls directly under the responsibilities of the Controller, which includes moving robots to given positions. The 'move_robot' function is a tool that the Controller uses to perform such tasks.
# ---
#
# Controller:
#    past steps: ("Use the 'move_robot' function to move Robot40 to location (2, 11).", 'Robot40 has been successfully moved to the location (2, 11).')
# ---
#
# replanner:
#     plan:
#         Use the 'grab_or_remove_item' function to remove the dust from location (2, 11) using Robot40.
#         Use the 'robot_status_change' function to set the status of Robot40 to idle after the task is completed.
#     current step:
#         Use the 'grab_or_remove_item' function to remove the dust from location (2, 11) using Robot40.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions using Robot40 to remove dust from location (2, 11), which implies that the robot has already been selected. Therefore, the Controller should act next, using the 'grab_or_remove_item' function to command Robot40 to remove the dust.
# ---
#
# Controller:
#    past steps: ("Use the 'grab_or_remove_item' function to remove the dust from location (2, 11) using Robot40.", 'Robot40 has successfully removed the dust from the location (2, 11).')
# ---
#
# replanner:
#     plan:
#         Use the 'robot_status_change' function to set the status of Robot40 to idle after the task is completed.
#     current step:
#         Use the 'robot_status_change' function to set the status of Robot40 to idle after the task is completed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with a set of tools, including the 'robot_status_change' which is specifically mentioned in the user request. The task involves changing the status of Robot40 to idle, which falls under the Controller's responsibilities.
# ---
#
# Controller:
#    past steps: ("Use the 'robot_status_change' function to set the status of Robot40 to idle after the task is completed.", 'The status of Robot40 has been changed to idle.')
# ---
#
# replanner:
#     response:
#         Robot40 equipped with a vacuum has successfully moved to location (2, 11) and removed the dust. The robot status has been set to idle, completing the task.
# ---
#
# 5. task: Move Robot26 to location (12, 1) and remove the grass.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot26 to verify it is equipped with the lawnmower tool property.
#     Use the move_robot function with Robot26 to move it to location (12, 1).
#     Use the grab_or_remove_item function with Robot26 to remove the grass at location (12, 1).
#     Use the robot_status_change function with Robot26 to set its status to idle.
#   current step:
#      Use the select_known_robot_tool with Robot26 to verify it is equipped with the lawnmower tool property.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifically asks to use the 'select_known_robot_tool' to verify if Robot26 is equipped with the lawnmower tool property. The 'Robot_selector' is responsible for selecting the correct robot and has the 'select_known_robot_tool' needed for this task.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool with Robot26 to verify it is equipped with the lawnmower tool property.', 'Robot26 is currently active and is not available to solve the task. Therefore, I cannot verify if it is equipped with the lawnmower tool property at this moment.')
# ---
#
# replanner:
#     plan:
#         Wait until Robot26 is no longer active and is available.
#         Use the select_known_robot_tool with Robot26 to verify if it is now equipped with the lawnmower tool property.
#         Use the move_robot function with Robot26 to move it to location (12, 1).
#         Use the grab_or_remove_item function with Robot26 to remove the grass at location (12, 1).
#         Use the robot_status_change function with Robot26 to set its status to idle.
#     current step:
#         Wait until Robot26 is no longer active and is available.
# ---
#
# supervisor:
#    next agent: misc_agent
#    reason: The request involves waiting for a specific condition (Robot26 being no longer active and available), which is not a direct action but rather a monitoring or querying task. The Controller is responsible for controlling robots with specific tools, and the Robot_selector is for selecting the correct robot. The misc_agent is responsible for answering more generic questions, and in this case, it seems most appropriate for handling the task of waiting and monitoring for a robot's availability.
# ---
#
# misc_agent:
#    past steps: ('Wait until Robot26 is no longer active and is available.', "I'm here to assist you now. How can I help you today?")
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot26 to set its status to idle.
#         Use the select_known_robot_tool with Robot26 to verify if it is equipped with the lawnmower tool property.
#         Use the move_robot function with Robot26 to move it to location (12, 1).
#         Use the grab_or_remove_item function with Robot26 to remove the grass at location (12, 1).
#     current step:
#         Use the robot_status_change function with Robot26 to set its status to idle.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'robot_status_change' function to set the status of Robot26 to idle. The 'robot_status_change' function is one of the tools under the Controller's responsibility. Therefore, the Controller is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ('Use the robot_status_change function with Robot26 to set its status to idle.', "Robot26's status has been changed to idle.")
# ---
#
# replanner:
#     plan:
#         Verify if Robot26 is equipped with the lawnmower tool property using the select_known_robot_tool function.
#         Move Robot26 to location (12, 1) using the move_robot function.
#         Remove the grass at location (12, 1) with Robot26 using the grab_or_remove_item function.
#         Set Robot26's status to idle using the robot_status_change function after completing the task.
#     current step:
#         Verify if Robot26 is equipped with the lawnmower tool property using the select_known_robot_tool function.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for verifying if a specified robot is equipped with a certain tool property. Since the user request is to verify if Robot26 is equipped with the lawnmower tool property, the Robot_selector should use the select_known_robot_tool function to determine this.
# ---
#
# Robot_selector:
#    past steps: ('Verify if Robot26 is equipped with the lawnmower tool property using the select_known_robot_tool function.', 'The initial selected tool property for Robot26 was "lawnmower" which is specifically used for cutting grass. Robot26, however, is equipped with a "mop" tool property, which according to the provided list of items and associated tool properties is used for cleaning up liquid spills.\n\nSince a lawnmower is necessary for tasks involving grass, and a mop is not suitable for this purpose, Robot26 with the tool property: mop cannot solve the task that requires a lawnmower. The tool properties are not interchangeable in this context, and the specific task of cutting grass cannot be accomplished with a mop.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool to find a robot equipped with a lawnmower tool property that is near location (12, 1).
#         Assign the task to the robot selected by the robot_selection_tool.
#         Move the selected robot to location (12, 1) using the move_robot function.
#         Remove the grass at location (12, 1) with the selected robot using the grab_or_remove_item function.
#         Set the selected robot's status to idle using the robot_status_change function after completing the task.
#     current step:
#         Use the robot_selection_tool to find a robot equipped with a lawnmower tool property that is near location (12, 1).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: Since the user request involves finding a robot equipped with a specific tool property (a lawnmower) and also considering the location proximity (near location 12, 1), the Robot_selector is the appropriate worker to act next. The robot_selection_tool is designed to determine the best suited robot to solve the objective when no specific robot is mentioned, which aligns with the current user request.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to find a robot equipped with a lawnmower tool property that is near location (12, 1).', 'Robot31 is the best suited to solve the task with its lawnmower tool property, and it is near location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Move Robot31 to location (12, 1) using the move_robot function.
#         Remove the grass at location (12, 1) with Robot31 using the grab_or_remove_item function.
#         Set Robot31's status to idle using the robot_status_change function after completing the task.
#     current step:
#         Move Robot31 to location (12, 1) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action involving a particular robot (Robot31) and a specific location (12, 1). The Controller is responsible for controlling the robots with a set of tools, including the move_robot function which is exactly needed here to move Robot31 to the desired position. Therefore, the Controller is the appropriate worker to act next to fulfill this request.
# ---
#
# Controller:
#    past steps: ('Move Robot31 to location (12, 1) using the move_robot function.', 'Robot31 has been successfully moved to the location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Remove the grass at location (12, 1) with Robot31 using the grab_or_remove_item function.
#         Set Robot31's status to idle using the robot_status_change function after completing the task.
#     current step:
#         Remove the grass at location (12, 1) with Robot31 using the grab_or_remove_item function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: Since the specific robot (Robot31) and the action (remove the grass) are already specified in the user request, the Controller is the appropriate worker to perform the current_step using the 'grab_or_remove_item' function to remove the grass at the specified location.
# ---
#
# Controller:
#    past steps: ('Remove the grass at location (12, 1) with Robot31 using the grab_or_remove_item function.', 'Robot31 has removed the grass and has been moved to the location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Set Robot31's status to idle using the robot_status_change function after completing the task.
#     current step:
#         Set Robot31's status to idle using the robot_status_change function after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task requires the use of the 'robot_status_change' function which is a tool controlled by the Controller. Therefore, the Controller should act next to change Robot31's status to idle after the completion of the task.
# ---
#
# Controller:
#    past steps: ("Set Robot31's status to idle using the robot_status_change function after completing the task.", 'The status of Robot31 has been successfully changed to idle after completing the task.')
# ---
#
# replanner:
#     response:
#         The grass at location (12, 1) has been successfully removed by Robot31, which is equipped with a lawnmower tool property. The robot has been set to idle status after completing the task. No further actions are required.
# ---
#
# 6. task: Move Robot41 to location (4, 11) and remove the small debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify that Robot41 is equipped with a tool property suitable for removing small debris, such as a vacuum or broom.
#     If Robot41 is not equipped with the right tool, use the robot_status_change function to set Robot41 to idle and select a different robot using the robot_selection_tool with a desired property like vacuum or broom, and item_position (4, 11).
#     Use the move_robot function to move the selected robot to location (4, 11).
#     Once the robot is in position, use the grab_or_remove_item function to remove the small debris.
#     After the objective is completed, use the robot_status_change function to set the robot's status to idle.
#   current step:
#      Use the select_known_robot_tool to verify that Robot41 is equipped with a tool property suitable for removing small debris, such as a vacuum or broom.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for determining if a specified robot is equipped with the necessary tool property to solve the objective. Since the user request specifies a robot (Robot41) and requires verification that it has a suitable tool for removing small debris, the select_known_robot_tool should be used. This tool is part of the Robot_selector's toolkit, making the Robot_selector the appropriate worker to act next.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to verify that Robot41 is equipped with a tool property suitable for removing small debris, such as a vacuum or broom.', 'The initial selected tools for removing small debris were a vacuum or a broom. Robot41 cannot solve the task with the tool property: lawnmower because a lawnmower is designed for cutting grass and is not suitable for picking up or sweeping small debris as per the list of items with associated tool properties. A lawnmower does not have the capability to vacuum or broom small particles, which is necessary for the task at hand.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function to set Robot41's status to idle.
#         Use the robot_selection_tool with the desired property like vacuum or broom, and item_position (4, 11) to select a robot equipped for removing small debris.
#         Use the move_robot function to move the selected robot to location (4, 11).
#         Once the robot is in position, use the grab_or_remove_item function to remove the small debris.
#         After the objective is completed, use the robot_status_change function to set the robot's status to idle.
#     current step:
#         Use the robot_status_change function to set Robot41's status to idle.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with a set of tools, including the robot_status_change function which is needed to set Robot41's status to idle as per the request.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function to set Robot41's status to idle.", "Robot41's status has been set to idle.")
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with the desired property like vacuum or broom, and item_position (4, 11) to select a robot equipped for removing small debris.
#         Use the move_robot function to move the selected robot to location (4, 11).
#         Once the robot is in position, use the grab_or_remove_item function to remove the small debris.
#         After the objective is completed, use the robot_status_change function to set the robot's status to idle.
#     current step:
#         Use the robot_selection_tool with the desired property like vacuum or broom, and item_position (4, 11) to select a robot equipped for removing small debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves selecting a robot with a specific tool property such as a vacuum or broom and a specified item position. The Robot_selector is responsible for selecting the correct robot using the robot_selection_tool, which fits the requirements of the user request perfectly. Therefore, the Robot_selector should be the worker to perform the current_step.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool with the desired property like vacuum or broom, and item_position (4, 11) to select a robot equipped for removing small debris.', 'The best-suited robot to remove small debris at the position (4, 11) is Robot50, which is equipped with a vacuum.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot50, which is equipped with a vacuum, to location (4, 11).
#         Once Robot50 is in position, use the grab_or_remove_item function to remove the small debris.
#         After the objective is completed, use the robot_status_change function to set Robot50's status to idle.
#     current step:
#         Use the move_robot function to move Robot50, which is equipped with a vacuum, to location (4, 11).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a direct action involving moving a robot to a specific location. The Controller is responsible for controlling the robots with tools including 'move_robot'. Since the robot's name and the desired position are provided, the Controller is the appropriate worker to carry out the 'move_robot' function.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function to move Robot50, which is equipped with a vacuum, to location (4, 11).', 'Robot50, equipped with a vacuum, has been successfully moved to the location (4, 11).')
# ---
#
# replanner:
#     plan:
#         Once Robot50 is in position at (4, 11), use the grab_or_remove_item function to remove the small debris.
#         After the small debris is removed, use the robot_status_change function to set Robot50's status to idle.
#     current step:
#         Once Robot50 is in position at (4, 11), use the grab_or_remove_item function to remove the small debris.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action that involves moving a robot to a certain position and then using it to grab or remove an item. Since these actions fall within the Controller's toolset, specifically the 'move_robot' and 'grab_or_remove_item' tools, the Controller is the correct worker to carry out the next steps.
# ---
#
# Controller:
#    past steps: ('Once Robot50 is in position at (4, 11), use the grab_or_remove_item function to remove the small debris.', 'Robot50 is now at position (4, 11) and has removed the small debris.')
# ---
#
# replanner:
#     plan:
#         After the small debris is removed, use the robot_status_change function to set Robot50's status to idle.
#     current step:
#         After the small debris is removed, use the robot_status_change function to set Robot50's status to idle.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, including changing their status. Since the current_step involves setting Robot50's status to idle after completing an objective, the Controller should use the robot_status_change function to perform this task.
# ---
#
# Controller:
#    past steps: ("After the small debris is removed, use the robot_status_change function to set Robot50's status to idle.", 'Robot50 has successfully grabbed/removed the small debris and is now set to idle.')
# ---
#
# replanner:
#     response:
#         Robot50 equipped with a vacuum has successfully removed the small debris at location (4, 11) and has been set to idle status.
# ---
#
# 7. task: Move Robot2 to location (9, 1) and remove the vehicle.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with 'Robot2' and 'tow hook' to ensure Robot2 is equipped with the necessary tool property to remove the vehicle.
#     Use the move_robot function with 'Robot2' and the coordinates (9, 1) to move Robot2 to the desired location.
#     Use the grab_or_remove_item function with 'Robot2' and 'vehicle' to remove the vehicle from the location.
#     Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after the task is completed.
#   current step:
#      Use the select_known_robot_tool with 'Robot2' and 'tow hook' to ensure Robot2 is equipped with the necessary tool property to remove the vehicle.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to verify if 'Robot2' is equipped with a 'tow hook' to remove a vehicle. The Robot_selector is responsible for determining if a robot is equipped with the necessary tool property to complete a task, using the select_known_robot_tool.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with 'Robot2' and 'tow hook' to ensure Robot2 is equipped with the necessary tool property to remove the vehicle.", 'The initial selected tool for removing a vehicle was a "tow hook," which is appropriate for the task at hand. However, Robot2 is equipped with a "gripper." According to the list of items with associated tool properties provided, a "gripper" is not suitable for removing a vehicle. The tasks that can be performed by a "gripper" include manipulating toolkit, large debris, construction materials, but not vehicles. Therefore, Robot2 with a "gripper" cannot solve the task of removing a vehicle, as it requires a "tow hook" to be performed effectively and safely.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with 'tow hook' and the coordinates (9, 1) to select the correct robot equipped with the necessary tool property to remove the vehicle.
#         Use the move_robot function with the selected robot and the coordinates (9, 1) to move the robot to the desired location.
#         Use the grab_or_remove_item function with the selected robot and 'vehicle' to remove the vehicle from the location.
#         Use the robot_status_change function with the selected robot and 'idle' to set the robot's status to idle after the task is completed.
#     current step:
#         Use the robot_selection_tool with 'tow hook' and the coordinates (9, 1) to select the correct robot equipped with the necessary tool property to remove the vehicle.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request requires the use of the robot_selection_tool with specific criteria ('tow hook' and coordinates (9, 1)) to select the appropriate robot for the task. The Robot_selector is responsible for selecting the correct robot using tools like robot_selection_tool when no specific robot is mentioned in the objective. Therefore, the Robot_selector should act next to determine the best suited robot to remove the vehicle.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with 'tow hook' and the coordinates (9, 1) to select the correct robot equipped with the necessary tool property to remove the vehicle.", 'Robot23 is the best suited to solve the task of removing the vehicle at coordinates (9, 1) with its tow hook.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot23 and the coordinates (9, 1) to move Robot23 to the desired location.
#         Use the grab_or_remove_item function with Robot23 and 'vehicle' to remove the vehicle from the location.
#         Use the robot_status_change function with Robot23 and 'idle' to set Robot23's status to idle after the task is completed.
#     current step:
#         Use the move_robot function with Robot23 and the coordinates (9, 1) to move Robot23 to the desired location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions the use of the 'move_robot' function to move Robot23 to a particular set of coordinates. The Controller is responsible for controlling the robots and has the 'move_robot' tool which is needed to fulfill this request. Therefore, the Controller is the correct worker to act next to execute this function.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot23 and the coordinates (9, 1) to move Robot23 to the desired location.', 'Robot23 has been successfully moved to the position (9, 1).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot23 and 'vehicle' to remove the vehicle from the location.
#         Use the robot_status_change function with Robot23 and 'idle' to set Robot23's status to idle after the task is completed.
#     current step:
#         Use the grab_or_remove_item function with Robot23 and 'vehicle' to remove the vehicle from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action 'grab_or_remove_item' to be performed with Robot23 and the item 'vehicle'. Since the Controller is responsible for controlling the robots and has the tool 'grab_or_remove_item' to grab or remove items, it is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot23 and 'vehicle' to remove the vehicle from the location.", 'Robot23 has successfully grabbed and removed the vehicle from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot23 and 'idle' to set Robot23's status to idle after the task is completed.
#     current step:
#         Use the robot_status_change function with Robot23 and 'idle' to set Robot23's status to idle after the task is completed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested to use the 'robot_status_change' function with Robot23 and 'idle', which falls under the responsibilities of the Controller. The Controller has the toolset necessary to change a robot's status, specifically using the 'robot_status_change' function.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot23 and 'idle' to set Robot23's status to idle after the task is completed.", "Robot23's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot23 with a tow hook has successfully moved to location (9, 1) and removed the vehicle. The robot's status has been set to idle upon completion of the task.
# ---
#
# 8. task: Move Robot28 to location (11, 6) and remove the construction materials.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot28 and the 'front loader' as the desired_robot_tool_property to ensure Robot28 is equipped to handle construction materials.
#     If Robot28 has the 'front loader', use the move_robot function with 'Robot28' as the robot_name and (11, 6) as the desired_position to move Robot28 to the location.
# ...
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with 'Robot29' as the robot_name and (11, 6) as the desired_position to move Robot29 to the location.
#         After Robot29 reaches location (11, 6), use the grab_or_remove_item function with 'Robot29' as the robot_name and 'construction materials' as the item_name to remove the construction materials from the location.
#         Upon successful removal of the construction materials, use the robot_status_change function with 'Robot29' as the robot_name and 'idle' as the status to set Robot29's status to idle.
#     current step:
#         Use the move_robot function with 'Robot29' as the robot_name and (11, 6) as the desired_position to move Robot29 to the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action 'move_robot' with a clear instruction to move 'Robot29' to a specified location (11, 6). Since the Controller is responsible for controlling the robots and has the 'move_robot' function among its tools, it is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the move_robot function with 'Robot29' as the robot_name and (11, 6) as the desired_position to move Robot29 to the location.", 'Robot29 has been successfully moved to the desired position (11, 6).')
# ---
#
# replanner:
#     plan:
#         After Robot29 reaches location (11, 6), use the grab_or_remove_item function with 'Robot29' as the robot_name and 'construction materials' as the item_name to remove the construction materials from the location.
#         Upon successful removal of the construction materials, use the robot_status_change function with 'Robot29' as the robot_name and 'idle' as the status to set Robot29's status to idle.
#     current step:
#         After Robot29 reaches location (11, 6), use the grab_or_remove_item function with 'Robot29' as the robot_name and 'construction materials' as the item_name to remove the construction materials from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with specific tools, including 'move_robot' and 'grab_or_remove_item'. The user request specifies an action that requires a robot, Robot29, to move to a location and then use the grab_or_remove_item function to remove construction materials. Since the robot's name and the item to be interacted with are both specified, the Controller should act next to execute these commands.
# ---
#
# Controller:
#    past steps: ("After Robot29 reaches location (11, 6), use the grab_or_remove_item function with 'Robot29' as the robot_name and 'construction materials' as the item_name to remove the construction materials from the location.", 'Robot29 has successfully reached the location (11, 6) and has grabbed/removed the construction materials from the location.')
# ---
#
# replanner:
#     plan:
#         Upon successful removal of the construction materials, use the robot_status_change function with 'Robot29' as the robot_name and 'idle' as the status to set Robot29's status to idle.
#     current step:
#         Upon successful removal of the construction materials, use the robot_status_change function with 'Robot29' as the robot_name and 'idle' as the status to set Robot29's status to idle.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'robot_status_change' function to set Robot29's status to idle. This function is within the Controller's set of tools, making the Controller the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Upon successful removal of the construction materials, use the robot_status_change function with 'Robot29' as the robot_name and 'idle' as the status to set Robot29's status to idle.", 'Robot29 has successfully removed the construction materials and is now set to idle status.')
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot29, equipped with a front loader, has moved to location (11, 6) and removed the construction materials. Robot29 has now been set to idle status.
# ---
#
# 9. task: Move Robot39 to location (6, 1) and remove the tree branches.
# ---
# planner:
#   plan:
#     Use the 'select_known_robot_tool' with Robot39 and the 'saw' tool property to ensure Robot39 is equipped to remove tree branches.
#     Use the 'move_robot' function to move Robot39 to location (6, 1).
#     Use the 'grab_or_remove_item' to remove the tree branches at location (6, 1).
#     Use the 'robot_status_change' to set Robot39's status to 'idle' after the tree branches have been removed.
#   current step:
#      Use the 'select_known_robot_tool' with Robot39 and the 'saw' tool property to ensure Robot39 is equipped to remove tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has specified a particular robot, Robot39, and a specific tool property, 'saw', that is required for the task. The Robot_selector is responsible for confirming whether the specified robot has the required tool property using the 'select_known_robot_tool'. This will determine if Robot39 is indeed equipped to remove tree branches.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'select_known_robot_tool' with Robot39 and the 'saw' tool property to ensure Robot39 is equipped to remove tree branches.", 'The initial selected tool for removing tree branches was a "saw." However, Robot39 is equipped with a "front loader," which is not suitable for the task of removing tree branches. According to the list of items with associated tool properties, a saw is the appropriate tool for dealing with tree branches. Therefore, Robot39 with a front loader cannot solve the task, as it requires a different tool property that is specifically designed for cutting, which the front loader does not provide.')
# ---
#
# replanner:
#     plan:
#         Use the 'robot_selection_tool' with the 'saw' tool property and item position (6, 1) to select a robot that is equipped to remove tree branches.
#         Use the 'move_robot' function to move the selected robot to location (6, 1).
#         Use the 'grab_or_remove_item' to remove the tree branches at location (6, 1).
#         Use the 'robot_status_change' to set the robot's status to 'idle' after the tree branches have been removed.
#     current step:
#         Use the 'robot_selection_tool' with the 'saw' tool property and item position (6, 1) to select a robot that is equipped to remove tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to select a robot that is equipped with a 'saw' tool property to remove tree branches at a specified position (6, 1). Since the task involves selecting the correct robot for the job and no specific robot has been mentioned, the 'Robot_selector' with the tool 'robot_selection_tool' should be used to determine the best suited robot for this task.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'robot_selection_tool' with the 'saw' tool property and item position (6, 1) to select a robot that is equipped to remove tree branches.", 'Robot24 is the best suited to remove tree branches with its saw tool property at the position (6, 1).')
# ---
#
# replanner:
#     plan:
#         Use the 'move_robot' function to move Robot24 to location (6, 1).
#         Use the 'grab_or_remove_item' to remove the tree branches at location (6, 1).
#         Use the 'robot_status_change' to set Robot24's status to 'idle' after the tree branches have been removed.
#     current step:
#         Use the 'move_robot' function to move Robot24 to location (6, 1).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving moving a robot to a specific location. Since the Controller is responsible for controlling robots and has the 'move_robot' tool that can execute this action, the Controller is the appropriate worker to act next.
# ---
#
# Controller:
#    past steps: ("Use the 'move_robot' function to move Robot24 to location (6, 1).", 'Robot24 has been successfully moved to the location (6, 1).')
# ---
#
# replanner:
#     plan:
#         Use the 'grab_or_remove_item' function with Robot24 to remove the tree branches at location (6, 1).
#         Use the 'robot_status_change' function to set Robot24's status to 'idle' after the tree branches have been removed.
#     current step:
#         Use the 'grab_or_remove_item' function with Robot24 to remove the tree branches at location (6, 1).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action ('grab_or_remove_item') that needs to be performed by a robot (Robot24) at a specific location (6, 1). The Controller is responsible for controlling the robots and has the appropriate tool ('grab_or_remove_item') for this task.
# ---
#
# Controller:
#    past steps: ("Use the 'grab_or_remove_item' function with Robot24 to remove the tree branches at location (6, 1).", 'Robot24 has successfully grabbed/removed the tree branches.')
# ---
#
# replanner:
#     plan:
#         Use the 'robot_status_change' function to set Robot24's status to 'idle' after the tree branches have been removed.
#     current step:
#         Use the 'robot_status_change' function to set Robot24's status to 'idle' after the tree branches have been removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to use the 'robot_status_change' function to set Robot24's status to 'idle', which is a task for the Controller who is responsible for controlling robots and has the 'robot_status_change' tool to change the status of the robots.
# ---
#
# Controller:
#    past steps: ("Use the 'robot_status_change' function to set Robot24's status to 'idle' after the tree branches have been removed.", "The tree branches have been removed and Robot24's status is now set to 'idle'.")
# ---
#
# replanner:
#     response:
#         The objective has been completed. Robot24, equipped with a saw, has successfully moved to location (6, 1) and removed the tree branches. Robot24's status has been set to 'idle' after the completion of the task.
# ---
#
# 10. task: Move Robot28 to location (2, 8) and remove the screws.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify if Robot28 is equipped with a screwdriver tool property.
#     If Robot28 is not equipped with a screwdriver, select a different robot using the robot_selection_tool that has the screwdriver tool property and is closest to (2, 8).
#     Use the move_robot function to move Robot28 or the selected robot to location (2, 8).
#     Use the grab_or_remove_item function to remove the screws at location (2, 8).
#     Use the robot_status_change function to set Robot28 or the selected robot's status to idle after the removal of the screws.
#   current step:
#      Use the select_known_robot_tool to verify if Robot28 is equipped with a screwdriver tool property.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifically mentions the need to use the 'select_known_robot_tool' to verify if Robot28 is equipped with a screwdriver tool property. The Robot_selector is responsible for selecting the correct robot and determining if the robot is equipped with the necessary tool properties to solve the objective. Therefore, routing the current_step to Robot_selector is appropriate to fulfill the user's request.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to verify if Robot28 is equipped with a screwdriver tool property.', 'Robot28 cannot solve the task with the tool property: broom. The initial selected tool was a screwdriver, which is required for tasks involving screws. Since Robot28 is equipped with a broom, which is suitable for dealing with dust or small debris, it is not the appropriate tool for tasks that require screwing or unscrewing. The task requires a screwdriver, and Robot28 does not have this capability.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool to determine the best suited robot with a screwdriver tool property that is closest to (2, 8).
#         Use the move_robot function to move the selected robot to location (2, 8).
#         Use the grab_or_remove_item function to remove the screws at location (2, 8).
#         Use the robot_status_change function to set the robot's status to idle after the removal of the screws.
#     current step:
#         Use the robot_selection_tool to determine the best suited robot with a screwdriver tool property that is closest to (2, 8).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to select the best suited robot with a specific tool property (screwdriver) and proximity to a certain location (2, 8). This falls under the responsibility of the Robot_selector, who has the robot_selection_tool designed for determining the best suited robot based on desired properties and location.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to determine the best suited robot with a screwdriver tool property that is closest to (2, 8).', 'Robot45 is the best suited robot with a screwdriver tool property to handle the task at location (2, 8).')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot45 to location (2, 8).
#         Use the grab_or_remove_item function to remove the screws at location (2, 8).
#         Use the robot_status_change function to set Robot45's status to idle after the removal of the screws.
#     current step:
#         Use the move_robot function to move Robot45 to location (2, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested a specific action involving moving a robot to a desired position. The Controller is responsible for controlling robots and has the 'move_robot' tool, which is needed to move Robot45 to the specified location (2, 8). Therefore, the Controller is the correct worker to act next to fulfill this user request.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function to move Robot45 to location (2, 8).', 'Robot45 has been successfully moved to the location (2, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to remove the screws at location (2, 8).
#         Use the robot_status_change function to set Robot45's status to idle after the removal of the screws.
#     current step:
#         Use the grab_or_remove_item function to remove the screws at location (2, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots, which includes the use of the tool 'grab_or_remove_item'. Since the user request specifies an action that involves removing an item (screws) at a specific location, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to remove the screws at location (2, 8).', 'The robot equipped with a screwdriver has successfully removed the screws and has been moved to the location (2, 8).')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function to set Robot45's status to idle after the removal of the screws.
#     current step:
#         Use the robot_status_change function to set Robot45's status to idle after the removal of the screws.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task requires using the robot_status_change function to set a specific robot's status to idle, which is a function within the Controller's set of tools. Therefore, the Controller is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function to set Robot45's status to idle after the removal of the screws.", 'Robot45 has removed the screws and is now set to idle status.')
# ---
#
# replanner:
#     response:
#         Robot45 equipped with a screwdriver has successfully removed the screws at location (2, 8) and is now set to idle status.
# ---
