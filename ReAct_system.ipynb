# %%
# %%capture --no-stderr
# %pip install -U langchain langimport os langchainhub
# Out:
# ERROR: Could not find a version that satisfies the requirement langimport (from versions: none)
# ERROR: No matching distribution found for langimport
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Initialize environment variables

# %%
import os
os.environ["OPENAI_API_KEY"] = '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'
os.environ["LANGCHAIN_API_KEY"] = 'ls__c0f826e0c4514d678c5fdec4a48e6b92'
os.environ["TAVILY_API_KEY"] = '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'

# %%
# %pip install langchainhub
# Out:
# Requirement already satisfied: langchainhub in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (0.1.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0.20240403)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from google.colab import userdata
import getpass
import os



def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass(f"Please provide your {var}")

_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("LANGCHAIN_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
# os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")
# os.environ["LANGCHAIN_API_KEY"] = userdata.get("LANGCHAIN_API_KEY")

# Optional, add tracing in LangSmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "ReAct plan and execute"

# %% [markdown]
# ## Initialize dummy robots
#
# This code is the simplified version of the actual agent code. This is only to show that the tools for the llm is working with the robot class

# %%
from typing import Tuple
import random

class Agent(object):
    def __init__(self, name, position, color, tool_property, inventory, status="idle"):
        self._name = name
        self._position = position
        self._color = color
        self._goal = None
        self._status = status
        self.tool_property = tool_property
        self._inventory = []
        

    def setGoal(self, goal):
        """Sets the Goal for the robot"""
        self._goal = goal
        self.set_status("active")


    def set_status(self, status="idle"):
        if status in ["idle", "active", "charging"]:
            old_status = self._status
            self._status = status
            if self._status == "idle":
                self._goal = None
    
    def add_item_invetory(self, item):
        self._inventory.append(item)

    @property
    def tool_property(self) -> str:
        """agent tool i.e gripper"""
        return self._tool_property
    
    @tool_property.setter
    def tool_property(self, new_tool):
        self._tool_property = new_tool

    @property
    def inventory(self) -> list:
        """ An agents inventory """
        return self._inventory

    @property
    def position(self) -> Tuple[int, int]:
        """ The position of the agent """
        return self._position

    @position.setter
    def position(self, new_position: Tuple[int, int]):
        """ Set the new position

        :new_position: The new node id

        """
        self._position = new_position

    @property
    def name(self) -> str:
        """ The name of the agent """
        return self._name

    @name.setter
    def name(self, new_name: str):
        """ Sets a new name for the agent

        :new_name: The new name for the agent

        """
        self._name = new_name

    @property
    def color(self) -> str:
        """ The color of the agent """
        return self._color

    @color.setter
    def color(self, new_color: str):
        """ Sets a new color for the agent

        :new_goal: The new color for the agent

        """
        self._color = new_color

    @property
    def goal(self) -> Tuple[int, int]:
        """ The goal of the agent """
        return self._goal

    @goal.setter
    def goal(self, new_goal: Tuple[int, int]):
        """ Set the new goal

        :new_goal: The new goal node id

        """
        self._goal = new_goal

# %%
# Available tools is: lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum
# define agents:  ('name', placement: (x,y), 'color', Property, inventory)
R1 = Agent("Robot1", (12, 4), "aqua", "lawnmower", None, "active")
R2 = Agent("Robot2", (4, 6), "maroon", "gripper", None, "charging")
R3 = Agent("Robot3", (4, 12), "green", "tow hook", None, "active")
R4 = Agent("Robot4", (5, 1), "purple", "saw", None, "active")
R5 = Agent("Robot5", (9, 2), "orange", "welding tool", None, "active")
R6 = Agent("Robot6", (3, 10), "pink", "mop", None, "charging")
R7 = Agent("Robot7", (5, 7), "blue", "spray nozzle", None, "active")
R8 = Agent("Robot8", (8, 3), "olive", "broom", None, "idle")
R9 = Agent("Robot9", (5, 10), "silver", "front loader", None, "charging")
R10 = Agent("Robot10", (10, 6), "cyan", "vacuum", None, "charging")
R11 = Agent("Robot11", (11, 5), "navy", "lawnmower", None, "charging")
R12 = Agent("Robot12", (1, 6), "yellow", "gripper", None, "active")
R13 = Agent("Robot13", (1, 9), "pink", "tow hook", None, "charging")
R14 = Agent("Robot14", (11, 11), "silver", "saw", None, "idle")
R15 = Agent("Robot15", (6, 11), "orange", "welding tool", None, "charging")
R16 = Agent("Robot16", (6, 8), "olive", "mop", None, "active")
R17 = Agent("Robot17", (12, 9), "fuchsia", "spray nozzle", None, "idle")
R18 = Agent("Robot18", (4, 5), "black", "broom", None, "active")
R19 = Agent("Robot19", (3, 12), "magenta", "front loader", None, "idle")
R20 = Agent("Robot20", (5, 9), "black", "vacuum", None, "active")
R21 = Agent("Robot21", (9, 7), "magenta", "lawnmower", None, "charging")
R22 = Agent("Robot22", (8, 11), "blue", "gripper", None, "idle")
R23 = Agent("Robot23", (11, 7), "silver", "tow hook", None, "idle")
R24 = Agent("Robot24", (10, 5), "navy", "saw", None, "idle")
R25 = Agent("Robot25", (10, 11), "white", "welding tool", None, "active")
R26 = Agent("Robot26", (1, 2), "aqua", "mop", None, "idle")
R27 = Agent("Robot27", (2, 1), "white", "spray nozzle", None, "charging")
R28 = Agent("Robot28", (2, 7), "navy", "broom", None, "charging")
R29 = Agent("Robot29", (10, 8), "aqua", "front loader", None, "charging")
R30 = Agent("Robot30", (7, 12), "fuchsia", "vacuum", None, "active")
R31 = Agent("Robot31", (12, 2), "fuchsia", "lawnmower", None, "charging")
R32 = Agent("Robot32", (12, 8), "olive", "gripper", None, "charging")
R33 = Agent("Robot33", (5, 5), "lime", "tow hook", None, "active")
R34 = Agent("Robot34", (8, 4), "black", "saw", None, "active")
R35 = Agent("Robot35", (5, 11), "black", "welding tool", None, "idle")
R36 = Agent("Robot36", (5, 8), "olive", "mop", None, "active")
R37 = Agent("Robot37", (8, 1), "maroon", "spray nozzle", None, "idle")
R38 = Agent("Robot38", (10, 4), "green", "broom", None, "active")
R39 = Agent("Robot39", (1, 1), "yellow", "front loader", None, "idle")
R40 = Agent("Robot40", (11, 3), "magenta", "vacuum", None, "charging")
R41 = Agent("Robot41", (10, 1), "olive", "lawnmower", None, "charging")
R42 = Agent("Robot42", (10, 7), "teal", "gripper", None, "charging")
R43 = Agent("Robot43", (11, 9), "blue", "tow hook", None, "active")
R44 = Agent("Robot44", (9, 6), "fuchsia", "saw", None, "active")
R45 = Agent("Robot45", (2, 3), "blue", "welding tool", None, "idle")
R46 = Agent("Robot46", (1, 7), "black", "mop", None, "active")
R47 = Agent("Robot47", (2, 6), "maroon", "spray nozzle", None, "idle")
R48 = Agent("Robot48", (7, 2), "lime", "broom", None, "idle")
R49 = Agent("Robot49", (6, 9), "orange", "front loader", None, "active")
R50 = Agent("Robot50", (7, 8), "red", "vacuum", None, "idle")


robots = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, 
          R11, R12, R13, R14, R15, R16, R17, R18, R19, R20, 
          R21, R22, R23, R24, R25, R26, R27, R28, R29, R30, 
          R31, R32, R33, R34, R35, R36, R37, R38, R39, R40, 
          R41, R42, R43, R44, R45, R46, R47, R48, R49, R50]

# Extracting used coordinates from the robot definitions and generating a list of coordinates not in use within (12, 12) space.
used_coordinates = []
for robot in robots:
    used_coordinates.append(robot.position)

# Generating all possible coordinates within a 12x12 space
all_coordinates = [(x, y) for x in range(1, 13) for y in range(1, 13)]

# Finding the coordinates not in use
unused_coordinates = [coord for coord in all_coordinates if coord not in used_coordinates]
total = len(unused_coordinates) + len(robots)
if total == 12*12:
    print("correct number of unsued positions")
    print(unused_coordinates)
else:
    print("incorrect number of unsued positions")
# Out:
# correct number of unsued positions
# [(1, 3), (1, 4), (1, 5), (1, 8), (1, 10), (1, 11), (1, 12), (2, 2), (2, 4), (2, 5), (2, 8), (2, 9), (2, 10), (2, 11), (2, 12), (3, 1), (3, 2), (3, 3), (3, 4), (3, 5), (3, 6), (3, 7), (3, 8), (3, 9), (3, 11), (4, 1), (4, 2), (4, 3), (4, 4), (4, 7), (4, 8), (4, 9), (4, 10), (4, 11), (5, 2), (5, 3), (5, 4), (5, 6), (5, 12), (6, 1), (6, 2), (6, 3), (6, 4), (6, 5), (6, 6), (6, 7), (6, 10), (6, 12), (7, 1), (7, 3), (7, 4), (7, 5), (7, 6), (7, 7), (7, 9), (7, 10), (7, 11), (8, 2), (8, 5), (8, 6), (8, 7), (8, 8), (8, 9), (8, 10), (8, 12), (9, 1), (9, 3), (9, 4), (9, 5), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (10, 2), (10, 3), (10, 9), (10, 10), (10, 12), (11, 1), (11, 2), (11, 4), (11, 6), (11, 8), (11, 10), (11, 12), (12, 1), (12, 3), (12, 5), (12, 6), (12, 7), (12, 10), (12, 11), (12, 12)]

# %% [markdown]
# ## Create Tools

# %% [markdown]
# **Helper functions**

# %%
def sort_by_tool(tool_name, robot_list=robots):
    usable_robots = []
    for robot in robot_list:
        if robot.tool_property == tool_name:
            usable_robots.append(robot)
    return usable_robots

def sort_by_availability(robot_list, target_pos):
    available_robots = []
    if robot_list:
        closest_robot = robot_list[0].name
        min_dist = dist_func(robot_list[0].position, target_pos)
        flag = True
        for robot in robot_list:
            if robot._status != "active":
                available_robots.append(robot.name)
                if flag:
                    flag = False
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
                    
                if min_dist > dist_func(robot.position, target_pos):
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
        if available_robots:
            return f"out of available robot: {available_robots}, {closest_robot} is the best suited to solve the task."
    return "no robot with the specified tool to solve the task"

def dist_func(robot_pos, target_pos):
    x_dist = abs(target_pos["x"] - robot_pos[0])
    y_dist = abs(target_pos["y"] - robot_pos[1])
    total_dist = x_dist + y_dist
    return total_dist

def select_known_robot(robot_name, desired_tool, robot_list=robots):
    for robot in robot_list:                
        if robot_name == robot.name:
            if robot._status != "active":
                if desired_tool == robot.tool_property:
                    return f"{robot_name} with the tool property: {robot.tool_property} has been selected to solve the task."
                return f"""{robot_name} is not equipped with the tool property initially selected for task completion. 
                Can {robot_name} with tool property: {robot.tool_property} still solve the task?
                In your anwser please stat the initial selected tool and why {robot_name} can/can't solve the task with the tool property: {robot.tool_property}. 
                """
            return f"{robot_name} is currently active and is not available to solve the task"
    return f"{robot_name} is not a valid robot"

def change_status(robot_name, robot_list=robots, status="idle"):
    for robot in robot_list:
        if robot_name == robot.name:
            old_status = robot._status
            robot.set_status(status)
            return f"{robot.name} has changed status from {old_status} to {status}"

def set_goal(robot_name: str, position: Tuple, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.setGoal(position)
            return robot.goal
        
def add_item_to_inventory(robot_name, item_name, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.add_item_invetory(item_name)

# %% [markdown]
# **LLM tools**

# %%
from typing import Annotated, List, Tuple, Union

from langchain_core.tools import tool
from langsmith import trace

@tool
def move_robot(robot_name: str, position: Tuple) -> str:
    """Moves the Specified robot to the desired position"""
    goal = set_goal(robot_name=robot_name, position=position)
    return f"{robot_name} has been moved to the desired position {goal}"

@tool
def grab_or_remove_item(robot_name: str, item_name: str) -> str:
    """makes the specified robot grab/remove the desired item"""
    add_item_to_inventory(robot_name=robot_name, item_name=item_name)
    return f"{robot_name} has grabed/removed the desired item {item_name}"

@tool
def robot_status_change(robot_name: str, status: str):
    """Changes the status of a robot"""
    return change_status(robot_name=robot_name, status=status)

@tool
def robot_selection_tool(desired_robot_tool_property, 
                         item_position) -> str:
    """Finds the most robots with the desired tool property. Remember that the item_position needs to be a dict of x and y coordinates"""
    sorted_robots = sort_by_tool(desired_robot_tool_property)
    return sort_by_availability(sorted_robots, item_position)
@tool
def select_known_robot_tool(robot_name: str, desired_robot_tool_property) -> str:
    """select the specified robot to solve the task. If the robot does not have the desired tool for the task, then it will ask if the robot still can solve the task.
    This tool does not alter the tools a robot has, but will try to use the selected robot although it might not have the desired tool.
    """
    return select_known_robot(robot_name=robot_name, desired_tool=desired_robot_tool_property)

@tool
def agent_response_tool(input: str, response: str) -> str:
    """this is a tool that returns the response to the input"""
    return response


control_tools = [move_robot, grab_or_remove_item, robot_status_change]
selection_tools = [robot_selection_tool, select_known_robot_tool]
misc_tools = [agent_response_tool]

# %% [markdown]
# ## Define our Execution Agent + state
#
# Let's now start by defining the state the track for this agent.
#
# First, we will need to track the current plan. Let's represent that as a list of strings.
#
# Next, we should track previously executed steps. Let's represent that as a list of tuples (these tuples will contain the step and then the result)
#
# Finally, we need to have some state to represent the final response as well as the original input.

# %%
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import List, Tuple, Annotated, TypedDict
import operator


class PlanExecute(TypedDict):
    input: str
    plan: List[str]
    current_step: str
    # Used to route work. The supervisor calls a function
    # that will update this every time it makes a decision
    next: str
    # The reason behind the member choice
    reasoning: str
    past_steps: Annotated[List[Tuple], operator.add]
    response: List[str]
    robot_name: str
    tool_property: str
    item: str
    item_position: Tuple[int]

# %% [markdown]
# Now we will create the execution agent(s) we want to use to execute tasks.

# %%
from langchain import hub
from langchain.agents import create_openai_functions_agent
from langchain_openai import ChatOpenAI

controller_prompt = """
    You are an agent that control robots actions using the tools available to you.
    remember you are only able to grab/remove the items and not the robots tool property. this is the list of tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].
    which are not to be grabed or removed.
    Work autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.
    """

selector_prompt = """
    You are a agent with the purpose to select the best suited robot for the task. A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].
    If a specified robot is already selected to solve the task, use select_known_robot_tool.
    Here is an example of that.

    EXAMPLE: 
    task = "Move robot_name to location (2, 11) and sort the recyclables."
    Robot = robot_name
    END EXAMPLE

    remember to select the most apropriate tool_property for the task i.e a gripper for a task where something needs to be picked up.
    Work autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.
"""

misc_prompt = """
    You are an agent that can answer general questions and messages that doesn't have anything to do with making a robot solve a complex task.
    Work autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.
    """

prompt = hub.pull("hwchase17/openai-tools-agent")

# %%
import pprint
pprint.pp(prompt.__dict__)
# Out:
# {'name': None,
#  'input_variables': ['agent_scratchpad', 'input'],
#  'input_types': {'chat_history': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]],
#                  'agent_scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]},
#  'output_parser': None,
#  'partial_variables': {},
#  'metadata': {'lc_hub_owner': 'hwchase17',
#               'lc_hub_repo': 'openai-tools-agent',
#               'lc_hub_commit_hash': 'c18672812789a3b9697656dd539edf0120285dcae36396d0b548ae42a4ed66f5'},
#  'tags': None,
#  'messages': [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are a helpful assistant')),
#               MessagesPlaceholder(variable_name='chat_history', optional=True),
#               HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')),
#               MessagesPlaceholder(variable_name='agent_scratchpad')],
#  'validate_template': False}

# %%
from typing import Any, Callable, List, Optional, TypedDict, Union

from langchain.agents import AgentExecutor, create_openai_tools_agent, create_tool_calling_agent
from langgraph.prebuilt import create_agent_executor
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import Runnable
from langchain_core.tools import BaseTool
from langchain_openai import ChatOpenAI

from langgraph.graph import END, StateGraph

def create_executor_agent(
    llm: ChatOpenAI,
    tools: list,
    system_prompt: str,
) -> str:
    """Create a function-calling agent and add it to the graph."""
    system_prompt += """\nWork autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.
    """

    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt,
            ),
            MessagesPlaceholder(variable_name="chat_history", optional=True),
            (
                "human",
                "{input}",
            ),
            # MessagesPlaceholder(variable_name="input"),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
            
            # MessagesPlaceholder(variable_name="messages"),
            # MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )

    agent = create_tool_calling_agent(llm, tools, prompt)
    executor = create_agent_executor(agent, tools)
    return executor


# async def agent_executor_node(state: PlanExecute, agent):
#     task = state.plan[0]
#     agent_response = await agent.ainvoke({"input": task, "chat_history": []})
#     return {
#         "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
#     }

def create_team_supervisor(llm: ChatOpenAI, system_prompt, members) -> str:
    """An LLM-based router."""
    options = members
    function_def = {
        "name": "route",
        "description": "Select the next role.",
        "parameters": {
            "title": "routeSchema",
            "type": "object",
            "properties": {
                "next": {
                    "title": "Next",
                    "anyOf": [
                        {"enum": options},
                    ],
                },
                "reasoning": {
                    "type": "string",
                    "description": "The reason behind the choice of member"
                }
            },
            "required": ["reasoning", "next"],
        },
    }
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            (
                "human",
                "{current_step}",
            ),
            (
                "system",
                "Given the conversation above, who should act next? Select one of: {options}, and remember to give reasoning behind the choice",
            ),
        ]
    ).partial(options=str(options), team_members=", ".join(members))
    return (
        prompt
        | llm.bind_functions(functions=[function_def], function_call="route")
        | JsonOutputFunctionsParser()
    )

# %%
import functools

# Choose the LLM that will drive the agent
llm_supervisor = ChatOpenAI(model="gpt-4-1106-preview")
llm = ChatOpenAI(model="gpt-3.5-turbo-1106")


control_agent = create_executor_agent(
    llm, 
    control_tools, 
    """
    You are an agent that control robots actions using the tools available to you.
    remember you are only able to grab/remove the items and not the robots tool property. this is the list of tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].
     which are not to be grabed or removed.
    """
    )

# robot_control_node = functools.partial(agent_executor_node, agent=control_agent)

robot_selector_agent = create_executor_agent(
    llm,
    selection_tools,
    """
    You are a agent with the purpose to select the best suited robot for the task. A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].
    If a specified robot is already selected to solve the task, use select_known_robot_tool.
    Here is an example of that.

    EXAMPLE: 
    task = "Move robot_name to location (2, 11) and sort the recyclables."
    Robot = robot_name
    END EXAMPLE

    remember to select the most apropriate tool_property for the task i.e a gripper for a task where something needs to be picked up.
    When giving the response, only tell what you have done and nothing else.
"""
)

# robot_selector_node = functools.partial(agent_executor_node, robot_selector_agent)

misc_agent = create_executor_agent(
    llm,
    misc_tools,
    """
    You are an agent that can answer general questions and messages that doesn't have anything to do with making a robot solve a complex task.
    """
)

# misc_node = functools.partial(agent_executor_node, misc_agent)

supervisor_agent = create_team_supervisor(
    llm_supervisor,
    """
    You are a supervisor tasked with routing the current_step to the following workers: Controller, Robot_selector, misc_agent.
    Given the following user request, respond with the worker to act next and the reason behind the choice.
    The selected worker will perform the current_step.

    Controller:
    Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

    tool functionality:
        - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
        - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
        - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

    Robot_selector:
    Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

    tool functionality:
        - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
        - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    misc_agent:
    Reponsible for anwsering more generic questions with tool: [agent_response_tool].
    
    """,
    ["Controller", "Robot_selector", "misc_agent"],
)

# %%
# pprint.pp(control_agent.__dict__)

# %%
# robot_selector_agent.invoke(
#     {"input": ["Which robot should solve the task located at (6, 6)? The task requires a gripper"], "chat_history": []}
# )

# %% [markdown]
# ## Planning Step
#
# Let's now think about creating the planning step. This will use function calling to create a plan.

# %%
from langchain_core.pydantic_v1 import BaseModel


class Plan(BaseModel):
    """Plan to follow in future"""

    steps: List[str] = Field(
        description="different steps to follow, should be in sorted order"
    )
    current_step: str = Field(
        description="the first step to follow as per the steps variable"
    )

# %%
from langchain.chains.openai_functions import create_structured_output_runnable
from langchain_core.prompts import ChatPromptTemplate

control_tools = [move_robot, grab_or_remove_item, robot_status_change]
selection_tools = [robot_selection_tool, select_known_robot_tool]
misc_tools = [agent_response_tool]

planner_prompt = ChatPromptTemplate.from_template(
"""For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

When making the plan, keep in mind the executor agents capabilities:

Controller:
Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

tool functionality:
    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

Robot_selector:
Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

tool functionality:
    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

misc_agent:
Reponsible for anwsering more generic questions with tool: [agent_response_tool].

If there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.

When designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.

A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].

{objective}"""
)
planner = create_structured_output_runnable(
    Plan, ChatOpenAI(model="gpt-4-1106-preview", temperature=0), planner_prompt
)

# %%
pprint.pp(planner_prompt, width=20)
# Out:
# ChatPromptTemplate(input_variables=['objective'], messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['objective'], template='For the given objective, come up with a simple step by step plan. This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.\n\nWhen making the plan, keep in mind the executor agents capabilities:\n\nController:\nReponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].\n\ntool functionality:\n    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.\n    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.\n    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.\n\nRobot_selector:\nReponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]\n\ntool functionality:\n    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.\n    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.\n\nmisc_agent:\nReponsible for anwsering more generic questions with tool: [agent_response_tool].\n\nIf there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.\n\nWhen designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.\n\nA robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].\n\n{objective}'))])

# %%
# planner.invoke(
#     {"objective": "Move to location (5, 4) and sweep the fallen leaves."}
# )

# %% [markdown]
# ## Re-Plan Step
#
# Now, let's create a step that re-does the plan based on the result of the previous step.

# %%
from langchain.chains.openai_functions import create_openai_fn_runnable


class Response(BaseModel):
    """Response to user."""
    robot_name: str = Field(
        description="The robot that solved the task i.e Robot22"
    )
    tool_property: str = Field(
        description="The tool property of {robot_name} i.e gripper"
    )
    item: str = Field(
        description="The item that is being manipulated i.e toolkit"
    )
    item_position: str = Field(
        description="The position of {item} i.e (11, 8)"
    )
    response: str


replanner_prompt = ChatPromptTemplate.from_template(
"""For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

When making the plan, keep in mind the executor agents capabilities:

Controller:
Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

tool functionality:
    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

Robot_selector:
Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

tool functionality:
    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

misc_agent:
Reponsible for anwsering more generic questions with tool: [agent_response_tool].

If there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.

When designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.

A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, welding tool, mop, spray nozzle, broom, front loader, vacuum].

Your objective was this:
{input}

Your original plan was this:
{plan}

You have currently done the follow steps:
{past_steps}

Update your plan accordingly. If no more steps are needed and you can return to the user, then respond with that. Otherwise, fill out the plan. Only add steps to the plan that still NEED to be done. Do not return previously done steps as part of the plan."""
)


replanner = create_openai_fn_runnable(
    [Plan, Response],
    ChatOpenAI(model="gpt-4-1106-preview", temperature=0),
    replanner_prompt,
)

# %% [markdown]
# ## Create the Graph
#
# We can now create the graph!

# %%
def clear_txt(path):
    # Clear the file by opening it in write mode and closing it
    with open(path, "w") as file:
        pass

def write_txt(path, string):
    # Open the file in append mode and write the string
    with open(path, "a") as file:
        file.write(string)

# %%
file_name = "temp_react.txt"

async def controller_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await control_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def robot_selector_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await robot_selector_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def misc_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await misc_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def plan_step(state: PlanExecute):
    plan = await planner.ainvoke({"objective": state["input"]})
    return {"plan": plan.steps, "current_step": plan.current_step}


async def replan_step(state: PlanExecute):
    output = await replanner.ainvoke(state)
    if isinstance(output, Response):
        # return {"response": output.response}
        write_txt(file_name, f"{output.robot_name};{output.tool_property};{output.item};{output.item_position}\n")
        return {"response": output.response, "robot_name": output.robot_name, "tool_property": output.tool_property, "item": output.item, "item_position": output.item_position}
    else:
        return {"plan": output.steps, "current_step": output.current_step}


def should_end(state: PlanExecute):
    if "response" in state and state["response"]:
        return True
    else:
        return False

# %%
from langgraph.graph import StateGraph, END

workflow = StateGraph(PlanExecute)

# Add the plan node
workflow.add_node("planner", plan_step)

# Add supervisor node
workflow.add_node("supervisor", supervisor_agent)

# Add the execution step nodes
workflow.add_node("Controller", controller_execute_step)
workflow.add_node("Robot_selector", robot_selector_execute_step)
workflow.add_node("misc_agent", misc_execute_step)

# Add a replan node
workflow.add_node("replanner", replan_step)

# Define the starting node
workflow.set_entry_point("planner")

# From plan we go to supervisor
workflow.add_edge("planner", "supervisor")

# Supervisor select one of the executor nodes
workflow.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {"Controller": "Controller", "Robot_selector": "Robot_selector", "misc_agent": "misc_agent"}
)

# The executor nodes return to the replanner
workflow.add_edge("Controller", "replanner")
workflow.add_edge("Robot_selector", "replanner")
workflow.add_edge("misc_agent", "replanner")

# If task not completed then replan and go to the supervisor
workflow.add_conditional_edges(
    "replanner",
    # Next, we pass in the function that will determine which node is called next.
    should_end,
    {
        # If `tools`, then we call the tool node.
        True: END,
        False: "supervisor",
    },
)

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable
app = workflow.compile()

# %% [markdown]
# ### Test results

# %%
def task_iteration(file_path):
        task = file_path.readline()
        if not task:
            return False
        return task.strip()

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def process_ReAct_response(name, response):
    output = []

    if name == "planner":
        print(f"{name}:\n  plan:")
        output.append(f"{name}:\n    plan:")
        for step in response["plan"]:
            print(f"    {step}")
            output.append(f"        {step}")
        next_step = response["current_step"]
        print(f"  current step:\n     {next_step}\n---\n")
        output.append(f"    current step:\n       {next_step}\n---\n")

    elif name == "replanner":
        if "plan" in response and response["plan"]:
            print(f"{name}:\n    plan:")
            output.append(f"{name}:\n    plan:")
            for step in response["plan"]:
                print(f"        {step}")
                output.append(f"        {step}")
            next_step = response["current_step"]
            print(f"    current step:\n        {next_step}\n---\n")
            output.append(f"    current step:\n        {next_step}\n---\n")
        elif "response" in response and response["response"]:
            response = response["response"]
            print(f"{name}:\n    response:\n        {response}\n---\n")
            output.append(f"{name}:\n    response:\n        {response}\n---\n")

    elif name == "supervisor":
        print(f"{name}:\n   next agent: {response['next']}\n   reason: {response['reasoning']}\n---\n")
        output.append(f"{name}:\n   next agent: {response['next']}\n   reason: {response['reasoning']}\n---\n")

    else:
        past_steps = response["past_steps"]
        print(f"{name}:\n   past steps: {past_steps}\n---\n")
        output.append(f"{name}:\n   past steps: {past_steps}\n---\n")

    return output

# %% [markdown]
# ## Easy test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Easy_react_matrix.txt"
clear_txt(file_name)

with open("Easy_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 50}
        inputs = {"input": task}
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
        
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('output_Easy_react.xlsx')
# Out:
# 1. task: Move Robot2 to location (3, 11) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with 'Robot2' and 'gripper' to ensure Robot2 is equipped with a gripper capable of removing the toolkit.
#     Use the move_robot function with 'Robot2' and the coordinates (3, 11) to move Robot2 to the specified location.
#     Use the grab_or_remove_item function with 'Robot2' and 'toolkit' to remove the toolkit from the location.
#     Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after completing the task.
#   current step:
#      Use the select_known_robot_tool with 'Robot2' and 'gripper' to ensure Robot2 is equipped with a gripper capable of removing the toolkit.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to ensure that Robot2 is equipped with a gripper capable of removing the toolkit. This task falls under the responsibility of the Robot_selector, who has the tool 'select_known_robot_tool' to determine if the specified robot is equipped with the necessary tool property to solve the objective.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with 'Robot2' and 'gripper' to ensure Robot2 is equipped with a gripper capable of removing the toolkit.", 'The robot "Robot2" with the gripper tool has been selected to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with 'Robot2' and the coordinates (3, 11) to move Robot2 to the specified location.
#         Use the grab_or_remove_item function with 'Robot2' and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after completing the task.
#     current step:
#         Use the move_robot function with 'Robot2' and the coordinates (3, 11) to move Robot2 to the specified location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request directly specifies the use of the 'move_robot' function with 'Robot2' and given coordinates (3, 11). The 'Controller' is responsible for controlling the robots with tools including 'move_robot'. Therefore, the 'Controller' should perform the current_step to move 'Robot2' to the specified location.
# ---
#
# Controller:
#    past steps: ("Use the move_robot function with 'Robot2' and the coordinates (3, 11) to move Robot2 to the specified location.", 'Robot2 has been moved to the desired position (3, 11).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with 'Robot2' and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after completing the task.
#     current step:
#         Use the grab_or_remove_item function with 'Robot2' and 'toolkit' to remove the toolkit from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: Since the user request specifies the action 'grab_or_remove_item' with a specific robot ('Robot2') and an item ('toolkit'), the Controller is the appropriate worker to carry out this task as it is responsible for controlling the robots and has the tool needed to perform the action.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with 'Robot2' and 'toolkit' to remove the toolkit from the location.", 'The toolkit has been removed from the location by Robot2.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after completing the task.
#     current step:
#         Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions using the 'robot_status_change' function to set Robot2's status to 'idle'. This function is within the Controller's set of tools, therefore the Controller is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with 'Robot2' and 'idle' to set Robot2's status to idle after completing the task.", 'The status of Robot2 has been changed to idle.')
# ---
#
# replanner:
#     response:
#         All steps have been completed successfully. No further action is required.
# ---
#
# 2. task: Move Robot6 to location (11, 8) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot6 and the 'mop' tool property to ensure Robot6 is equipped to clean the liquid spill.
#     Use the move_robot function with Robot6 and the coordinates (11, 8) to move Robot6 to the location of the liquid spill.
#     Use the grab_or_remove_item function with Robot6 and the item name 'liquid spill' to clean up the spill.
#     Use the robot_status_change function with Robot6 and the status 'idle' to set Robot6's status after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot6 and the 'mop' tool property to ensure Robot6 is equipped to clean the liquid spill.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for determining if a specific robot has the necessary tool property to accomplish a task. In this case, we need to verify if Robot6 is equipped with a 'mop' tool property to clean the liquid spill, which falls under the responsibilities of the Robot_selector using the select_known_robot_tool.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot6 and the 'mop' tool property to ensure Robot6 is equipped to clean the liquid spill.", "I have used the select_known_robot_tool to ensure that Robot6 with the 'mop' tool property is selected for cleaning the liquid spill.")
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot6 and the coordinates (11, 8) to move Robot6 to the location of the liquid spill.
#         Use the grab_or_remove_item function with Robot6 and the item name 'liquid spill' to clean up the spill.
#         Use the robot_status_change function with Robot6 and the status 'idle' to set Robot6's status after the task is complete.
#     current step:
#         Use the move_robot function with Robot6 and the coordinates (11, 8) to move Robot6 to the location of the liquid spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a direct action for a specific robot (Robot6) to move to a set of coordinates (11, 8). Since the Controller is responsible for controlling the robots and has the tool 'move_robot' to move a specified robot to a given position, it is the correct worker to perform this task.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot6 and the coordinates (11, 8) to move Robot6 to the location of the liquid spill.', 'Robot6 has been moved to the location of the liquid spill.')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot6 and the item name 'liquid spill' to clean up the spill.
#         Use the robot_status_change function with Robot6 and the status 'idle' to set Robot6's status after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot6 and the item name 'liquid spill' to clean up the spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'grab_or_remove_item' function with a particular robot (Robot6) and an item name ('liquid spill'). Since the Controller is responsible for controlling the robots and using tools such as 'move_robot', 'grab_or_remove_item', and 'robot_status_change', it is the appropriate worker to carry out the action of cleaning up the spill with Robot6.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot6 and the item name 'liquid spill' to clean up the spill.", 'The liquid spill has been cleaned up by Robot6.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot6 and the status 'idle' to set Robot6's status after the task is complete.
#     current step:
#         Use the robot_status_change function with Robot6 and the status 'idle' to set Robot6's status after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task requires the use of the 'robot_status_change' function to set Robot6's status to 'idle', which is a tool under the responsibility of the Controller. Therefore, the Controller is the correct worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot6 and the status 'idle' to set Robot6's status after the task is complete.", 'Robot6\'s status has been successfully changed to "idle" after completing the task.')
# ---
#
# replanner:
#     response:
#         All steps of the task have been successfully completed and no further action is required.
# ---
#
# 3. task: Move Robot39 to location (1, 12) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot39 and the 'front loader' tool property to ensure Robot39 is equipped to remove large debris.
#     Use the move_robot tool with Robot39 and the desired position (1, 12) to move Robot39 to the location of the large debris.
#     Use the grab_or_remove_item tool with Robot39 and the item name 'large debris' to remove the debris from the location.
#     Use the robot_status_change tool with Robot39 and set the status to 'idle' after the removal of the debris is complete.
#   current step:
#      Use the select_known_robot_tool with Robot39 and the 'front loader' tool property to ensure Robot39 is equipped to remove large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to ensure that a particular robot, Robot39, is equipped with a 'front loader' tool property to remove large debris. This task falls under the responsibilities of the Robot_selector, who can use the select_known_robot_tool to confirm if Robot39 has the required tool property to complete the objective.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot39 and the 'front loader' tool property to ensure Robot39 is equipped to remove large debris.", "I have selected Robot39 with the 'front loader' tool property to ensure it is equipped to remove large debris.")
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool with Robot39 and the desired position (1, 12) to move Robot39 to the location of the large debris.
#         Use the grab_or_remove_item tool with Robot39 and the item name 'large debris' to remove the debris from the location.
#         Use the robot_status_change tool with Robot39 and set the status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the move_robot tool with Robot39 and the desired position (1, 12) to move Robot39 to the location of the large debris.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a particular robot (Robot39) and a desired position (1, 12) for moving to the location of the large debris. Since the Controller is responsible for controlling the robots with tools that include 'move_robot', it is the appropriate worker to carry out the task of moving Robot39 to the given position.
# ---
#
# Controller:
#    past steps: ('Use the move_robot tool with Robot39 and the desired position (1, 12) to move Robot39 to the location of the large debris.', 'Robot39 has been successfully moved to the location of the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with Robot39 and the item name 'large debris' to remove the debris from the location.
#         Use the robot_status_change tool with Robot39 and set the status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the grab_or_remove_item tool with Robot39 and the item name 'large debris' to remove the debris from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving a particular robot (Robot39) and an item ('large debris'). The Controller is responsible for controlling the robots and has the tool 'grab_or_remove_item' which is needed to remove the item from the robot's location. Therefore, the Controller is the correct worker to act next to execute this task.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item tool with Robot39 and the item name 'large debris' to remove the debris from the location.", 'The large debris has been successfully removed by Robot39.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool with Robot39 and set the status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the robot_status_change tool with Robot39 and set the status to 'idle' after the removal of the debris is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a task (setting Robot39's status to 'idle' after completing an objective) that falls under the responsibilities of the Controller. The Controller has the necessary tool, robot_status_change, to change the status of the robot as requested.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool with Robot39 and set the status to 'idle' after the removal of the debris is complete.", "The debris has been removed, and Robot39's status has been set to 'idle'.")
# ---
#
# replanner:
#     response:
#         All steps have been successfully completed and no further action is required. The objective to move Robot39 to location (1, 12) and remove the large debris has been achieved.
# ---

# %% [markdown]
# ## Medium test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Medium_react_matrix.txt"
clear_txt(file_name)

with open("Medium_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 50}
        inputs = {"input": task}
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
        
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('output_Medium_react.xlsx')
# Out:
# 1. task: Move to location (3, 3) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool to determine the best suited robot to move to location (3, 3) and remove the toolkit.
#     Move the selected robot to location (3, 3) using the move_robot function.
#     Grab the toolkit at location (3, 3) using the grab_or_remove_item function.
#     Set the robot's status to idle using the robot_status_change function after the toolkit has been removed.
#   current step:
#      Use the robot_selection_tool to determine the best suited robot to move to location (3, 3) and remove the toolkit.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves determining the best suited robot to move to a specific location and perform an action (remove the toolkit). Since no specific robot is mentioned, we need to use the robot_selection_tool, which falls under the responsibility of the Robot_selector. Therefore, the Robot_selector should be the next to act to select the appropriate robot for the task.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to determine the best suited robot to move to location (3, 3) and remove the toolkit.', 'I have selected Robot13 with the tow hook to solve the task of moving to location (3, 3) and removing the toolkit.')
# ---
#
# replanner:
#     plan:
#         Move Robot13 to location (3, 3) using the move_robot function.
#         Grab the toolkit at location (3, 3) using the grab_or_remove_item function.
#         Set Robot13's status to idle using the robot_status_change function after the toolkit has been removed.
#     current step:
#         Move Robot13 to location (3, 3) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request clearly specifies which robot (Robot13) to move and the desired position ((3, 3)). The Controller is responsible for controlling the robots and has the tool 'move_robot' which is needed to fulfill this specific task.
# ---
#
# Controller:
#    past steps: ('Move Robot13 to location (3, 3) using the move_robot function.', 'Robot13 has been successfully moved to the desired location (3, 3).')
# ---
#
# replanner:
#     plan:
#         Verify that Robot13 is equipped with a gripper using the select_known_robot_tool function, as a gripper is necessary to grab items.
#         Grab the toolkit at location (3, 3) using the grab_or_remove_item function.
#         Set Robot13's status to idle using the robot_status_change function after the toolkit has been removed.
#     current step:
#         Verify that Robot13 is equipped with a gripper using the select_known_robot_tool function, as a gripper is necessary to grab items.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to verify if a particular robot, Robot13, is equipped with a specific tool property, a gripper. The Robot_selector is responsible for determining if a specified robot is equipped with the required tool property capable of solving the objective using the select_known_robot_tool function. Therefore, the Robot_selector is the correct worker to act next to verify the equipment of Robot13.
# ---
#
# Robot_selector:
#    past steps: ('Verify that Robot13 is equipped with a gripper using the select_known_robot_tool function, as a gripper is necessary to grab items.', 'I have attempted to verify if Robot13 is equipped with a gripper, but it is currently not available to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool to select a robot with a gripper tool property, as it is necessary to grab items, and ensure it is at location (3, 3).
#         Move the selected robot to location (3, 3) using the move_robot function.
#         Grab the toolkit at location (3, 3) using the grab_or_remove_item function.
#         Set the robot's status to idle using the robot_status_change function after the toolkit has been removed.
#     current step:
#         Use the robot_selection_tool to select a robot with a gripper tool property, as it is necessary to grab items, and ensure it is at location (3, 3).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The robot_selection_tool must be used to select a robot with the specific tool property required for the task, which in this case is a gripper. The Robot_selector is responsible for utilizing the robot_selection_tool to find the best-suited robot that can grab items and then ensure it is positioned at the specified location (3, 3).
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to select a robot with a gripper tool property, as it is necessary to grab items, and ensure it is at location (3, 3).', 'I have selected Robot2 with the gripper tool property to solve the task at location (3, 3).')
# ---
#
# replanner:
#     plan:
#         Move Robot2 to location (3, 3) using the move_robot function.
#         Grab the toolkit at location (3, 3) using the grab_or_remove_item function.
#         Set Robot2's status to idle using the robot_status_change function after the toolkit has been removed.
#     current step:
#         Move Robot2 to location (3, 3) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to move a specific robot, Robot2, to a new location. The Controller is responsible for controlling the robots with tools including 'move_robot'. Since the robot's name and the desired position are both specified, the Controller should use the 'move_robot' function to carry out this task.
# ---
#
# Controller:
#    past steps: ('Move Robot2 to location (3, 3) using the move_robot function.', 'Robot2 has been moved to the desired position (3, 3)')
# ---
#
# replanner:
#     plan:
#         Grab the toolkit at location (3, 3) using the grab_or_remove_item function with Robot2.
#         Set Robot2's status to idle using the robot_status_change function after the toolkit has been removed.
#     current step:
#         Grab the toolkit at location (3, 3) using the grab_or_remove_item function with Robot2.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action to be performed by a robot, namely 'Robot2', to grab an item, and the exact function 'grab_or_remove_item' to be used. The Controller is responsible for controlling the robots and using the tools provided, which includes the 'grab_or_remove_item' function. Therefore, the Controller is the correct worker to act next to execute the requested action.
# ---
#
# Controller:
#    past steps: ('Grab the toolkit at location (3, 3) using the grab_or_remove_item function with Robot2.', 'The toolkit at location (3, 3) has been successfully grabbed by Robot2.')
# ---
#
# replanner:
#     plan:
#         Set Robot2's status to idle using the robot_status_change function after the toolkit has been removed.
#     current step:
#         Set Robot2's status to idle using the robot_status_change function after the toolkit has been removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with a set of tools including the robot_status_change function. The task requires setting Robot2's status to idle after the toolkit has been removed, which falls under the Controller's capabilities.
# ---
#
# Controller:
#    past steps: ("Set Robot2's status to idle using the robot_status_change function after the toolkit has been removed.", "Robot2's status has been successfully changed to idle after the toolkit has been removed.")
# ---
#
# replanner:
#     response:
#         The objective is complete. No further steps are required.
# ---
#
# 2. task: Move to location (9, 5) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use the robot_selector's robot_selection_tool with the 'mop' or 'vacuum' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).
#     Use the Controller's move_robot function to move the selected robot to location (9, 5).
#     Use the Controller's grab_or_remove_item function with the robot's name and 'liquid spill' as the item name to clean up the spill.
#     Use the Controller's robot_status_change function to set the robot's status to 'idle' after the cleanup is complete.
#   current step:
#      Use the robot_selector's robot_selection_tool with the 'mop' or 'vacuum' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: Since the objective requires selecting a robot with a specific tool property ('mop' or 'vacuum') to clean a spill at a specific location, and no robot has been specified, the robot_selection_tool from the Robot_selector is the appropriate tool to determine the best suited robot for this task.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selector's robot_selection_tool with the 'mop' or 'vacuum' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).", 'It seems that there are no robots with the specified tools to clean the liquid spill at location (9, 5).')
# ---
#
# replanner:
#     plan:
#         Use the robot_selector's robot_selection_tool with the 'spray nozzle' or 'broom' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).
#         Use the Controller's move_robot function to move the selected robot to location (9, 5).
#         Use the Controller's grab_or_remove_item function with the robot's name and 'liquid spill' as the item name to clean up the spill.
#         Use the Controller's robot_status_change function to set the robot's status to 'idle' after the cleanup is complete.
#     current step:
#         Use the robot_selector's robot_selection_tool with the 'spray nozzle' or 'broom' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector should be used in this situation because the user request involves selecting the correct robot equipped with the necessary tool property, either a 'spray nozzle' or 'broom', to clean a liquid spill at a specific location. The robot_selection_tool is designed to determine the best suited robot to solve the objective when no specific robot is mentioned, making the Robot_selector the appropriate worker to act next.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selector's robot_selection_tool with the 'spray nozzle' or 'broom' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).", 'I was unable to find a robot with the specified tool to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selector's robot_selection_tool with the 'mop' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).
#         If a robot with a 'mop' is not available, use the robot_selection_tool with the 'vacuum' tool property.
#         Use the Controller's move_robot function to move the selected robot to location (9, 5).
#         Use the Controller's grab_or_remove_item function with the robot's name and 'liquid spill' as the item name to clean up the spill.
#         Use the Controller's robot_status_change function to set the robot's status to 'idle' after the cleanup is complete.
#     current step:
#         Use the robot_selector's robot_selection_tool with the 'mop' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to find a robot capable of cleaning a liquid spill, which requires a robot with a 'mop' tool property. The Robot_selector is the appropriate worker to handle this request because it has the tool 'robot_selection_tool' that is used to determine the best suited robot for a given objective when no specific robot is mentioned. In this case, the objective is to clean a spill at a specific location, and the desired robot tool property is 'mop'.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selector's robot_selection_tool with the 'mop' tool property to find a robot capable of cleaning the liquid spill at location (9, 5).", "I have used the robot_selector's robot_selection_tool to find the robot capable of cleaning the liquid spill at location (9, 5) using the 'mop' tool property. Robot6 has been selected as the best suited robot for the task.")
# ---
#
# replanner:
#     plan:
#         Use the Controller's move_robot function to move Robot6 to location (9, 5).
#         Use the Controller's grab_or_remove_item function with Robot6's name and 'liquid spill' as the item name to clean up the spill.
#         Use the Controller's robot_status_change function to set Robot6's status to 'idle' after the cleanup is complete.
#     current step:
#         Use the Controller's move_robot function to move Robot6 to location (9, 5).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action for a particular robot, Robot6, to be moved to a specific location (9, 5). This falls under the Controller's responsibilities, specifically using the move_robot tool to move the selected robot to the given position.
# ---
#
# Controller:
#    past steps: ("Use the Controller's move_robot function to move Robot6 to location (9, 5).", 'Robot6 has been moved to the desired position (9, 5)')
# ---
#
# replanner:
#     plan:
#         Use the Controller's grab_or_remove_item function with Robot6's name and 'liquid spill' as the item name to clean up the spill.
#         Use the Controller's robot_status_change function to set Robot6's status to 'idle' after the cleanup is complete.
#     current step:
#         Use the Controller's grab_or_remove_item function with Robot6's name and 'liquid spill' as the item name to clean up the spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The request specifies the use of the Controller's function 'grab_or_remove_item' with a particular robot, Robot6, and a specific item, 'liquid spill'. Since the robot and the action are clearly mentioned, the Controller is the appropriate worker to carry out the task.
# ---
#
# Controller:
#    past steps: ("Use the Controller's grab_or_remove_item function with Robot6's name and 'liquid spill' as the item name to clean up the spill.", 'The liquid spill has been successfully cleaned up by Robot6.')
# ---
#
# replanner:
#     plan:
#         Use the Controller's robot_status_change function to set Robot6's status to 'idle' after the cleanup is complete.
#     current step:
#         Use the Controller's robot_status_change function to set Robot6's status to 'idle' after the cleanup is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested to use the Controller's tool, specifically the robot_status_change function, to set Robot6's status to 'idle' after completing its cleanup task. Since the request pertains to controlling a robot's status, which falls under the Controller's responsibilities, the Controller is the appropriate worker to act next.
# ---
#
# Controller:
#    past steps: ("Use the Controller's robot_status_change function to set Robot6's status to 'idle' after the cleanup is complete.", 'The status of Robot6 has been set to "idle" after the cleanup is complete.')
# ---
#
# replanner:
#     response:
#         The objective is complete. Robot6 has successfully cleaned up the liquid spill at location (9, 5) and its status has been set to 'idle'. No further steps are required.
# ---
#
# 3. task: Move to location (3, 4) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to check if the specified robot has a 'front loader' or 'gripper' tool property to handle large debris.
#     Use the move_robot function to move the selected robot to the location (3, 4).
#     Use the grab_or_remove_item function to remove the large debris from the location (3, 4).
#     Use the robot_status_change function to set the robot's status to 'idle' after the removal of the debris is complete.
#   current step:
#      Use the select_known_robot_tool to check if the specified robot has a 'front loader' or 'gripper' tool property to handle large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to check if a specified robot has certain tool properties ('front loader' or 'gripper') to handle large debris. The Robot_selector is responsible for selecting the correct robot and determining if a robot is equipped with the necessary tool properties to solve a given objective, which aligns with the user's request. Therefore, the Robot_selector should use the select_known_robot_tool to verify the robot's capabilities.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool to check if the specified robot has a 'front loader' or 'gripper' tool property to handle large debris.", 'I was unable to find a robot with the specified tool property to handle large debris.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool to determine the best suited robot with a 'front loader' or 'gripper' tool property to handle large debris at location (3, 4).
#         Use the move_robot function to move the selected robot to the location (3, 4).
#         Use the grab_or_remove_item function to remove the large debris from the location (3, 4).
#         Use the robot_status_change function to set the robot's status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the robot_selection_tool to determine the best suited robot with a 'front loader' or 'gripper' tool property to handle large debris at location (3, 4).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifically asks for the use of the 'robot_selection_tool' to determine the best-suited robot with either a 'front loader' or 'gripper' tool property to handle large debris at a specific location. The Robot_selector is responsible for selecting the correct robot and has the necessary tool to fulfill this request.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool to determine the best suited robot with a 'front loader' or 'gripper' tool property to handle large debris at location (3, 4).", 'Robot39 with the tool property: front loader and Robot2 with the tool property: gripper have been selected to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot39 or Robot2 to the location (3, 4).
#         Use the grab_or_remove_item function to remove the large debris from the location (3, 4) with the selected robot.
#         Use the robot_status_change function to set the robot's status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the move_robot function to move Robot39 or Robot2 to the location (3, 4).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: Since the user request specifies an action that involves moving a robot but does not indicate which robot is currently best suited for the task, the Robot_selector should be used to determine which of the specified robots (Robot39 or Robot2) is best equipped to move to the location (3, 4). The Robot_selector has the tools necessary to make this determination.
# ---
#
# Robot_selector:
#    past steps: ('Use the move_robot function to move Robot39 or Robot2 to the location (3, 4).', 'I have selected Robot39 with the front loader tool to move to the location (3, 4).')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function to move Robot39 to the location (3, 4).
#         Use the grab_or_remove_item function to remove the large debris from the location (3, 4) with Robot39.
#         Use the robot_status_change function to set Robot39's status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the grab_or_remove_item function to remove the large debris from the location (3, 4) with Robot39.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task directly involves a specific robot, Robot39, and specifies an action, 'grab_or_remove_item', which falls under the Controller's set of tools. Since the robot and the action are already defined, there is no need for the Robot_selector to select a robot or assess its capabilities. The Controller can directly use the 'grab_or_remove_item' function to remove the large debris from the specified location.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function to move Robot39 to the location (3, 4).', 'Robot39 has been successfully moved to the location (3, 4).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to remove the large debris from the location (3, 4) with Robot39.
#         Use the robot_status_change function to set Robot39's status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the grab_or_remove_item function to remove the large debris from the location (3, 4) with Robot39.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified the robot (Robot39) and the action (remove the large debris) at a particular location (3, 4). The Controller is responsible for controlling the robots and using tools such as grab_or_remove_item, which is the required action. Therefore, the Controller is the appropriate worker to act next to perform the current_step.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to remove the large debris from the location (3, 4) with Robot39.', 'The large debris has been successfully removed from the location (3, 4) by Robot39.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function to set Robot39's status to 'idle' after the removal of the debris is complete.
#     current step:
#         Use the robot_status_change function to set Robot39's status to 'idle' after the removal of the debris is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with the set of tools provided. Since the user request specifically asks to use the 'robot_status_change' function to set Robot39's status to 'idle' after completing an objective, the Controller is the appropriate worker to carry out this step using the 'robot_status_change' tool.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function to set Robot39's status to 'idle' after the removal of the debris is complete.", "The status of Robot39 has been set to 'idle' after the removal of the debris is complete.")
# ---
#
# replanner:
#     response:
#         The task is complete. Robot39 with the front loader tool property has successfully moved to location (3, 4), removed the large debris, and its status has been set to 'idle'. No further steps are needed.
# ---

# %% [markdown]
# ## Hard test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Hard_react_matrix.txt"
clear_txt(file_name)

with open("Hard_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 50}
        inputs = {"input": task}
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
        
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('output_Hard_react.xlsx')
# Out:
# 1. task: Move Robot35 to location (7, 5) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot35 and the 'gripper' tool property to ensure Robot35 is equipped to grab the toolkit.
#     Use the move_robot function with Robot35 and the coordinates (7, 5) to move Robot35 to the location of the toolkit.
#     Use the grab_or_remove_item function with Robot35 and 'toolkit' to remove the toolkit from the location.
#     Use the robot_status_change function with Robot35 and 'idle' to set Robot35's status to idle after completing the task.
#   current step:
#      Use the select_known_robot_tool with Robot35 and the 'gripper' tool property to ensure Robot35 is equipped to grab the toolkit.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The task requires confirmation that Robot35 has the necessary 'gripper' tool property to grab the toolkit. The Robot_selector is responsible for verifying if a specified robot is equipped with the required tool property using the 'select_known_robot_tool'. Therefore, the Robot_selector should act next to ensure Robot35 is capable of performing the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot35 and the 'gripper' tool property to ensure Robot35 is equipped to grab the toolkit.", 'I have selected Robot35 with the tool property: welding tool to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with the 'gripper' tool property and the coordinates (7, 5) to determine the best suited robot to solve the objective since Robot35 does not have the required tool property.
#         Use the move_robot function with the selected robot and the coordinates (7, 5) to move the robot to the location of the toolkit.
#         Use the grab_or_remove_item function with the selected robot and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with the selected robot and 'idle' to set the robot's status to idle after completing the task.
#     current step:
#         Use the robot_selection_tool with the 'gripper' tool property and the coordinates (7, 5) to determine the best suited robot to solve the objective since Robot35 does not have the required tool property.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request implies that a robot with a specific tool property ('gripper') is needed and that the task involves coordinates (7, 5). Since the request also mentions that Robot35 does not have the required tool property, the Robot_selector should use the robot_selection_tool to determine the best suited robot that has the 'gripper' tool property and can reach the coordinates (7, 5) to fulfill the objective.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with the 'gripper' tool property and the coordinates (7, 5) to determine the best suited robot to solve the objective since Robot35 does not have the required tool property.", 'I have selected Robot2 with the gripper tool property to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot2 and the coordinates (7, 5) to move the robot to the location of the toolkit.
#         Use the grab_or_remove_item function with Robot2 and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with Robot2 and 'idle' to set the robot's status to idle after completing the task.
#     current step:
#         Use the move_robot function with Robot2 and the coordinates (7, 5) to move the robot to the location of the toolkit.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action (move_robot) that falls under the Controller's responsibilities. The Controller has the move_robot tool, which is used to move a specified robot to a given position. The request also provides the specific robot (Robot2) and the desired position (coordinates 7, 5), which is required information for the move_robot function.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot2 and the coordinates (7, 5) to move the robot to the location of the toolkit.', 'Robot2 has been moved to the desired position (7, 5) to access the toolkit.')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot2 and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with Robot2 and 'idle' to set the robot's status to idle after completing the task.
#     current step:
#         Use the grab_or_remove_item function with Robot2 and 'toolkit' to remove the toolkit from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to 'use the grab_or_remove_item function with Robot2 and 'toolkit'' which is a direct instruction to manipulate an item using a specific robot. The Controller is responsible for controlling the robots and has the 'grab_or_remove_item' tool to execute this task. Therefore, the Controller should act next to remove the toolkit from the location using Robot2.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot2 and 'toolkit' to remove the toolkit from the location.", 'The toolkit has been successfully removed by Robot2.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot2 and 'idle' to set the robot's status to idle after completing the task.
#     current step:
#         Use the robot_status_change function with Robot2 and 'idle' to set the robot's status to idle after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots and has the tool robot_status_change which is needed to change the robot's status to idle after completing its task. Therefore, the Controller is the correct worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot2 and 'idle' to set the robot's status to idle after completing the task.", 'The status of Robot2 has been successfully changed to "idle."')
# ---
#
# replanner:
#     response:
#         The task has been completed successfully. No further steps are required.
# ---
#
# 2. task: Move Robot31 to location (6, 2) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot31 and the 'mop' tool property to ensure Robot31 is equipped to clean the liquid spill.
#     Use the move_robot function with Robot31 and the desired position (6, 2) to move Robot31 to the location of the liquid spill.
#     Use the grab_or_remove_item function with Robot31 and the item name 'liquid spill' to clean up the spill.
#     Use the robot_status_change function with Robot31 and the status 'idle' to set Robot31's status to idle after the cleanup is complete.
#   current step:
#      Use the select_known_robot_tool with Robot31 and the 'mop' tool property to ensure Robot31 is equipped to clean the liquid spill.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector should be utilized to confirm that Robot31 is equipped with the necessary 'mop' tool property to address the task of cleaning the liquid spill. This is in line with the select_known_robot_tool's purpose, which is to verify if a specified robot has the required tool property to complete the given objective.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot31 and the 'mop' tool property to ensure Robot31 is equipped to clean the liquid spill.", "I have selected Robot31 with the tool property 'lawnmower' to solve the task.")
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with the 'mop' tool property and the item position (6, 2) to determine the best suited robot to clean the liquid spill.
#         Use the move_robot function with the selected robot and the desired position (6, 2) to move the robot to the location of the liquid spill.
#         Use the grab_or_remove_item function with the selected robot and the item name 'liquid spill' to clean up the spill.
#         Use the robot_status_change function with the selected robot and the status 'idle' to set the robot's status to idle after the cleanup is complete.
#     current step:
#         Use the robot_selection_tool with the 'mop' tool property and the item position (6, 2) to determine the best suited robot to clean the liquid spill.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves selecting the best suited robot to clean a liquid spill using a specific tool property ('mop'). The Robot_selector is responsible for selecting the correct robot based on desired tool properties and item positions, which aligns with the user's request. Therefore, the Robot_selector should use the robot_selection_tool to determine the best robot for the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with the 'mop' tool property and the item position (6, 2) to determine the best suited robot to clean the liquid spill.", 'I have used the robot_selection_tool to determine that Robot26 is the best suited to clean the liquid spill with a mop tool.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot26 and the desired position (6, 2) to move the robot to the location of the liquid spill.
#         Use the grab_or_remove_item function with Robot26 and the item name 'liquid spill' to clean up the spill.
#         Use the robot_status_change function with Robot26 and the status 'idle' to set the robot's status to idle after the cleanup is complete.
#     current step:
#         Use the move_robot function with Robot26 and the desired position (6, 2) to move the robot to the location of the liquid spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a direct action involving the movement of a particular robot, Robot26, to a specific position (6, 2). The Controller is responsible for controlling the robots and has the tool 'move_robot' which is needed to execute this action. Therefore, the Controller is the correct worker to act next to move Robot26 to the desired position to address the liquid spill.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot26 and the desired position (6, 2) to move the robot to the location of the liquid spill.', 'The robot has been moved to the location of the liquid spill and has grabbed the mop to clean it up.')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot26 and the item name 'liquid spill' to clean up the spill.
#         Use the robot_status_change function with Robot26 and the status 'idle' to set the robot's status to idle after the cleanup is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot26 and the item name 'liquid spill' to clean up the spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action 'grab_or_remove_item' with a particular robot (Robot26) and an item ('liquid spill'). Since the Controller is responsible for using tools like 'grab_or_remove_item', and the robot as well as the item are specified, it is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot26 and the item name 'liquid spill' to clean up the spill.", 'The liquid spill has been successfully cleaned up by Robot26.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot26 and the status 'idle' to set the robot's status to idle after the cleanup is complete.
#     current step:
#         Use the robot_status_change function with Robot26 and the status 'idle' to set the robot's status to idle after the cleanup is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to use the 'robot_status_change' function to set Robot26's status to 'idle' after the cleanup is complete. The 'robot_status_change' function is one of the tools that the Controller is responsible for, hence the Controller is the correct worker to act next to perform this task.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot26 and the status 'idle' to set the robot's status to idle after the cleanup is complete.", 'The status of Robot26 has been successfully changed to "idle" after the cleanup is complete.')
# ---
#
# replanner:
#     response:
#         The task has been completed successfully. Robot26 equipped with a mop has cleaned up the liquid spill at location (6, 2) and its status has been set to 'idle'. No further steps are required.
# ---
#
# 3. task: Move Robot41 to location (12, 12) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot41 and a tool property example 'front loader' to ensure Robot41 is equipped to remove large debris.
#     Use the move_robot function with Robot41 and the desired position (12, 12) to move Robot41 to the location of the large debris.
#     Use the grab_or_remove_item function with Robot41 and the item name 'large debris' to remove the debris from the location.
#     Use the robot_status_change function with Robot41 and status 'idle' to set Robot41's status to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot41 and a tool property example 'front loader' to ensure Robot41 is equipped to remove large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to ensure that a particular robot, Robot41, is equipped with a specific tool property, in this case, a 'front loader' for the task of removing large debris. The Robot_selector is responsible for determining if a specified robot has the required tool property to solve the objective using the select_known_robot_tool. Therefore, the Robot_selector should act next to verify that Robot41 has a 'front loader' attachment.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot41 and a tool property example 'front loader' to ensure Robot41 is equipped to remove large debris.", 'I have selected Robot41 with the tool property "lawnmower" to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot41 and the desired position (12, 12) to move Robot41 to the location of the large debris.
#         Use the grab_or_remove_item function with Robot41 and the item name 'large debris' to remove the debris from the location.
#         Use the robot_status_change function with Robot41 and status 'idle' to set Robot41's status to idle after the task is complete.
#     current step:
#         Use the move_robot function with Robot41 and the desired position (12, 12) to move Robot41 to the location of the large debris.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to move a robot, Robot41, to a particular position (12, 12) to handle large debris. The Controller is the appropriate worker for this task because one of the tools it is responsible for is 'move_robot', which is used to move a selected robot to a given position. Since the robot name and desired position are both provided, the Controller can directly use the 'move_robot' tool to fulfill this request.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot41 and the desired position (12, 12) to move Robot41 to the location of the large debris.', 'The robot has been successfully moved to the desired position (12, 12) to address the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot41 and the item name 'large debris' to remove the debris from the location.
#         Use the robot_status_change function with Robot41 and status 'idle' to set Robot41's status to idle after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot41 and the item name 'large debris' to remove the debris from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for using the tool 'grab_or_remove_item' to manage items in the robot's vicinity. Since the user has requested the use of 'grab_or_remove_item' with Robot41 and the item 'large debris', the Controller is the correct worker to perform this current step.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot41 and the item name 'large debris' to remove the debris from the location.", 'The large debris has been successfully removed by Robot41.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot41 and status 'idle' to set Robot41's status to idle after the task is complete.
#     current step:
#         Use the robot_status_change function with Robot41 and status 'idle' to set Robot41's status to idle after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested to use the 'robot_status_change' function to set Robot41's status to 'idle', which is one of the tools controlled by the Controller. Therefore, the Controller should act next to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot41 and status 'idle' to set Robot41's status to idle after the task is complete.", 'Robot41\'s status has been successfully changed to "idle" after completing the task.')
# ---
#
# replanner:
#     response:
#         All steps of the task have been successfully completed and no further action is required.
# ---
