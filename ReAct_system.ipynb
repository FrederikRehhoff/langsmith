# %%
# %%capture --no-stderr
# %pip install -U langchain langimport os langchainhub
# Out:
# ERROR: Could not find a version that satisfies the requirement langimport (from versions: none)
# ERROR: No matching distribution found for langimport
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Initialize environment variables

# %%
import os
os.environ["OPENAI_API_KEY"] = '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'
os.environ["LANGCHAIN_API_KEY"] = 'ls__c0f826e0c4514d678c5fdec4a48e6b92'
os.environ["TAVILY_API_KEY"] = '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'

# %%
# %pip install langchainhub
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchainhub in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (0.1.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from langchainhub) (2.31.0.20240403)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchainhub) (2024.2.2)
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from google.colab import userdata
import getpass
import os



def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass(f"Please provide your {var}")

_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("LANGCHAIN_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
# os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")
# os.environ["LANGCHAIN_API_KEY"] = userdata.get("LANGCHAIN_API_KEY")

# Optional, add tracing in LangSmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "ReAct"

# %% [markdown]
# ## Initialize dummy robots
#
# This code is the simplified version of the actual agent code. This is only to show that the tools for the llm is working with the robot class

# %%
from typing import Tuple
import random

class Agent(object):
    def __init__(self, name, position, color, tool_property, inventory, status="idle"):
        self._name = name
        self._position = position
        self._color = color
        self._goal = None
        self._status = status
        self.tool_property = tool_property
        self._inventory = []
        

    def setGoal(self, goal):
        """Sets the Goal for the robot"""
        self._goal = goal
        self.set_status("active")


    def set_status(self, status="idle"):
        if status in ["idle", "active", "charging"]:
            old_status = self._status
            self._status = status
            if self._status == "idle":
                self._goal = None
    
    def add_item_invetory(self, item):
        self._inventory.append(item)

    @property
    def tool_property(self) -> str:
        """agent tool i.e gripper"""
        return self._tool_property
    
    @tool_property.setter
    def tool_property(self, new_tool):
        self._tool_property = new_tool

    @property
    def inventory(self) -> list:
        """ An agents inventory """
        return self._inventory

    @property
    def position(self) -> Tuple[int, int]:
        """ The position of the agent """
        return self._position

    @position.setter
    def position(self, new_position: Tuple[int, int]):
        """ Set the new position

        :new_position: The new node id

        """
        self._position = new_position

    @property
    def name(self) -> str:
        """ The name of the agent """
        return self._name

    @name.setter
    def name(self, new_name: str):
        """ Sets a new name for the agent

        :new_name: The new name for the agent

        """
        self._name = new_name

    @property
    def color(self) -> str:
        """ The color of the agent """
        return self._color

    @color.setter
    def color(self, new_color: str):
        """ Sets a new color for the agent

        :new_goal: The new color for the agent

        """
        self._color = new_color

    @property
    def goal(self) -> Tuple[int, int]:
        """ The goal of the agent """
        return self._goal

    @goal.setter
    def goal(self, new_goal: Tuple[int, int]):
        """ Set the new goal

        :new_goal: The new goal node id

        """
        self._goal = new_goal

# %%
# Available tools is: lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum
# define agents:  ('name', placement: (x,y), 'color', Property, inventory)
R1 = Agent("Robot1", (12, 4), "aqua", "lawnmower", None, "active")
R2 = Agent("Robot2", (4, 6), "maroon", "gripper", None, "charging")
R3 = Agent("Robot3", (4, 12), "green", "tow hook", None, "active")
R4 = Agent("Robot4", (5, 1), "purple", "saw", None, "active")
R5 = Agent("Robot5", (9, 2), "orange", "screwdriver", None, "active")
R6 = Agent("Robot6", (3, 10), "pink", "mop", None, "charging")
R7 = Agent("Robot7", (5, 7), "blue", "spray nozzle", None, "active")
R8 = Agent("Robot8", (8, 3), "olive", "broom", None, "idle")
R9 = Agent("Robot9", (5, 10), "silver", "front loader", None, "charging")
R10 = Agent("Robot10", (10, 6), "cyan", "vacuum", None, "charging")
R11 = Agent("Robot11", (11, 5), "navy", "lawnmower", None, "charging")
R12 = Agent("Robot12", (1, 6), "yellow", "gripper", None, "active")
R13 = Agent("Robot13", (1, 9), "pink", "tow hook", None, "charging")
R14 = Agent("Robot14", (11, 11), "silver", "saw", None, "idle")
R15 = Agent("Robot15", (6, 11), "orange", "screwdriver", None, "charging")
R16 = Agent("Robot16", (6, 8), "olive", "mop", None, "active")
R17 = Agent("Robot17", (12, 9), "fuchsia", "spray nozzle", None, "idle")
R18 = Agent("Robot18", (4, 5), "black", "broom", None, "active")
R19 = Agent("Robot19", (3, 12), "magenta", "front loader", None, "idle")
R20 = Agent("Robot20", (5, 9), "black", "vacuum", None, "active")
R21 = Agent("Robot21", (9, 7), "magenta", "lawnmower", None, "charging")
R22 = Agent("Robot22", (8, 11), "blue", "gripper", None, "idle")
R23 = Agent("Robot23", (11, 7), "silver", "tow hook", None, "idle")
R24 = Agent("Robot24", (10, 5), "navy", "saw", None, "idle")
R25 = Agent("Robot25", (10, 11), "white", "screwdriver", None, "active")
R26 = Agent("Robot26", (1, 2), "aqua", "mop", None, "idle")
R27 = Agent("Robot27", (2, 1), "white", "spray nozzle", None, "charging")
R28 = Agent("Robot28", (2, 7), "navy", "broom", None, "charging")
R29 = Agent("Robot29", (10, 8), "aqua", "front loader", None, "charging")
R30 = Agent("Robot30", (7, 12), "fuchsia", "vacuum", None, "active")
R31 = Agent("Robot31", (12, 2), "fuchsia", "lawnmower", None, "charging")
R32 = Agent("Robot32", (12, 8), "olive", "gripper", None, "charging")
R33 = Agent("Robot33", (5, 5), "lime", "tow hook", None, "active")
R34 = Agent("Robot34", (8, 4), "black", "saw", None, "active")
R35 = Agent("Robot35", (5, 11), "black", "screwdriver", None, "idle")
R36 = Agent("Robot36", (5, 8), "olive", "mop", None, "active")
R37 = Agent("Robot37", (8, 1), "maroon", "spray nozzle", None, "idle")
R38 = Agent("Robot38", (10, 4), "green", "broom", None, "active")
R39 = Agent("Robot39", (1, 1), "yellow", "front loader", None, "idle")
R40 = Agent("Robot40", (11, 3), "magenta", "vacuum", None, "charging")
R41 = Agent("Robot41", (10, 1), "olive", "lawnmower", None, "charging")
R42 = Agent("Robot42", (10, 7), "teal", "gripper", None, "charging")
R43 = Agent("Robot43", (11, 9), "blue", "tow hook", None, "active")
R44 = Agent("Robot44", (9, 6), "fuchsia", "saw", None, "active")
R45 = Agent("Robot45", (2, 3), "blue", "screwdriver", None, "idle")
R46 = Agent("Robot46", (1, 7), "black", "mop", None, "active")
R47 = Agent("Robot47", (2, 6), "maroon", "spray nozzle", None, "idle")
R48 = Agent("Robot48", (7, 2), "lime", "broom", None, "idle")
R49 = Agent("Robot49", (6, 9), "orange", "front loader", None, "active")
R50 = Agent("Robot50", (7, 8), "red", "vacuum", None, "idle")


robots = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, 
          R11, R12, R13, R14, R15, R16, R17, R18, R19, R20, 
          R21, R22, R23, R24, R25, R26, R27, R28, R29, R30, 
          R31, R32, R33, R34, R35, R36, R37, R38, R39, R40, 
          R41, R42, R43, R44, R45, R46, R47, R48, R49, R50]

# Extracting used coordinates from the robot definitions and generating a list of coordinates not in use within (12, 12) space.
used_coordinates = []
for robot in robots:
    used_coordinates.append(robot.position)

# Generating all possible coordinates within a 12x12 space
all_coordinates = [(x, y) for x in range(1, 13) for y in range(1, 13)]

# Finding the coordinates not in use
unused_coordinates = [coord for coord in all_coordinates if coord not in used_coordinates]
total = len(unused_coordinates) + len(robots)
if total == 12*12:
    print("correct number of unsued positions")
    print(unused_coordinates)
else:
    print("incorrect number of unsued positions")
# Out:
# correct number of unsued positions
# [(1, 3), (1, 4), (1, 5), (1, 8), (1, 10), (1, 11), (1, 12), (2, 2), (2, 4), (2, 5), (2, 8), (2, 9), (2, 10), (2, 11), (2, 12), (3, 1), (3, 2), (3, 3), (3, 4), (3, 5), (3, 6), (3, 7), (3, 8), (3, 9), (3, 11), (4, 1), (4, 2), (4, 3), (4, 4), (4, 7), (4, 8), (4, 9), (4, 10), (4, 11), (5, 2), (5, 3), (5, 4), (5, 6), (5, 12), (6, 1), (6, 2), (6, 3), (6, 4), (6, 5), (6, 6), (6, 7), (6, 10), (6, 12), (7, 1), (7, 3), (7, 4), (7, 5), (7, 6), (7, 7), (7, 9), (7, 10), (7, 11), (8, 2), (8, 5), (8, 6), (8, 7), (8, 8), (8, 9), (8, 10), (8, 12), (9, 1), (9, 3), (9, 4), (9, 5), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (10, 2), (10, 3), (10, 9), (10, 10), (10, 12), (11, 1), (11, 2), (11, 4), (11, 6), (11, 8), (11, 10), (11, 12), (12, 1), (12, 3), (12, 5), (12, 6), (12, 7), (12, 10), (12, 11), (12, 12)]

# %% [markdown]
# ## Create Tools

# %% [markdown]
# **Helper functions**

# %%
def sort_by_tool(tool_name, robot_list=robots):
    usable_robots = []
    for robot in robot_list:
        if robot.tool_property == tool_name:
            usable_robots.append(robot)
    return usable_robots

def sort_by_availability(robot_list, target_pos):
    available_robots = []
    if robot_list:
        closest_robot = robot_list[0].name
        min_dist = dist_func(robot_list[0].position, target_pos)
        flag = True
        for robot in robot_list:
            if robot._status != "active":
                available_robots.append(robot.name)
                if flag:
                    flag = False
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
                    
                if min_dist > dist_func(robot.position, target_pos):
                    closest_robot = robot.name
                    min_dist = dist_func(robot.position, target_pos)
        if available_robots:
            return f"out of available robot: {available_robots}, {closest_robot} is the best suited to solve the task."
    return "no robot with the specified tool to solve the task"

def dist_func(robot_pos, target_pos):
    x_dist = abs(target_pos["x"] - robot_pos[0])
    y_dist = abs(target_pos["y"] - robot_pos[1])
    total_dist = x_dist + y_dist
    return total_dist

def select_known_robot(robot_name, desired_tool, robot_list=robots):
    for robot in robot_list:                
        if robot_name == robot.name:
            if robot._status != "active":
                if desired_tool == robot.tool_property:
                    return f"{robot_name} with the tool property: {robot.tool_property} has been selected to solve the task."
                return f"""{robot_name} is not equipped with the tool property initially selected for task completion. 
                Can {robot_name} with tool property: {robot.tool_property} still solve the task?
                If a list of items with assoicated tool properties is provided, remember to use that as reference.
                In your anwser please stat the initial selected tool and why {robot_name} can/can't solve the task with the tool property: {robot.tool_property}. in this step be strict and try to stay close to the list of items with assoicated tool properties
                """
            return f"{robot_name} is currently active and is not available to solve the task"
    return f"{robot_name} is not a valid robot"

def change_status(robot_name, robot_list=robots, status="idle"):
    for robot in robot_list:
        if robot_name == robot.name:
            old_status = robot._status
            robot.set_status(status)
            return f"{robot.name} has changed status from {old_status} to {status}"

def set_goal(robot_name: str, position: Tuple, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.setGoal(position)
            return robot.goal
        
def add_item_to_inventory(robot_name, item_name, robot_list=robots):
    for robot in robot_list:
        if robot_name == robot.name:
            robot.add_item_invetory(item_name)

# %% [markdown]
# **LLM tools**

# %%
from typing import Annotated, List, Tuple, Union

from langchain_core.tools import tool
from langsmith import trace

from langchain_core.pydantic_v1 import BaseModel, Field


class desired_robot_tool_property(BaseModel):
    """Inputs to the tools."""

    desired_robot_tool_property: str = Field(
        description="The desired tool property which is requied to solve the task given"
    )


@tool
def move_robot(robot_name: str, position: Tuple) -> str:
    """Moves the Specified robot to the desired position"""
    goal = set_goal(robot_name=robot_name, position=position)
    return f"{robot_name} has been moved to the desired position {goal}"

@tool
def grab_or_remove_item(robot_name: str, item_name: str) -> str:
    """makes the specified robot grab/remove the desired item"""
    add_item_to_inventory(robot_name=robot_name, item_name=item_name)
    return f"{robot_name} has grabed/removed the desired item {item_name}"

@tool
def robot_status_change(robot_name: str, status: str):
    """Changes the status of a robot"""
    return change_status(robot_name=robot_name, status=status)

@tool
def robot_selection_tool(desired_robot_tool_property, 
                         item_position) -> str:
    """Finds the most robots with the desired tool property. Remember that the item_position needs to be a dict of x and y coordinates"""
    sorted_robots = sort_by_tool(desired_robot_tool_property)
    return sort_by_availability(sorted_robots, item_position)
@tool
def select_known_robot_tool(robot_name: str, desired_robot_tool_property) -> str:
    """select the specified robot to solve the task. If the robot does not have the desired tool for the task, then it will ask if the robot still can solve the task.
    This tool does not alter the tools a robot has, but will try to use the selected robot although it might not have the desired tool.
    """
    return select_known_robot(robot_name=robot_name, desired_tool=desired_robot_tool_property)

@tool
def agent_response_tool(input: str, response: str) -> str:
    """this is a tool that returns the response to the input"""
    return response


control_tools = [move_robot, grab_or_remove_item, robot_status_change]
selection_tools = [robot_selection_tool, select_known_robot_tool]
misc_tools = [agent_response_tool]

# %% [markdown]
# ## Define our Execution Agent + state
#
# Let's now start by defining the state the track for this agent.
#
# First, we will need to track the current plan. Let's represent that as a list of strings.
#
# Next, we should track previously executed steps. Let's represent that as a list of tuples (these tuples will contain the step and then the result)
#
# Finally, we need to have some state to represent the final response as well as the original input.

# %%
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import List, Tuple, Annotated, TypedDict
import operator


class PlanExecute(TypedDict):
    input: str
    plan: List[str]
    current_step: str
    # Used to route work. The supervisor calls a function
    # that will update this every time it makes a decision
    next: str
    # The reason behind the member choice
    reasoning: str
    past_steps: Annotated[List[Tuple], operator.add]
    response: List[str]
    robot_name: str
    tool_property: str
    item: str
    item_position: Tuple[int]

# %% [markdown]
# Now we will create the execution agent(s) we want to use to execute tasks.

# %%
from typing import Any, Callable, List, Optional, TypedDict, Union

from langchain.agents import AgentExecutor, create_openai_tools_agent, create_tool_calling_agent
from langgraph.prebuilt import create_agent_executor
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import Runnable
from langchain_core.tools import BaseTool
from langchain_openai import ChatOpenAI

from langgraph.graph import END, StateGraph

def create_executor_agent(
    llm: ChatOpenAI,
    tools: list,
    system_prompt: str,
) -> str:
    """Create a function-calling agent and add it to the graph."""
    system_prompt += """\nWork autonomously according to your specialty, using the tools available to you.
    Do not ask for clarification.
    """

    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt,
            ),
            MessagesPlaceholder(variable_name="chat_history", optional=True),
            (
                "human",
                "{input}",
            ),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )

    agent = create_tool_calling_agent(llm, tools, prompt)
    executor = create_agent_executor(agent, tools)
    return executor

def create_team_supervisor(llm: ChatOpenAI, system_prompt, members) -> str:
    """An LLM-based router."""
    options = members
    function_def = {
        "name": "route",
        "description": "Select the next role.",
        "parameters": {
            "title": "routeSchema",
            "type": "object",
            "properties": {
                "next": {
                    "title": "Next",
                    "anyOf": [
                        {"enum": options},
                    ],
                },
                "reasoning": {
                    "type": "string",
                    "description": "The reason behind the choice of member"
                }
            },
            "required": ["reasoning", "next"],
        },
    }
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            (
                "human",
                "{current_step}",
            ),
            (
                "system",
                "Given the conversation above, who should act next? Select one of: {options}, and remember to give reasoning behind the choice",
            ),
        ]
    ).partial(options=str(options), team_members=", ".join(members))
    return (
        prompt
        | llm.bind_functions(functions=[function_def], function_call="route")
        | JsonOutputFunctionsParser()
    )

# %%
import functools

# Choose the LLM that will drive the agent

# ----- GPT-3.5 -----
# llm_agents = ChatOpenAI(model="gpt-3.5-turbo-1106")
# llm_planner = ChatOpenAI(model="gpt-3.5-turbo-1106")

# ----- GPT-4 -------
llm_agents = ChatOpenAI(model="gpt-4-1106-preview")
llm_planner = ChatOpenAI(model="gpt-4-1106-preview")



control_agent = create_executor_agent(
    llm_agents, 
    control_tools, 
    """
    You are an agent that control robots actions using the tools available to you.
    remember you are only able to grab/remove the items and not the robots tool property. this is the list of tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].
     which are not to be grabed or removed.
    """
    )


robot_selector_agent = create_executor_agent(
    llm_agents,
    selection_tools,
    """
    You are a agent with the purpose to select the best suited robot for the task. A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].
    If a specified robot is already selected to solve the task, use select_known_robot_tool.
    Here is an example of that.

    EXAMPLE: 
    task = "Move robot_name to location (2, 11) and sort the recyclables."
    Robot = robot_name
    END EXAMPLE

    remember to select the most apropriate tool_property for the task i.e a gripper for a task where something needs to be picked up.

    here is a list of items, and what tool property can manipulating that item:
    
    toolkit = gripper
    liquid spill = mop
    large debris = gripper, front loader 
    dust = vacuum, broom
    grass = lawnmower
    small debris = broom, vacuum 
    vehicle = tow hook
    construction materials = gripper, front loader, tow hook
    tree branches = saw
    screws = screwdriver

    remember that each of the items in the list is a category of it's own
    
"""
)


misc_agent = create_executor_agent(
    llm_agents,
    misc_tools,
    """
    You are an agent that can answer general questions and messages that doesn't have anything to do with making a robot solve a complex task.
    """
)


supervisor_agent = create_team_supervisor(
    llm_agents,
    """
    You are a supervisor tasked with routing the current_step to the following workers: Controller, Robot_selector, misc_agent.
    Given the following user request, respond with the worker to act next and the reason behind the choice.
    The selected worker will perform the current_step.

    Controller:
    Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

    tool functionality:
        - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
        - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
        - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

    Robot_selector:
    Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

    tool functionality:
        - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
        - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    misc_agent:
    Reponsible for anwsering more generic questions with tool: [agent_response_tool].
    
    """,
    ["Controller", "Robot_selector", "misc_agent"],
)

# %%
# robot_selector_agent.invoke(
#     {"input": ["Which robot should solve the task located at (6, 6)? The task requires a gripper"], "chat_history": []}
# )

# %% [markdown]
# ## Planning Step
#
# Let's now think about creating the planning step. This will use function calling to create a plan.

# %%
from langchain_core.pydantic_v1 import BaseModel


class Plan(BaseModel):
    """Plan to follow in future"""

    steps: List[str] = Field(
        description="different steps to follow, should be in sorted order"
    )
    current_step: str = Field(
        description="the first step to follow as per the steps variable"
    )

# %%
from langchain.chains.openai_functions import create_structured_output_runnable
from langchain_core.prompts import ChatPromptTemplate

control_tools = [move_robot, grab_or_remove_item, robot_status_change]
selection_tools = [robot_selection_tool, select_known_robot_tool]
misc_tools = [agent_response_tool]

planner_prompt = ChatPromptTemplate.from_template(
"""For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

When making the plan, keep in mind the executor agents capabilities:

Controller:
Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

tool functionality:
    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

Robot_selector:
Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

tool functionality:
    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    Here is an example of a task with and without a specified robot.
    
    EXAMPLE WITH SPECIFIED ROBOT:
     - Move Robot22 to location (6, 1) and remove the toolkit.

    EXAMPLE WITHOUT SPECIFIED ROBOT:
     - Move to location (9, 4) and remove the construction materials.

misc_agent:
Reponsible for anwsering more generic questions with tool: [agent_response_tool].

If there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.

When designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.

A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].

{objective}"""
)
planner = create_structured_output_runnable(
    Plan, llm_planner, planner_prompt
)

# %%
# planner.invoke(
#     {"objective": "Move to location (5, 4) and sweep the fallen leaves."}
# )

# %% [markdown]
# ## Re-Plan Step
#
# Now, let's create a step that re-does the plan based on the result of the previous step.

# %%
from langchain.chains.openai_functions import create_openai_fn_runnable


class Response(BaseModel):
    """Response to user."""
    robot_name: str = Field(
        description="The robot that solved the task i.e Robot22"
    )
    tool_property: str = Field(
        description="The tool property of {robot_name} i.e gripper"
    )
    item: str = Field(
        description="The item that is being manipulated i.e toolkit"
    )
    item_position: str = Field(
        description="The position of {item} i.e (11, 8)"
    )
    response: str


replanner_prompt = ChatPromptTemplate.from_template(
"""For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

When making the plan, keep in mind the executor agents capabilities:

Controller:
Reponsible for controlling the robots with a set of tools. the tools are: [move_robot, grab_or_remove_item, robot_status_change].

tool functionality:
    - move_robot(robot_name, desired_position): Moves the selected robot to a given position.
    - grab_or_remove_item(robot_name, item_name): grabs the item on the robots location and adds it to the robots inventory.
    - robot_status_change(robot_name, status): changes the current status of the robot to one of the statuses: idle, active, charging. This should only be used to set the robots status to idle after the objective is complete.

Robot_selector:
Reponsible for selecting the correct robot using tools: [robot_selection_tool, select_known_robot_tool]

tool functionality:
    - robot_selection_tool(desired_robot_tool_property, item_position): If no robot is specified in the objective, then this tools is to be used to determine the best suited robot to solve the objective.
    - select_known_robot_tool(robot_name, desired_robot_tool_property): If a robot is specified in the objective then this tool is to be used to determined if the robot is equipped with a tool property capable of solving the objective.

    Here is an example of a task with and without a specified robot.
    
    EXAMPLE WITH SPECIFIED ROBOT:
     - Move Robot22 to location (6, 1) and remove the toolkit.

    EXAMPLE WITHOUT SPECIFIED ROBOT:
     - Move to location (9, 4) and remove the construction materials.

misc_agent:
Reponsible for anwsering more generic questions with tool: [agent_response_tool].

If there is a specified robot for the objective, then always make sure the robot is equipped with a tool property capable of solving the objective. remember to give a tool property example in the same step as the check.

When designing a step by step plan for the objective, keep in mind the required input to the executor agents tools.

A robot can have the following tool properties: [lawnmower, gripper, tow hook, saw, screwdriver, mop, spray nozzle, broom, front loader, vacuum].

Your objective was this:
{input}

Your original plan was this:
{plan}

You have currently done the follow steps:
{past_steps}

Update your plan accordingly. If no more steps are needed and you can return to the user, then respond to the user. Otherwise, fill out the plan. Only add steps to the plan that still NEED to be done. Do not return previously done steps as part of the plan.
Remember to fill out the response to the user completely.
"""
)


replanner = create_openai_fn_runnable(
    [Plan, Response],
    llm_planner,
    replanner_prompt,
)

# %% [markdown]
# ## Create the Graph
#
# We can now create the graph!

# %%
def clear_txt(path):
    # Clear the file by opening it in write mode and closing it
    with open(path, "w") as file:
        pass

def write_txt(path, string):
    # Open the file in append mode and write the string
    with open(path, "a") as file:
        file.write(string)

# %%
file_name = "temp_react.txt"

async def controller_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await control_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def robot_selector_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await robot_selector_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def misc_execute_step(state: PlanExecute):
    task = state["plan"][0]
    agent_response = await misc_agent.ainvoke({"input": task, "chat_history": []})
    return {
        "past_steps": (task, agent_response["agent_outcome"].return_values["output"])
    }

async def plan_step(state: PlanExecute):
    plan = await planner.ainvoke({"objective": state["input"]})
    return {"plan": plan.steps, "current_step": plan.current_step}


async def replan_step(state: PlanExecute):
    output = await replanner.ainvoke(state)
    if isinstance(output, Response):
        # return {"response": output.response}
        write_txt(file_name, f"{output.robot_name};{output.tool_property};{output.item};{output.item_position}\n")
        return {"response": output.response, "robot_name": output.robot_name, "tool_property": output.tool_property, "item": output.item, "item_position": output.item_position}
    else:
        return {"plan": output.steps, "current_step": output.current_step}


def should_end(state: PlanExecute):
    if "response" in state and state["response"]:
        return True
    else:
        return False

# %%
from langgraph.graph import StateGraph, END

workflow = StateGraph(PlanExecute)

# Add the plan node
workflow.add_node("planner", plan_step)

# Add supervisor node
workflow.add_node("supervisor", supervisor_agent)

# Add the execution step nodes
workflow.add_node("Controller", controller_execute_step)
workflow.add_node("Robot_selector", robot_selector_execute_step)
workflow.add_node("misc_agent", misc_execute_step)

# Add a replan node
workflow.add_node("replanner", replan_step)

# Define the starting node
workflow.set_entry_point("planner")

# From plan we go to supervisor
workflow.add_edge("planner", "supervisor")

# Supervisor select one of the executor nodes
workflow.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {"Controller": "Controller", "Robot_selector": "Robot_selector", "misc_agent": "misc_agent"}
)

# The executor nodes return to the replanner
workflow.add_edge("Controller", "replanner")
workflow.add_edge("Robot_selector", "replanner")
workflow.add_edge("misc_agent", "replanner")

# If task not completed then replan and go to the supervisor
workflow.add_conditional_edges(
    "replanner",
    # Next, we pass in the function that will determine which node is called next.
    should_end,
    {
        # If `tools`, then we call the tool node.
        True: END,
        False: "supervisor",
    },
)

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable
app = workflow.compile()

# %% [markdown]
# ### Test results

# %%
def task_iteration(file_path):
        task = file_path.readline()
        if not task:
            return False
        return task.strip()

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\frede\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def process_ReAct_response(name, response):
    output = []

    if name == "planner":
        print(f"{name}:\n  plan:")
        output.append(f"{name}:\n    plan:")
        for step in response["plan"]:
            print(f"    {step}")
            output.append(f"        {step}")
        next_step = response["current_step"]
        print(f"  current step:\n     {next_step}\n---\n")
        output.append(f"    current step:\n       {next_step}\n---\n")

    elif name == "replanner":
        if "plan" in response and response["plan"]:
            print(f"{name}:\n    plan:")
            output.append(f"{name}:\n    plan:")
            for step in response["plan"]:
                print(f"        {step}")
                output.append(f"        {step}")
            next_step = response["current_step"]
            print(f"    current step:\n        {next_step}\n---\n")
            output.append(f"    current step:\n        {next_step}\n---\n")
        elif "response" in response and response["response"]:
            response = response["response"]
            print(f"{name}:\n    response:\n        {response}\n---\n")
            output.append(f"{name}:\n    response:\n        {response}\n---\n")

    elif name == "supervisor":
        print(f"{name}:\n   next agent: {response['next']}\n   reason: {response['reasoning']}\n---\n")
        output.append(f"{name}:\n   next agent: {response['next']}\n   reason: {response['reasoning']}\n---\n")

    else:
        past_steps = response["past_steps"]
        print(f"{name}:\n   past steps: {past_steps}\n---\n")
        output.append(f"{name}:\n   past steps: {past_steps}\n---\n")

    return output

# %% [markdown]
# ## Easy test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Results\Result_matrix\Easy_react_matrix.txt"
clear_txt(file_name)

with open("Results\Tasks\Easy_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 100}
        inputs = {"input": task}
        i = 1
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
            if i == 49:
                # This is to ensure there is a response even though the it fails due recursion limit
                write_txt(file_name, "DNF;DNF;DNF;DNF\n")
                history.extend("DNF")
                break
            i+=1

        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('Results\Raw_output\output_Easy_react.xlsx')
# Out:
# 1. task: Move Robot32 to location (2, 9) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot32 and the 'gripper' tool property to determine if Robot32 is equipped with a tool property capable of solving the objective.
#     Use the move_robot function with Robot32 and the desired position (2, 9) to move Robot32 to the specified location.
#     Use the grab_or_remove_item function with Robot32 and 'toolkit' to remove the toolkit from the location.
#     Use the robot_status_change function with Robot32 and 'idle' to set the robot's status to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot32 and the 'gripper' tool property to determine if Robot32 is equipped with a tool property capable of solving the objective.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifically mentions the need to use the 'select_known_robot_tool' to determine if Robot32 is equipped with a 'gripper' tool property. Since this tool is part of the Robot_selector's toolkit, the Robot_selector is the appropriate worker to act next in order to fulfill the user request.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot32 and the 'gripper' tool property to determine if Robot32 is equipped with a tool property capable of solving the objective.", 'Robot32, equipped with a gripper tool property, has been selected to solve the task.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot32 and the desired position (2, 9) to move Robot32 to the specified location.
#         Use the grab_or_remove_item function with Robot32 and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with Robot32 and 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the move_robot function with Robot32 and the desired position (2, 9) to move Robot32 to the specified location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically involves moving a robot to a desired position. The Controller is responsible for controlling the robots and has the 'move_robot' function that is needed to perform this action. The robot to be moved (Robot32) and the desired position (2, 9) are already specified, so the Robot_selector is not needed for this task. The misc_agent is also not required as the task is not about answering generic questions.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot32 and the desired position (2, 9) to move Robot32 to the specified location.', 'Robot32 has been successfully moved to the position (2, 9).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot32 and 'toolkit' to remove the toolkit from the location.
#         Use the robot_status_change function with Robot32 and 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot32 and 'toolkit' to remove the toolkit from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving a robot (Robot32) and an item ('toolkit'), which falls under the responsibilities of the Controller. The Controller has the 'grab_or_remove_item' tool, which is needed to remove the toolkit from the location as per the user request.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot32 and 'toolkit' to remove the toolkit from the location.", 'Robot32 has successfully removed the toolkit from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot32 and 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the robot_status_change function with Robot32 and 'idle' to set the robot's status to idle after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request entails using the 'robot_status_change' function to set the status of Robot32 to 'idle', which is one of the tools controlled by the Controller. Therefore, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot32 and 'idle' to set the robot's status to idle after the task is complete.", 'The status of Robot32 has been successfully changed to idle.')
# ---
#
# replanner:
#     response:
#         The objective has been completed successfully. Robot32, equipped with a gripper, moved to location (2, 9), removed the toolkit, and is now set to idle status.
# ---
#
# 2. task: Move Robot6 to location (5, 4) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot6 and 'mop' tool property to confirm if Robot6 is equipped with a mop for cleaning up the liquid spill.
#     Use the move_robot function with Robot6 and desired position (5, 4) to move Robot6 to the location of the liquid spill.
#     Use the grab_or_remove_item function with Robot6 and 'liquid spill' to clean up the spill at the robot's location.
#     Use the robot_status_change function with Robot6 and status 'idle' to set Robot6's status to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot6 and 'mop' tool property to confirm if Robot6 is equipped with a mop for cleaning up the liquid spill.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to use the select_known_robot_tool to confirm if a specific robot, Robot6, is equipped with a mop tool property. This falls under the responsibility of the Robot_selector, who has access to the select_known_robot_tool and can determine if Robot6 has the necessary equipment to handle the task of cleaning up a liquid spill.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot6 and 'mop' tool property to confirm if Robot6 is equipped with a mop for cleaning up the liquid spill.", 'Robot6 is equipped with a mop and has been selected to clean up the liquid spill.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot6 and desired position (5, 4) to move Robot6 to the location of the liquid spill.
#         Use the grab_or_remove_item function with Robot6 and 'liquid spill' to clean up the spill at the robot's location.
#         Use the robot_status_change function with Robot6 and status 'idle' to set Robot6's status to idle after the task is complete.
#     current step:
#         Use the move_robot function with Robot6 and desired position (5, 4) to move Robot6 to the location of the liquid spill.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving moving a robot, which falls under the Controller's responsibilities. The Controller has the tool 'move_robot' which is used to move a specified robot to a given position. Since the robot name (Robot6) and the desired position ((5, 4)) are both provided, the Controller is the appropriate worker to act next and perform the current_step.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot6 and desired position (5, 4) to move Robot6 to the location of the liquid spill.', 'Robot6 has been successfully moved to the position (5, 4).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot6 and 'liquid spill' to clean up the spill at the robot's location.
#         Use the robot_status_change function with Robot6 and status 'idle' to set Robot6's status to idle after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot6 and 'liquid spill' to clean up the spill at the robot's location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The 'grab_or_remove_item' function is a tool available to the Controller to manage robots. Since the user request specifies the use of this function with Robot6 and a specific task ('liquid spill'), the Controller is the appropriate worker to execute the task. There is no need to select or identify a robot since Robot6 is already specified, and the task does not involve answering generic questions, which would be the domain of the misc_agent.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot6 and 'liquid spill' to clean up the spill at the robot's location.", 'Robot6 has cleaned up the liquid spill at its location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot6 and status 'idle' to set Robot6's status to idle after the task is complete.
#     current step:
#         Use the robot_status_change function with Robot6 and status 'idle' to set Robot6's status to idle after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to use the robot_status_change function to set Robot6's status to 'idle'. As the Controller is responsible for controlling the robots with a set of tools including robot_status_change, it is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot6 and status 'idle' to set Robot6's status to idle after the task is complete.", "Robot6's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot6 equipped with a mop has successfully cleaned up the liquid spill at location (5, 4) and is now set to idle.
# ---
#
# 3. task: Move Robot29 to location (5, 12) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot29 and gripper as the desired_robot_tool_property to ensure Robot29 is equipped to remove large debris.
#     Use the move_robot function with Robot29 and (5, 12) as the parameters to move Robot29 to the correct location.
#     Use the grab_or_remove_item function with Robot29 and 'large debris' as the parameters to remove the debris from the location.
#     Use the robot_status_change function with Robot29 and 'idle' as the parameters to set Robot29's status to idle after completing the task.
#   current step:
#      Use the select_known_robot_tool with Robot29 and gripper as the desired_robot_tool_property to ensure Robot29 is equipped to remove large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to use the select_known_robot_tool to verify if Robot29 is equipped with a gripper suitable for removing large debris. This task falls within the responsibilities of the Robot_selector, as this worker is tasked with selecting and verifying robots for specific tasks based on their tool properties.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool with Robot29 and gripper as the desired_robot_tool_property to ensure Robot29 is equipped to remove large debris.', 'The initial selected tool property for removing large debris was a gripper. According to the list of items with associated tool properties, large debris can be manipulated using either a gripper or a front loader. Therefore, Robot29, with a tool property of front loader, can still solve the task of removing large debris effectively.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot29 and (5, 12) as the parameters to move Robot29 to the correct location.
#         Use the grab_or_remove_item function with Robot29 and 'large debris' as the parameters to remove the debris from the location.
#         Use the robot_status_change function with Robot29 and 'idle' as the parameters to set Robot29's status to idle after completing the task.
#     current step:
#         Use the move_robot function with Robot29 and (5, 12) as the parameters to move Robot29 to the correct location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action to move a specific robot (Robot29) to a designated position ((5, 12)). The Controller is responsible for such actions, with the tool 'move_robot' being the appropriate one to use for moving the robot to the given position.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot29 and (5, 12) as the parameters to move Robot29 to the correct location.', 'Robot29 has been successfully moved to the position (5, 12).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot29 and 'large debris' as the parameters to remove the debris from the location.
#         Use the robot_status_change function with Robot29 and 'idle' as the parameters to set Robot29's status to idle after completing the task.
#     current step:
#         Use the grab_or_remove_item function with Robot29 and 'large debris' as the parameters to remove the debris from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving a robot ('Robot29') and an item ('large debris') to be removed from a location. Since the Controller is responsible for controlling the robots and has the tool 'grab_or_remove_item' which is required for this task, the Controller should act next to execute the function with the provided parameters.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot29 and 'large debris' as the parameters to remove the debris from the location.", 'Robot29 has successfully grabbed or removed the large debris.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot29 and 'idle' as the parameters to set Robot29's status to idle after completing the task.
#     current step:
#         Use the robot_status_change function with Robot29 and 'idle' as the parameters to set Robot29's status to idle after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request explicitly mentions using the tool 'robot_status_change' with specific parameters (Robot29, 'idle'). The Controller is responsible for controlling the robots and has the 'robot_status_change' tool that can change the robot's status to 'idle' after the objective is complete. Therefore, the Controller is the appropriate worker to perform the current step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot29 and 'idle' as the parameters to set Robot29's status to idle after completing the task.", "Robot29's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot29 equipped with a front loader has successfully moved to location (5, 12) and removed the large debris. The robot's status is now set to idle, and the task is complete.
# ---
#
# 4. task: Move Robot48 to location (6, 6) and remove the dust.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with 'Robot48' and 'vacuum' to ensure Robot48 is equipped with a vacuum.
#     Execute move_robot with 'Robot48' to position (6, 6).
#     Use grab_or_remove_item with 'Robot48' and 'dust' to clean up the dust at location (6, 6).
#     Change the status of Robot48 to 'idle' using robot_status_change.
#   current step:
#      Use the select_known_robot_tool with 'Robot48' and 'vacuum' to ensure Robot48 is equipped with a vacuum.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to use the 'select_known_robot_tool' to confirm whether 'Robot48' is equipped with a 'vacuum'. The Robot_selector is responsible for using the 'select_known_robot_tool' to determine if the specified robot has the required tool property.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with 'Robot48' and 'vacuum' to ensure Robot48 is equipped with a vacuum.", "The initial selected tool for Robot48 was a 'vacuum', which is suited for tasks involving the removal of dust or small debris. However, Robot48 is not equipped with a vacuum but rather with a 'broom'. According to the list of items and associated tool properties, a broom can also be used for dust and small debris. Therefore, even though Robot48 does not have the initially selected tool of a vacuum, it can still solve the task with its broom, as it is an appropriate tool for the same types of items.")
# ---
#
# replanner:
#     plan:
#         Execute move_robot with 'Robot48' to position (6, 6).
#         Use grab_or_remove_item with 'Robot48' and 'dust' to clean up the dust at location (6, 6).
#         Change the status of Robot48 to 'idle' using robot_status_change.
#     current step:
#         Execute move_robot with 'Robot48' to position (6, 6).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action to move a robot, Robot48, to a specific position, which is (6, 6). This falls under the functionality of the Controller, who is responsible for controlling the robots with the 'move_robot' tool. No robot selection is needed since the specific robot name is provided, and the request does not involve answering generic questions, which eliminates the need for the misc_agent.
# ---
#
# Controller:
#    past steps: ("Execute move_robot with 'Robot48' to position (6, 6).", 'Robot48 has been successfully moved to the position (6, 6).')
# ---
#
# replanner:
#     plan:
#         Use grab_or_remove_item with 'Robot48' and 'dust' to clean up the dust at location (6, 6).
#         Change the status of Robot48 to 'idle' using robot_status_change.
#     current step:
#         Use grab_or_remove_item with 'Robot48' and 'dust' to clean up the dust at location (6, 6).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action to be performed by a robot ('Robot48') and involves using one of the Controller's tools ('grab_or_remove_item') to clean up 'dust'. Since the specific robot and the action are already identified, the Controller is the appropriate worker to execute this command.
# ---
#
# Controller:
#    past steps: ("Use grab_or_remove_item with 'Robot48' and 'dust' to clean up the dust at location (6, 6).", 'Robot48 has grabbed the dust and has been moved to the location (6, 6) to clean up.')
# ---
#
# replanner:
#     plan:
#         Change the status of Robot48 to 'idle' using robot_status_change.
#     current step:
#         Change the status of Robot48 to 'idle' using robot_status_change.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task specifically requires using the 'robot_status_change' tool to change the status of a robot, which is one of the tools controlled by the Controller. Therefore, the Controller is the appropriate worker to handle this current_step.
# ---
#
# Controller:
#    past steps: ("Change the status of Robot48 to 'idle' using robot_status_change.", "Robot48's status has been changed to 'idle'.")
# ---
#
# replanner:
#     response:
#         Robot48 has completed the task of moving to location (6, 6) and removing the dust using its broom. The robot has been set to 'idle' status, signifying the completion of the objective.
# ---
#
# 5. task: Move Robot41 to location (1, 8) and remove the grass.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify Robot41 is equipped with the lawnmower tool property.
#     If Robot41 is not equipped with a lawnmower, select a different robot using robot_selection_tool that has the lawnmower tool property and is closest to location (1, 8).
#     Move the selected robot to location (1, 8) using the move_robot function.
#     Use the grab_or_remove_item function to remove the grass at location (1, 8).
#     Change the status of the robot to idle using the robot_status_change function.
#   current step:
#      Use the select_known_robot_tool to verify Robot41 is equipped with the lawnmower tool property.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request is to verify if Robot41 is equipped with the lawnmower tool property. This task falls under the responsibility of the Robot_selector, who uses the select_known_robot_tool to determine if a specified robot possesses the required tool property for the objective.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to verify Robot41 is equipped with the lawnmower tool property.', 'Robot41 is equipped with the lawnmower tool property and has been selected to solve the task.')
# ---
#
# replanner:
#     plan:
#         Move Robot41 to location (1, 8) using the move_robot function.
#         Use the grab_or_remove_item function to remove the grass at location (1, 8).
#         Change the status of the robot to idle using the robot_status_change function.
#     current step:
#         Move Robot41 to location (1, 8) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to move a specific robot, Robot41, to a designated location (1, 8). Since the Controller is responsible for controlling robots with tools that include the 'move_robot' function, it is the appropriate worker to route the current_step to. The Controller will use the 'move_robot' function to move Robot41 to the desired position as requested.
# ---
#
# Controller:
#    past steps: ('Move Robot41 to location (1, 8) using the move_robot function.', 'Robot41 has been moved to the desired position (1, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to remove the grass at location (1, 8).
#         Change the status of the robot to idle using the robot_status_change function.
#     current step:
#         Use the grab_or_remove_item function to remove the grass at location (1, 8).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies an action, which is 'remove the grass at location (1, 8)', but does not specify which robot should perform this task. The Robot_selector is responsible for selecting the correct robot when no specific robot is mentioned. The robot_selection_tool should be used to determine the best suited robot to remove the grass at the mentioned location.
# ---
#
# Robot_selector:
#    past steps: ('Use the grab_or_remove_item function to remove the grass at location (1, 8).', 'Robot21, equipped with a lawnmower, has been selected to remove the grass at location (1, 8).')
# ---
#
# replanner:
#     plan:
#         Robot41 uses the grab_or_remove_item function to remove the grass at location (1, 8).
#         Change the status of Robot41 to idle using the robot_status_change function.
#     current step:
#         Robot41 uses the grab_or_remove_item function to remove the grass at location (1, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action for a particular robot (Robot41) to use a specific function (grab_or_remove_item) to remove grass at a given location (1, 8). Since the Controller is responsible for controlling the robots and using tools such as 'move_robot', 'grab_or_remove_item', and 'robot_status_change', it is the appropriate worker to carry out this action. The Robot_selector is not needed as the robot has already been specified, and the misc_agent is not required as the task is not a generic question but a specific command for robot operation.
# ---
#
# Controller:
#    past steps: ('Robot41 uses the grab_or_remove_item function to remove the grass at location (1, 8).', 'Robot41 has successfully moved to location (1, 8) and removed the grass.')
# ---
#
# replanner:
#     plan:
#         Change the status of Robot41 to idle using the robot_status_change function.
#     current step:
#         Change the status of Robot41 to idle using the robot_status_change function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots and has the necessary tool for the task, which is the robot_status_change. This tool is used to change the current status of the robot, and in this case, it should be used to set Robot41's status to idle as requested.
# ---
#
# Controller:
#    past steps: ('Change the status of Robot41 to idle using the robot_status_change function.', "Robot41's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot41, equipped with a lawnmower, has successfully moved to location (1, 8) and removed the grass. The robot's status has been changed to idle, completing the task.
# ---
#
# 6. task: Move Robot10 to location (9, 5) and remove the small debris.
# ---
# planner:
#   plan:
#     Use the 'select_known_robot_tool' with Robot10 and the 'gripper' tool property to confirm that Robot10 is equipped to remove small debris.
#     Use the 'move_robot' function with Robot10 and the position (9, 5) to move Robot10 to the desired location.
#     Use the 'grab_or_remove_item' function with Robot10 and the item 'small debris' to remove it from the location.
#     Use the 'robot_status_change' function with Robot10 and set its status to 'idle' after completing the task.
#   current step:
#      Use the 'select_known_robot_tool' with Robot10 and the 'gripper' tool property to confirm that Robot10 is equipped to remove small debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The 'select_known_robot_tool' is a functionality of the Robot_selector, and the user request specifically asks to use this tool to confirm whether Robot10 is equipped with the 'gripper' tool property to remove small debris. Therefore, the Robot_selector should be the next to act to fulfill this request.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'select_known_robot_tool' with Robot10 and the 'gripper' tool property to confirm that Robot10 is equipped to remove small debris.", 'The initial selected tool was "gripper" which is appropriate for removing small debris. However, Robot10 does not have a gripper. Instead, Robot10 is equipped with a "vacuum," which is also suitable for dealing with small debris according to the list of items and associated tool properties. Therefore, Robot10 can still solve the task with the tool property: vacuum.')
# ---
#
# replanner:
#     plan:
#         Use the 'move_robot' function with Robot10 and the position (9, 5) to move Robot10 to the desired location.
#         Use the 'grab_or_remove_item' function with Robot10 and the item 'small debris' to remove it from the location.
#         Use the 'robot_status_change' function with Robot10 and set its status to 'idle' after completing the task.
#     current step:
#         Use the 'move_robot' function with Robot10 and the position (9, 5) to move Robot10 to the desired location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving the movement of a robot (Robot10) to a specific position (9, 5). The 'move_robot' function is a tool under the Controller's responsibility, which aligns with the requested action.
# ---
#
# Controller:
#    past steps: ("Use the 'move_robot' function with Robot10 and the position (9, 5) to move Robot10 to the desired location.", 'Robot10 has been successfully moved to the position (9, 5).')
# ---
#
# replanner:
#     plan:
#         Use the 'grab_or_remove_item' function with Robot10 and the item 'small debris' to remove it from the location.
#         Use the 'robot_status_change' function with Robot10 and set its status to 'idle' after completing the task.
#     current step:
#         Use the 'grab_or_remove_item' function with Robot10 and the item 'small debris' to remove it from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has requested the use of 'grab_or_remove_item' function with a specified robot (Robot10) and an item ('small debris'). The Controller is responsible for this action as it has the tool 'grab_or_remove_item' to remove items from a location using a robot.
# ---
#
# Controller:
#    past steps: ("Use the 'grab_or_remove_item' function with Robot10 and the item 'small debris' to remove it from the location.", 'Robot10 has successfully grabbed and removed the small debris from the location.')
# ---
#
# replanner:
#     plan:
#         Use the 'robot_status_change' function with Robot10 and set its status to 'idle' after completing the task.
#     current step:
#         Use the 'robot_status_change' function with Robot10 and set its status to 'idle' after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task involves using the 'robot_status_change' function to set the status of Robot10 to 'idle'. This function falls under the Controller's set of tools, as the Controller is responsible for controlling the robots using tools such as 'move_robot', 'grab_or_remove_item', and 'robot_status_change'. Since the specific action required is a status change for a robot, the Controller is the correct worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Use the 'robot_status_change' function with Robot10 and set its status to 'idle' after completing the task.", "Robot10's status has been changed to idle after completing the task.")
# ---
#
# replanner:
#     response:
#         Robot10 equipped with a vacuum has successfully moved to position (9, 5), removed the small debris, and is now set to idle.
# ---
#
# 7. task: Move Robot13 to location (10, 10) and remove the vehicle.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with 'Robot13' and 'tow hook' to ensure Robot13 is equipped with a tow hook capable of removing the vehicle.
#     Use the move_robot tool with 'Robot13' and position (10, 10) to move Robot13 to the specified location.
#     Use the grab_or_remove_item tool with 'Robot13' and 'vehicle' to remove the vehicle from the location.
#     Use the robot_status_change tool with 'Robot13' and status 'idle' to set Robot13's status to idle after completing the task.
#   current step:
#      Use the select_known_robot_tool with 'Robot13' and 'tow hook' to ensure Robot13 is equipped with a tow hook capable of removing the vehicle.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has specifically requested to check if 'Robot13' is equipped with a 'tow hook' to remove a vehicle. Therefore, the 'select_known_robot_tool' from the Robot_selector's set of tools is the appropriate next action to determine if Robot13 has the required tool property.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with 'Robot13' and 'tow hook' to ensure Robot13 is equipped with a tow hook capable of removing the vehicle.", 'Robot13, equipped with a tow hook, has been selected to solve the task of removing the vehicle.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool with 'Robot13' and position (10, 10) to move Robot13 to the specified location.
#         Use the grab_or_remove_item tool with 'Robot13' and 'vehicle' to remove the vehicle from the location.
#         Use the robot_status_change tool with 'Robot13' and status 'idle' to set Robot13's status to idle after completing the task.
#     current step:
#         Use the move_robot tool with 'Robot13' and position (10, 10) to move Robot13 to the specified location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to move a robot (Robot13) to a certain position (10, 10). The Controller is responsible for controlling the robots with a set of tools, including the 'move_robot' tool, which is used for moving robots to given positions. Therefore, the Controller is the correct worker to perform the current_step of moving Robot13.
# ---
#
# Controller:
#    past steps: ("Use the move_robot tool with 'Robot13' and position (10, 10) to move Robot13 to the specified location.", 'Robot13 has been moved to the desired position (10, 10).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with 'Robot13' and 'vehicle' to remove the vehicle from the location.
#         Use the robot_status_change tool with 'Robot13' and status 'idle' to set Robot13's status to idle after completing the task.
#     current step:
#         Use the grab_or_remove_item tool with 'Robot13' and 'vehicle' to remove the vehicle from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action that involves directly interacting with a robot ('Robot13') and an item ('vehicle'). The Controller is responsible for controlling the robots and has the tool 'grab_or_remove_item' needed to remove an item from the robot's location. Therefore, the Controller is the correct worker to act next to perform the current_step of using 'grab_or_remove_item' with 'Robot13' and 'vehicle' to remove the vehicle.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item tool with 'Robot13' and 'vehicle' to remove the vehicle from the location.", 'Robot13 has successfully grabbed or removed the vehicle from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool with 'Robot13' and status 'idle' to set Robot13's status to idle after completing the task.
#     current step:
#         Use the robot_status_change tool with 'Robot13' and status 'idle' to set Robot13's status to idle after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specifically requested the use of the 'robot_status_change' tool, which is a part of the Controller's set of tools. Therefore, the Controller is the right worker to set Robot13's status to 'idle' as per the user's request.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool with 'Robot13' and status 'idle' to set Robot13's status to idle after completing the task.", "Robot13's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot13, equipped with a tow hook, has successfully moved to location (10, 10) and removed the vehicle. The robot's status has been set to idle, completing the task.
# ---
#
# 8. task: Move Robot23 to location (8, 2) and remove the construction materials.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot23 and the 'front loader' tool property to ensure Robot23 is equipped to remove construction materials.
#     Use the move_robot function with Robot23 and position (8, 2) to move Robot23 to the designated location.
#     Use the grab_or_remove_item function with Robot23 and 'construction materials' to remove the materials from the location.
#     Use the robot_status_change function with Robot23 and set the status to 'idle' after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot23 and the 'front loader' tool property to ensure Robot23 is equipped to remove construction materials.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifically mentions the need to use the 'select_known_robot_tool' to ensure a named robot (Robot23) has the required tool property ('front loader') for the task of removing construction materials. The Robot_selector is responsible for using the 'select_known_robot_tool' to verify if the specified robot has the necessary capabilities.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot23 and the 'front loader' tool property to ensure Robot23 is equipped to remove construction materials.", "The initial selected tool for Robot23 to remove construction materials was a 'front loader'. According to the list of items with associated tool properties, construction materials can be manipulated using a gripper, front loader, or tow hook. While Robot23 does not have a front loader, it is equipped with a tow hook, which is also suitable for handling construction materials. Therefore, Robot23 with a tow hook can still solve the task of removing construction materials.")
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot23 and position (8, 2) to move Robot23 to the designated location.
#         Use the grab_or_remove_item function with Robot23 and 'construction materials' to remove the materials from the location.
#         Use the robot_status_change function with Robot23 and set the status to 'idle' after the task is complete.
#     current step:
#         Use the move_robot function with Robot23 and position (8, 2) to move Robot23 to the designated location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving a specific robot (Robot23) and a desired position ((8, 2)). The Controller is responsible for controlling the robots, and one of its tools is move_robot, which is used to move a selected robot to a given position. Therefore, the Controller is the appropriate worker to carry out this action.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot23 and position (8, 2) to move Robot23 to the designated location.', 'Robot23 has been moved to the desired position (8, 2).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot23 and 'construction materials' to remove the materials from the location.
#         Use the robot_status_change function with Robot23 and set the status to 'idle' after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot23 and 'construction materials' to remove the materials from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a direct action for a particular robot, Robot23, to use the grab_or_remove_item function to remove 'construction materials'. Since the Controller is responsible for controlling the robots with a set of tools, including the grab_or_remove_item function, it is the appropriate worker to act next to perform the current step.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot23 and 'construction materials' to remove the materials from the location.", 'Robot23 has successfully removed the construction materials from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot23 and set the status to 'idle' after the task is complete.
#     current step:
#         Use the robot_status_change function with Robot23 and set the status to 'idle' after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task requires the use of the 'robot_status_change' function to set the status of Robot23 to 'idle'. This function is a part of the Controller's set of tools, making the Controller the appropriate worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot23 and set the status to 'idle' after the task is complete.", "Robot23's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot23 equipped with a tow hook has successfully moved to location (8, 2) and removed the construction materials. The robot's status has been set to idle, completing the task.
# ---
#
# 9. task: Move Robot24 to location (11, 8) and remove the tree branches.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot24 and saw to ensure Robot24 is equipped to remove tree branches.
#     If Robot24 is not equipped with a saw, select an appropriate robot using robot_selection_tool with saw and the item position (11, 8).
#     Use the move_robot tool to move the selected robot to location (11, 8).
#     Use the grab_or_remove_item tool with the selected robot's name and 'tree branches' to remove the tree branches from the location.
#     Use the robot_status_change tool to set the selected robot's status to idle after the branches are removed.
#   current step:
#      Use the select_known_robot_tool with Robot24 and saw to ensure Robot24 is equipped to remove tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has specified a particular robot (Robot24) and a tool property (saw), indicating the need to confirm whether this robot possesses the required tool for the task (removing tree branches). The Robot_selector is responsible for this check using the select_known_robot_tool.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool with Robot24 and saw to ensure Robot24 is equipped to remove tree branches.', 'Robot24, equipped with a saw, has been selected to remove the tree branches.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool to move Robot24 to location (11, 8).
#         Use the grab_or_remove_item tool with Robot24 and 'tree branches' to remove the tree branches from the location.
#         Use the robot_status_change tool to set Robot24's status to idle after the branches are removed.
#     current step:
#         Use the move_robot tool to move Robot24 to location (11, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to use a specific tool, 'move_robot', to move Robot24 to a specified location (11, 8). The Controller is responsible for using the 'move_robot' tool to control the robots' movements. Since the request specifies both the robot name and the desired position, no robot selection is needed, and hence there is no need to involve the Robot_selector. The task does not involve answering generic questions, so the misc_agent is not the appropriate worker for this step.
# ---
#
# Controller:
#    past steps: ('Use the move_robot tool to move Robot24 to location (11, 8).', 'Robot24 has been successfully moved to the desired position (11, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with Robot24 and 'tree branches' to remove the tree branches from the location.
#         Use the robot_status_change tool to set Robot24's status to idle after the branches are removed.
#     current step:
#         Use the grab_or_remove_item tool with Robot24 and 'tree branches' to remove the tree branches from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action that involves a robot interacting with an item, which falls under the responsibilities of the Controller. The 'grab_or_remove_item' tool is one of the tools that the Controller uses to control the robots. Since the robot name 'Robot24' and the item 'tree branches' are provided, the Controller is the correct worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item tool with Robot24 and 'tree branches' to remove the tree branches from the location.", 'Robot24 has successfully grabbed and removed the tree branches from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool to set Robot24's status to idle after the branches are removed.
#     current step:
#         Use the robot_status_change tool to set Robot24's status to idle after the branches are removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action requiring the use of the 'robot_status_change' tool to set Robot24's status to idle. The 'Controller' is responsible for controlling the robots and has access to the 'robot_status_change' tool. Therefore, the Controller is the correct worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool to set Robot24's status to idle after the branches are removed.", 'Robot24 has removed the branches and is now set to idle status.')
# ---
#
# replanner:
#     response:
#         Robot24, equipped with a saw, has successfully moved to location (11, 8), removed the tree branches, and is now set to idle status.
# ---
#
# 10. task: Move Robot15 to location (3, 8) and remove the screws.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot15 and the screwdriver property to ensure Robot15 is equipped to remove screws.
#     Use the move_robot function with Robot15 and position (3, 8) to move Robot15 to the correct location.
#     Use the grab_or_remove_item function with Robot15 and the item 'screws' to remove the screws from the location.
#     Use the robot_status_change function with Robot15 and set the status to 'idle' after the screws are removed.
#   current step:
#      Use the select_known_robot_tool with Robot15 and the screwdriver property to ensure Robot15 is equipped to remove screws.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request indicates a need to determine if a specific robot (Robot15) has the necessary tool property (screwdriver) to perform a task (removing screws). The Robot_selector is responsible for selecting the correct robot and has the 'select_known_robot_tool' function that can be used to confirm if Robot15 is equipped with a screwdriver. Therefore, the Robot_selector should act next to ensure Robot15 is suitable for the task.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool with Robot15 and the screwdriver property to ensure Robot15 is equipped to remove screws.', 'Robot15, equipped with a screwdriver, has been selected to remove screws.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot15 and position (3, 8) to move Robot15 to the correct location.
#         Use the grab_or_remove_item function with Robot15 and the item 'screws' to remove the screws from the location.
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the screws are removed.
#     current step:
#         Use the move_robot function with Robot15 and position (3, 8) to move Robot15 to the correct location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to use the 'move_robot' function with a specific robot (Robot15) and a specific position (3, 8). The Controller is the worker responsible for controlling the robots, which includes using the 'move_robot' tool to move a robot to a given position. Since the robot name and desired position are already provided, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Use the move_robot function with Robot15 and position (3, 8) to move Robot15 to the correct location.', 'Robot15 has been successfully moved to the position (3, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot15 and the item 'screws' to remove the screws from the location.
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the screws are removed.
#     current step:
#         Use the grab_or_remove_item function with Robot15 and the item 'screws' to remove the screws from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of using the 'grab_or_remove_item' function with Robot15 and the item 'screws'. This is a direct instruction involving a specific robot and an item, which falls under the responsibilities of the Controller, who has the tools to perform this task.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot15 and the item 'screws' to remove the screws from the location.", 'Robot15 has successfully grabbed/removed the screws from the location.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the screws are removed.
#     current step:
#         Use the robot_status_change function with Robot15 and set the status to 'idle' after the screws are removed.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of changing the robot's status using the 'robot_status_change' function. This function is under the control of the Controller, who is responsible for tasks such as moving robots, grabbing or removing items, and changing robot statuses. Therefore, the Controller is the appropriate worker to carry out the requested action.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot15 and set the status to 'idle' after the screws are removed.", "Robot15 has successfully removed the screws and is now set to 'idle' status.")
# ---
#
# replanner:
#     response:
#         Robot15, equipped with a screwdriver, has moved to position (3, 8) and successfully removed the screws. The robot is now set to 'idle' status, and the task is complete.
# ---

# %% [markdown]
# ## Medium test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Results\Result_matrix\Medium_react_matrix.txt"
clear_txt(file_name)

with open("Results\Tasks\Medium_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 100}
        inputs = {"input": task}
        i = 1
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
            if i == 50:
                # This is to ensure there is a response even though the it fails due recursion limit
                write_txt(file_name, "DNF;DNF;DNF;DNF\n")
                history.extend("DNF")
                break
            i+=1
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('Results\Raw_output\output_Medium_react.xlsx')
# Out:
# 1. task: Move to location (9, 5) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool to select a robot with the 'gripper' tool property, as it's required to remove items, and determine the best suited robot for the task at location (9, 5).
#     Move the selected robot to location (9, 5) using the move_robot function.
#     Use the grab_or_remove_item function to have the robot remove the toolkit located at (9, 5).
#     After the toolkit is removed, change the robot's status to 'idle' using the robot_status_change function.
#   current step:
#      Use the robot_selection_tool to select a robot with the 'gripper' tool property, as it's required to remove items, and determine the best suited robot for the task at location (9, 5).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The robot_selection_tool needs to be used to select a robot with the 'gripper' tool property for item removal at a specific location. The Robot_selector is responsible for selecting the correct robot based on provided criteria.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool to select a robot with the 'gripper' tool property, as it's required to remove items, and determine the best suited robot for the task at location (9, 5).", "The best suited robot to solve the task at location (9, 5) with the 'gripper' tool property is Robot42.")
# ---
#
# replanner:
#     plan:
#         Move Robot42 to location (9, 5) using the move_robot function.
#         Use the grab_or_remove_item function to have Robot42 remove the toolkit located at (9, 5).
#         After the toolkit is removed, change Robot42's status to 'idle' using the robot_status_change function.
#     current step:
#         Move Robot42 to location (9, 5) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to move a specific robot, Robot42, to a particular location (9, 5). The Controller is responsible for controlling robots and has the move_robot function which is required for this task. Therefore, the Controller is the appropriate worker to act next.
# ---
#
# Controller:
#    past steps: ('Move Robot42 to location (9, 5) using the move_robot function.', 'Robot42 has been successfully moved to the desired position (9, 5).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to have Robot42 remove the toolkit located at (9, 5).
#         After the toolkit is removed, change Robot42's status to 'idle' using the robot_status_change function.
#     current step:
#         Use the grab_or_remove_item function to have Robot42 remove the toolkit located at (9, 5).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action for a particular robot, Robot42, to perform a specific task - removing the toolkit located at (9, 5). The Controller is responsible for controlling the robots and has the tool 'grab_or_remove_item' which is required for this action. Therefore, the Controller is the correct worker to carry out the current_step of having Robot42 remove the toolkit.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to have Robot42 remove the toolkit located at (9, 5).', 'Robot42 has successfully grabbed or removed the toolkit located at (9, 5).')
# ---
#
# replanner:
#     plan:
#         After the toolkit is removed, change Robot42's status to 'idle' using the robot_status_change function.
#     current step:
#         After the toolkit is removed, change Robot42's status to 'idle' using the robot_status_change function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task is to change Robot42's status to 'idle' using the robot_status_change function, which is one of the tools available to the Controller. Therefore, the Controller is responsible for carrying out this action.
# ---
#
# Controller:
#    past steps: ("After the toolkit is removed, change Robot42's status to 'idle' using the robot_status_change function.", "Robot42's status has been changed to 'idle'.")
# ---
#
# replanner:
#     response:
#         The toolkit at location (9, 5) has been successfully removed by Robot42. The robot is now set to 'idle'. The task is complete.
# ---
#
# 2. task: Move to location (3, 8) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Select a robot equipped with a tool property suitable for cleaning liquid spills, such as a mop or a vacuum, using robot_selection_tool('cleaning_tool_property', (3, 8)).
#     Move the selected robot to location (3, 8) using move_robot(robot_name, (3, 8)).
#     Remove the liquid spill using grab_or_remove_item(robot_name, 'liquid_spill').
#     Change the robot's status to idle using robot_status_change(robot_name, 'idle').
#   current step:
#      Select a robot equipped with a tool property suitable for cleaning liquid spills, such as a mop or a vacuum, using robot_selection_tool('cleaning_tool_property', (3, 8)).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need for selecting a robot with a cleaning tool property suitable for dealing with liquid spills. The Robot_selector is responsible for selecting the appropriate robot using the robot_selection_tool, which matches the requirement of the task. Therefore, the Robot_selector should act next to determine the best-suited robot for this objective.
# ---
#
# Robot_selector:
#    past steps: ("Select a robot equipped with a tool property suitable for cleaning liquid spills, such as a mop or a vacuum, using robot_selection_tool('cleaning_tool_property', (3, 8)).", 'The best-suited robot to clean the liquid spill at location (3, 8) is Robot6, which is equipped with a mop.')
# ---
#
# replanner:
#     plan:
#         Move Robot6 to location (3, 8) using move_robot('Robot6', (3, 8)).
#         Remove the liquid spill using grab_or_remove_item('Robot6', 'liquid_spill').
#         Change Robot6's status to idle using robot_status_change('Robot6', 'idle').
#     current step:
#         Move Robot6 to location (3, 8) using move_robot('Robot6', (3, 8)).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of moving a robot to a desired location. The Controller is responsible for controlling the robots and has the tool 'move_robot' which is needed for this task. Since the robot name 'Robot6' is provided, the Controller can directly use the 'move_robot' function to move Robot6 to the location (3, 8).
# ---
#
# Controller:
#    past steps: ("Move Robot6 to location (3, 8) using move_robot('Robot6', (3, 8)).", 'Robot6 has been successfully moved to the location (3, 8).')
# ---
#
# replanner:
#     plan:
#         Remove the liquid spill using grab_or_remove_item('Robot6', 'liquid_spill').
#         Change Robot6's status to idle using robot_status_change('Robot6', 'idle').
#     current step:
#         Remove the liquid spill using grab_or_remove_item('Robot6', 'liquid_spill').
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of removing a liquid spill using the 'grab_or_remove_item' tool and identifies 'Robot6' as the specific robot to perform the task. Since the Controller is responsible for controlling robots and using tools such as 'move_robot', 'grab_or_remove_item', and 'robot_status_change', and because the action required is within the scope of the Controller's responsibilities, the Controller should act next to carry out the task.
# ---
#
# Controller:
#    past steps: ("Remove the liquid spill using grab_or_remove_item('Robot6', 'liquid_spill').", 'The liquid spill has been successfully handled by Robot6.')
# ---
#
# replanner:
#     plan:
#         Change Robot6's status to idle using robot_status_change('Robot6', 'idle').
#     current step:
#         Change Robot6's status to idle using robot_status_change('Robot6', 'idle').
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to change a robot's status to idle. The Controller is responsible for controlling robots and has the tool 'robot_status_change' which is needed to complete the current_step.
# ---
#
# Controller:
#    past steps: ("Change Robot6's status to idle using robot_status_change('Robot6', 'idle').", "Robot6's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The liquid spill at location (3, 8) has been successfully cleaned by Robot6, which was equipped with a mop. Robot6's status is now set to idle.
# ---
#
# 3. task: Move to location (1, 4) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the robot_selection_tool to find a robot with a gripper or front loader tool property, which is needed for removing large debris, to move to location (1, 4).
#     Move the selected robot to location (1, 4) using the move_robot function.
#     Use the grab_or_remove_item function to remove the large debris from location (1, 4).
#     Once the large debris is removed, set the robot's status to idle using the robot_status_change function.
#   current step:
#      Use the robot_selection_tool to find a robot with a gripper or front loader tool property, which is needed for removing large debris, to move to location (1, 4).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to find a robot with a specific tool property (gripper or front loader) for a task (removing large debris) but does not specify a particular robot. The Robot_selector is responsible for selecting the correct robot when no specific robot is mentioned, using the robot_selection_tool to determine the best suited robot based on the desired tool property and item position.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to find a robot with a gripper or front loader tool property, which is needed for removing large debris, to move to location (1, 4).', 'The best-suited robot to remove large debris with a gripper tool property and move to location (1, 4) is Robot2.')
# ---
#
# replanner:
#     plan:
#         Move Robot2 to location (1, 4) using the move_robot function.
#         Use the grab_or_remove_item function to remove the large debris from location (1, 4).
#         Once the large debris is removed, set Robot2's status to idle using the robot_status_change function.
#     current step:
#         Move Robot2 to location (1, 4) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of moving a robot (Robot2) to a certain location (1, 4) and mentions the use of the move_robot function which is a tool controlled by the Controller. Therefore, the Controller is the appropriate worker to perform this task.
# ---
#
# Controller:
#    past steps: ('Move Robot2 to location (1, 4) using the move_robot function.', 'Robot2 has been moved to the desired position (1, 4).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to remove the large debris from location (1, 4).
#         Once the large debris is removed, set Robot2's status to idle using the robot_status_change function.
#     current step:
#         Use the grab_or_remove_item function to remove the large debris from location (1, 4).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action to be performed, which is 'grab_or_remove_item', a function within the Controller's set of tools. Since the specific function and the item location are given, the Controller is the appropriate worker to execute the task of removing the large debris from location (1, 4).
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to remove the large debris from location (1, 4).', 'The large debris at location (1, 4) has been removed.')
# ---
#
# replanner:
#     plan:
#         Set Robot2's status to idle using the robot_status_change function.
#     current step:
#         Set Robot2's status to idle using the robot_status_change function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action that involves changing a robot's status, which is a functionality of the Controller's toolset. Specifically, the tool 'robot_status_change' is designed to change the status of a robot to idle, active, or charging. Since the request is to set Robot2's status to idle, the Controller is the appropriate worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Set Robot2's status to idle using the robot_status_change function.", "Robot2's status has been set to idle.")
# ---
#
# replanner:
#     response:
#         The task to remove the large debris at location (1, 4) has been completed successfully. Robot2 with gripper tool property was used, and it has now been set to idle. No further steps are needed.
# ---
#
# 4. task: Move to location (6, 5) and remove the dust.
# ---
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[50], line 29
#      27 inputs = {"input": task}
#      28 i = 1
# ---> 29 async for event in app.astream(inputs, config=config):
#      30     for k, v in event.items():
#      31         if k != "__end__":
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\__init__.py:940, in Pregel.astream(self, input, config, output_keys, input_keys, interrupt_before_nodes, interrupt_after_nodes, debug, **kwargs)
#     937 async def input_stream() -> AsyncIterator[Union[dict[str, Any], Any]]:
#     938     yield input
# --> 940 async for chunk in self.atransform(
#     941     input_stream(),
#     942     config,
#     943     output_keys=output_keys,
#     944     input_keys=input_keys,
#     945     interrupt_before_nodes=interrupt_before_nodes,
#     946     interrupt_after_nodes=interrupt_after_nodes,
#     947     debug=debug,
#     948     **kwargs,
#     949 ):
#     950     yield chunk
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\__init__.py:964, in Pregel.atransform(self, input, config, output_keys, input_keys, interrupt_before_nodes, interrupt_after_nodes, debug, **kwargs)
#     952 async def atransform(
#     953     self,
#     954     input: AsyncIterator[Union[dict[str, Any], Any]],
#    (...)
#     962     **kwargs: Any,
#     963 ) -> AsyncIterator[Union[dict[str, Any], Any]]:
# --> 964     async for chunk in self._atransform_stream_with_config(
#     965         input,
#     966         self._atransform,
#     967         config,
#     968         output_keys=output_keys,
#     969         input_keys=input_keys,
#     970         interrupt_before_nodes=interrupt_before_nodes,
#     971         interrupt_after_nodes=interrupt_after_nodes,
#     972         debug=debug,
#     973         **kwargs,
#     974     ):
#     975         yield chunk
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:1980, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1978 while True:
#    1979     if accepts_context(asyncio.create_task):
# -> 1980         chunk: Output = await asyncio.create_task(  # type: ignore[call-arg]
#    1981             py_anext(iterator),  # type: ignore[arg-type]
#    1982             context=context,
#    1983         )
#    1984     else:
#    1985         chunk = cast(Output, await py_anext(iterator))
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:222, in _AsyncGeneratorContextManager.__aexit__(self, typ, value, traceback)
#     220     value = typ()
#     221 try:
# --> 222     await self.gen.athrow(typ, value, traceback)
#     223 except StopAsyncIteration as exc:
#     224     # Suppress StopIteration *unless* it's the same exception that
#     225     # was passed to throw().  This prevents a StopIteration
#     226     # raised inside the "with" statement from being suppressed.
#     227     return exc is not value
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\channels\base.py:109, in AsyncChannelsManager(channels, checkpoint)
#     105 empty = {
#     106     k: v.aempty(checkpoint["channel_values"].get(k)) for k, v in channels.items()
#     107 }
#     108 try:
# --> 109     yield {k: await v.__aenter__() for k, v in empty.items()}
#     110 finally:
#     111     for v in empty.values():
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\__init__.py:763, in Pregel._atransform(self, input, run_manager, config, **kwargs)
#     756 done, inflight = await asyncio.wait(
#     757     futures,
#     758     return_when=asyncio.FIRST_EXCEPTION,
#     759     timeout=self.step_timeout,
#     760 )
#     762 # panic on failure or timeout
# --> 763 _panic_or_proceed(done, inflight, step)
#     765 # apply writes to channels
#     766 _apply_writes(
#     767     checkpoint, channels, pending_writes, config, step + 1
#     768 )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\__init__.py:990, in _panic_or_proceed(done, inflight, step)
#     988             inflight.pop().cancel()
#     989         # raise the exception
# --> 990         raise exc
#     991         # TODO this is where retry of an entire step would happen
#     993 if inflight:
#     994     # if we got here means we timed out
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:4537, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    4531 async def ainvoke(
#    4532     self,
#    4533     input: Input,
#    4534     config: Optional[RunnableConfig] = None,
#    4535     **kwargs: Optional[Any],
#    4536 ) -> Output:
# -> 4537     return await self.bound.ainvoke(
#    4538         input,
#    4539         self._merge_configs(config),
#    4540         **{**self.kwargs, **kwargs},
#    4541     )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:2536, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    2534 try:
#    2535     for i, step in enumerate(self.steps):
# -> 2536         input = await step.ainvoke(
#    2537             input,
#    2538             # mark each step as a child run
#    2539             patch_config(
#    2540                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2541             ),
#    2542         )
#    2543 # finish the root run
#    2544 except BaseException as e:
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3983, in RunnableLambda.ainvoke(self, input, config, **kwargs)
#    3981 """Invoke this runnable asynchronously."""
#    3982 the_func = self.afunc if hasattr(self, "afunc") else self.func
# -> 3983 return await self._acall_with_config(
#    3984     self._ainvoke,
#    3985     input,
#    3986     self._config(config, the_func),
#    3987     **kwargs,
#    3988 )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:1676, in Runnable._acall_with_config(self, func, input, config, run_type, **kwargs)
#    1672 coro = acall_func_with_variable_args(
#    1673     func, input, config, run_manager, **kwargs
#    1674 )
#    1675 if accepts_context(asyncio.create_task):
# -> 1676     output: Output = await asyncio.create_task(coro, context=context)  # type: ignore
#    1677 else:
#    1678     output = await coro
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3930, in RunnableLambda._ainvoke(self, input, run_manager, config, **kwargs)
#    3928                 output = chunk
#    3929 else:
# -> 3930     output = await acall_func_with_variable_args(
#    3931         cast(Callable, afunc), input, config, run_manager, **kwargs
#    3932     )
#    3933 # If the output is a runnable, invoke it
#    3934 if isinstance(output, Runnable):
#
# Cell In[44], line 25, in plan_step(state)
#      24 async def plan_step(state: PlanExecute):
# ---> 25     plan = await planner.ainvoke({"objective": state["input"]})
#      26     return {"plan": plan.steps, "current_step": plan.current_step}
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:2536, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    2534 try:
#    2535     for i, step in enumerate(self.steps):
# -> 2536         input = await step.ainvoke(
#    2537             input,
#    2538             # mark each step as a child run
#    2539             patch_config(
#    2540                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2541             ),
#    2542         )
#    2543 # finish the root run
#    2544 except BaseException as e:
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:4537, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    4531 async def ainvoke(
#    4532     self,
#    4533     input: Input,
#    4534     config: Optional[RunnableConfig] = None,
#    4535     **kwargs: Optional[Any],
#    4536 ) -> Output:
# -> 4537     return await self.bound.ainvoke(
#    4538         input,
#    4539         self._merge_configs(config),
#    4540         **{**self.kwargs, **kwargs},
#    4541     )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:179, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     170 async def ainvoke(
#     171     self,
#     172     input: LanguageModelInput,
#    (...)
#     176     **kwargs: Any,
#     177 ) -> BaseMessage:
#     178     config = ensure_config(config)
# --> 179     llm_result = await self.agenerate_prompt(
#     180         [self._convert_input(input)],
#     181         stop=stop,
#     182         callbacks=config.get("callbacks"),
#     183         tags=config.get("tags"),
#     184         metadata=config.get("metadata"),
#     185         run_name=config.get("run_name"),
#     186         run_id=config.pop("run_id", None),
#     187         **kwargs,
#     188     )
#     189     return cast(ChatGeneration, llm_result.generations[0][0]).message
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:570, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     562 async def agenerate_prompt(
#     563     self,
#     564     prompts: List[PromptValue],
#    (...)
#     567     **kwargs: Any,
#     568 ) -> LLMResult:
#     569     prompt_messages = [p.to_messages() for p in prompts]
# --> 570     return await self.agenerate(
#     571         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     572     )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:530, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     517     if run_managers:
#     518         await asyncio.gather(
#     519             *[
#     520                 run_manager.on_llm_end(
#    (...)
#     528             ]
#     529         )
# --> 530     raise exceptions[0]
#     531 flattened_outputs = [
#     532     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item, union-attr]
#     533     for res in results
#     534 ]
#     535 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:715, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#     713 else:
#     714     if inspect.signature(self._agenerate).parameters.get("run_manager"):
# --> 715         result = await self._agenerate(
#     716             messages, stop=stop, run_manager=run_manager, **kwargs
#     717         )
#     718     else:
#     719         result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_openai\chat_models\base.py:649, in ChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#     647 message_dicts, params = self._create_message_dicts(messages, stop)
#     648 params = {**params, **kwargs}
# --> 649 response = await self.async_client.create(messages=message_dicts, **params)
#     650 return self._create_chat_result(response)
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\resources\chat\completions.py:1334, in AsyncCompletions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1282 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1283 async def create(
#    1284     self,
#    (...)
#    1332     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1333 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
# -> 1334     return await self._post(
#    1335         "/chat/completions",
#    1336         body=await async_maybe_transform(
#    1337             {
#    1338                 "messages": messages,
#    1339                 "model": model,
#    1340                 "frequency_penalty": frequency_penalty,
#    1341                 "function_call": function_call,
#    1342                 "functions": functions,
#    1343                 "logit_bias": logit_bias,
#    1344                 "logprobs": logprobs,
#    1345                 "max_tokens": max_tokens,
#    1346                 "n": n,
#    1347                 "presence_penalty": presence_penalty,
#    1348                 "response_format": response_format,
#    1349                 "seed": seed,
#    1350                 "stop": stop,
#    1351                 "stream": stream,
#    1352                 "temperature": temperature,
#    1353                 "tool_choice": tool_choice,
#    1354                 "tools": tools,
#    1355                 "top_logprobs": top_logprobs,
#    1356                 "top_p": top_p,
#    1357                 "user": user,
#    1358             },
#    1359             completion_create_params.CompletionCreateParams,
#    1360         ),
#    1361         options=make_request_options(
#    1362             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1363         ),
#    1364         cast_to=ChatCompletion,
#    1365         stream=stream or False,
#    1366         stream_cls=AsyncStream[ChatCompletionChunk],
#    1367     )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1738, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1724 async def post(
#    1725     self,
#    1726     path: str,
#    (...)
#    1733     stream_cls: type[_AsyncStreamT] | None = None,
#    1734 ) -> ResponseT | _AsyncStreamT:
#    1735     opts = FinalRequestOptions.construct(
#    1736         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1737     )
# -> 1738     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1441, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1432 async def request(
#    1433     self,
#    1434     cast_to: Type[ResponseT],
#    (...)
#    1439     remaining_retries: Optional[int] = None,
#    1440 ) -> ResponseT | _AsyncStreamT:
# -> 1441     return await self._request(
#    1442         cast_to=cast_to,
#    1443         options=options,
#    1444         stream=stream,
#    1445         stream_cls=stream_cls,
#    1446         remaining_retries=remaining_retries,
#    1447     )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1517, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1515 if retries > 0 and self._should_retry(err.response):
#    1516     await err.response.aclose()
# -> 1517     return await self._retry_request(
#    1518         options,
#    1519         cast_to,
#    1520         retries,
#    1521         err.response.headers,
#    1522         stream=stream,
#    1523         stream_cls=stream_cls,
#    1524     )
#    1526 # If the response is streamed then we need to explicitly read the response
#    1527 # to completion before attempting to access the response text.
#    1528 if not err.response.is_closed:
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1563, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1559 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1561 await anyio.sleep(timeout)
# -> 1563 return await self._request(
#    1564     options=options,
#    1565     cast_to=cast_to,
#    1566     remaining_retries=remaining,
#    1567     stream=stream,
#    1568     stream_cls=stream_cls,
#    1569 )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1517, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1515 if retries > 0 and self._should_retry(err.response):
#    1516     await err.response.aclose()
# -> 1517     return await self._retry_request(
#    1518         options,
#    1519         cast_to,
#    1520         retries,
#    1521         err.response.headers,
#    1522         stream=stream,
#    1523         stream_cls=stream_cls,
#    1524     )
#    1526 # If the response is streamed then we need to explicitly read the response
#    1527 # to completion before attempting to access the response text.
#    1528 if not err.response.is_closed:
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1563, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1559 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1561 await anyio.sleep(timeout)
# -> 1563 return await self._request(
#    1564     options=options,
#    1565     cast_to=cast_to,
#    1566     remaining_retries=remaining,
#    1567     stream=stream,
#    1568     stream_cls=stream_cls,
#    1569 )
#
# File c:\Users\frede\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1532, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1529         await err.response.aread()
#    1531     log.debug("Re-raising status error")
# -> 1532     raise self._make_status_error_from_response(err.response) from None
#    1534 return await self._process_response(
#    1535     cast_to=cast_to,
#    1536     options=options,
#    (...)
#    1539     stream_cls=stream_cls,
#    1540 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## Hard test

# %%
from langchain_core.messages import HumanMessage
from openpyxl import Workbook
import csv

# Create a new Excel workbook and select the active worksheet
wb = Workbook()
ws = wb.active

# Open the task file and read tasks one by one
file_name = "Results\Result_matrix\Hard_react_matrix.txt"
clear_txt(file_name)

with open("Results\Tasks\Hard_tasks_test.txt", 'r') as file:
    row = 1

    while True:
        task = task_iteration(file)
        if not task:
            break
        
        # Print the task number and task to the console
        print(f"{row}. task: {task}")
        print("---")

        history = []
        config = {"recursion_limit": 100}
        inputs = {"input": task}
        i = 1
        async for event in app.astream(inputs, config=config):
            for k, v in event.items():
                if k != "__end__":
                    response_data = process_ReAct_response(k, v)
                    history.extend(response_data)
                    
            if i == 50:
                # This is to ensure there is a response even though the it fails due recursion limit
                write_txt(file_name, "DNF;DNF;DNF;DNF\n")
                history.extend("DNF")
                break
            i+=1
        
        # Write task and processed data to the Excel sheet
        ws.cell(row=row, column=1, value=task)
        ws.cell(row=row, column=2, value="\n".join(history))
        row += 1

wb.save('Results\Raw_output\output_Hard_react.xlsx')
# Out:
# 1. task: Move Robot40 to location (4, 8) and remove the toolkit.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool function with Robot40 and the 'gripper' tool property to ensure Robot40 is equipped to grab items.
#     Utilize the move_robot function with Robot40 and the coordinates (4, 8) to move the robot to the desired location.
#     Once Robot40 is at location (4, 8), use the grab_or_remove_item function with Robot40 and the item_name 'toolkit' to remove the toolkit.
#     After the toolkit has been removed, utilize the robot_status_change function with Robot40 and the status 'idle' to set the robot's status to idle.
#   current step:
#      Use the select_known_robot_tool function with Robot40 and the 'gripper' tool property to ensure Robot40 is equipped to grab items.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to use the 'select_known_robot_tool' to verify if Robot40 is equipped with the 'gripper' tool property necessary for grabbing items. This task falls under the responsibilities of the Robot_selector, who has access to the 'select_known_robot_tool'. Therefore, the Robot_selector should act next to ensure Robot40 is properly equipped to perform the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool function with Robot40 and the 'gripper' tool property to ensure Robot40 is equipped to grab items.", 'The initial selected tool for Robot40 was a "gripper," which is suitable for grabbing items. However, Robot40 is equipped with a "vacuum," which according to the list of items with associated tool properties, is suitable for cleaning dust and small debris. Since a "vacuum" cannot grab items like a "gripper" can, Robot40 cannot solve the task with its current tool property: vacuum. The task requires a tool that can physically grip and handle objects, which is not a function a vacuum can perform.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool function with the 'gripper' tool property and the coordinates (4, 8) to determine the best-suited robot to solve the objective.
#         Utilize the move_robot function with the selected robot and the coordinates (4, 8) to move the robot to the desired location.
#         Once the selected robot is at location (4, 8), use the grab_or_remove_item function with the selected robot and the item_name 'toolkit' to remove the toolkit.
#         After the toolkit has been removed, utilize the robot_status_change function with the selected robot and the status 'idle' to set the robot's status to idle.
#     current step:
#         Use the robot_selection_tool function with the 'gripper' tool property and the coordinates (4, 8) to determine the best-suited robot to solve the objective.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the use of the 'robot_selection_tool' with a desired property ('gripper') and item position ((4, 8)). This task falls under the responsibility of the Robot_selector, who is equipped with the 'robot_selection_tool' to determine the best-suited robot for the job.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool function with the 'gripper' tool property and the coordinates (4, 8) to determine the best-suited robot to solve the objective.", "The best-suited robot to solve the task with the 'gripper' tool property at coordinates (4, 8) is Robot2.")
# ---
#
# replanner:
#     plan:
#         Utilize the move_robot function with Robot2 and the coordinates (4, 8) to move the robot to the desired location.
#         Once Robot2 is at location (4, 8), use the grab_or_remove_item function with Robot2 and the item_name 'toolkit' to remove the toolkit.
#         After the toolkit has been removed, utilize the robot_status_change function with Robot2 and the status 'idle' to set the robot's status to idle.
#     current step:
#         Utilize the move_robot function with Robot2 and the coordinates (4, 8) to move the robot to the desired location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user requested the use of the 'move_robot' function with a specific robot, Robot2, and provided coordinates (4, 8). The Controller is responsible for controlling the robots and has the 'move_robot' tool to move a selected robot to a given position. Since the robot and coordinates are specified, the Controller is the appropriate worker to carry out this action.
# ---
#
# Controller:
#    past steps: ('Utilize the move_robot function with Robot2 and the coordinates (4, 8) to move the robot to the desired location.', 'Robot2 has been successfully moved to the coordinates (4, 8).')
# ---
#
# replanner:
#     plan:
#         Once Robot2 is at location (4, 8), use the grab_or_remove_item function with Robot2 and the item_name 'toolkit' to remove the toolkit.
#         After the toolkit has been removed, utilize the robot_status_change function with Robot2 and the status 'idle' to set the robot's status to idle.
#     current step:
#         Once Robot2 is at location (4, 8), use the grab_or_remove_item function with Robot2 and the item_name 'toolkit' to remove the toolkit.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action that falls within the responsibilities of the Controller, which is to use the 'grab_or_remove_item' function. The request also specifies the robot (Robot2) and the item ('toolkit') involved in the action, which aligns with the Controller's tool functionality for manipulating items with robots.
# ---
#
# Controller:
#    past steps: ("Once Robot2 is at location (4, 8), use the grab_or_remove_item function with Robot2 and the item_name 'toolkit' to remove the toolkit.", "Robot2 has successfully moved to the location (4, 8) and has grabbed/removed the item 'toolkit'.")
# ---
#
# replanner:
#     plan:
#         After the toolkit has been removed, utilize the robot_status_change function with Robot2 and the status 'idle' to set the robot's status to idle.
#     current step:
#         After the toolkit has been removed, utilize the robot_status_change function with Robot2 and the status 'idle' to set the robot's status to idle.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The request directly specifies the use of the 'robot_status_change' function to set Robot2's status to 'idle'. This function is one of the tools that the Controller is responsible for using. Therefore, the Controller is the correct worker to act next to perform the current_step.
# ---
#
# Controller:
#    past steps: ("After the toolkit has been removed, utilize the robot_status_change function with Robot2 and the status 'idle' to set the robot's status to idle.", "Robot2's status has been successfully set to idle.")
# ---
#
# replanner:
#     response:
#         Robot2 with the gripper tool property has successfully moved to location (4, 8) and removed the toolkit. The robot's status is now set to idle.
# ---
#
# 2. task: Move Robot40 to location (6, 2) and remove the liquid spill.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to ensure Robot40 is equipped with a tool property capable of dealing with liquid spills, such as a mop or vacuum.
#     Use the move_robot tool to instruct Robot40 to move to location (6, 2).
#     Use the grab_or_remove_item tool to command Robot40 to remove the liquid spill at location (6, 2).
#     Use the robot_status_change tool to set Robot40's status to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool to ensure Robot40 is equipped with a tool property capable of dealing with liquid spills, such as a mop or vacuum.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The task requires the use of the select_known_robot_tool to verify that Robot40 has the appropriate tool property for dealing with liquid spills. The Robot_selector is responsible for using this tool and can determine if the robot is properly equipped to handle the objective.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to ensure Robot40 is equipped with a tool property capable of dealing with liquid spills, such as a mop or vacuum.', 'The initial selected tool for dealing with liquid spills was a mop. According to the list of items with associated tool properties, a mop is the appropriate tool for cleaning up liquid spills. Robot40 does not have a mop, but it does have a vacuum.\n\nHowever, a vacuum is not on the list for dealing with liquid spills; it is listed for dust and small debris. Therefore, based on the provided list and the strict adherence to it, Robot40 with a vacuum tool property cannot solve the task of dealing with liquid spills, as it requires a mop according to the specifications.')
# ---
#
# replanner:
#     plan:
#         Select a different robot with the necessary tool property (mop) using the robot_selection_tool, as Robot40 is not equipped to handle the task.
#         Use the move_robot tool to instruct the newly selected robot to move to location (6, 2).
#         Use the grab_or_remove_item tool to command the newly selected robot to remove the liquid spill at location (6, 2).
#         Use the robot_status_change tool to set the new robot's status to idle after the task is complete.
#     current step:
#         Select a different robot with the necessary tool property (mop) using the robot_selection_tool, as Robot40 is not equipped to handle the task.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request indicates the need to select a different robot with a specific tool property (mop). The Robot_selector is responsible for selecting the correct robot using the robot_selection_tool, which is the appropriate action to fulfill the user's request.
# ---
#
# Robot_selector:
#    past steps: ('Select a different robot with the necessary tool property (mop) using the robot_selection_tool, as Robot40 is not equipped to handle the task.', 'Robot26 is the best suited to handle the task as it is equipped with a mop.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot tool to instruct Robot26 to move to location (6, 2).
#         Use the grab_or_remove_item tool to command Robot26 to remove the liquid spill at location (6, 2).
#         Use the robot_status_change tool to set Robot26's status to idle after the task is complete.
#     current step:
#         Use the move_robot tool to instruct Robot26 to move to location (6, 2).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action for a robot (Robot26) to move to a specific location (6, 2). The Controller is responsible for controlling the robots with a set of tools which includes the move_robot function, making it the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ('Use the move_robot tool to instruct Robot26 to move to location (6, 2).', 'Robot26 has been moved to the desired position (6, 2).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool to command Robot26 to remove the liquid spill at location (6, 2).
#         Use the robot_status_change tool to set Robot26's status to idle after the task is complete.
#     current step:
#         Use the grab_or_remove_item tool to command Robot26 to remove the liquid spill at location (6, 2).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct command using the 'grab_or_remove_item' tool for a specific robot, Robot26, to remove a spill at a specific location. Since the robot (Robot26) and action (remove the liquid spill) are mentioned, the Controller is the appropriate worker to execute this command with the specified tool.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item tool to command Robot26 to remove the liquid spill at location (6, 2).', 'Robot26 has removed the liquid spill at location (6, 2).')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool to set Robot26's status to idle after the task is complete.
#     current step:
#         Use the robot_status_change tool to set Robot26's status to idle after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots with a set of tools including the robot_status_change tool, which is needed to set Robot26's status to idle after the task is complete.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool to set Robot26's status to idle after the task is complete.", "Robot26's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot26, equipped with a mop, has successfully moved to location (6, 2) and removed the liquid spill. The robot's status has been set to idle, completing the task.
# ---
#
# 3. task: Move Robot9 to location (12, 3) and remove the large debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot9 and the tool property 'front loader' to ensure Robot9 is equipped to remove large debris.
#     Utilize the move_robot function with Robot9 and the desired position (12, 3) to move Robot9 to the correct location.
#     Apply the grab_or_remove_item function with Robot9 and the item name 'large debris' to remove the debris from the location.
#     Activate the robot_status_change function with Robot9 and the status 'idle' to set Robot9's status to idle after completing the objective.
#   current step:
#      Use the select_known_robot_tool with Robot9 and the tool property 'front loader' to ensure Robot9 is equipped to remove large debris.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to verify if a specific robot, Robot9, has a 'front loader' tool property to remove large debris. The Robot_selector is responsible for determining if a specified robot is equipped with the necessary tool to solve the objective, using the select_known_robot_tool. Therefore, the Robot_selector should act next to ensure Robot9 is suitable for the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot9 and the tool property 'front loader' to ensure Robot9 is equipped to remove large debris.", 'Robot9 has been selected and equipped with a front loader to remove large debris.')
# ---
#
# replanner:
#     plan:
#         Utilize the move_robot function with Robot9 and the desired position (12, 3) to move Robot9 to the correct location.
#         Apply the grab_or_remove_item function with Robot9 and the item name 'large debris' to remove the debris from the location.
#         Activate the robot_status_change function with Robot9 and the status 'idle' to set Robot9's status to idle after completing the objective.
#     current step:
#         Utilize the move_robot function with Robot9 and the desired position (12, 3) to move Robot9 to the correct location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions using the 'move_robot' function with Robot9 to move it to the position (12, 3). The 'Controller' is the worker responsible for controlling the robots and has access to the 'move_robot' tool required for this task.
# ---
#
# Controller:
#    past steps: ('Utilize the move_robot function with Robot9 and the desired position (12, 3) to move Robot9 to the correct location.', 'Robot9 has been successfully moved to the position (12, 3).')
# ---
#
# replanner:
#     plan:
#         Apply the grab_or_remove_item function with Robot9 and the item name 'large debris' to remove the debris from the location.
#         Activate the robot_status_change function with Robot9 and the status 'idle' to set Robot9's status to idle after completing the objective.
#     current step:
#         Apply the grab_or_remove_item function with Robot9 and the item name 'large debris' to remove the debris from the location.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action that involves a robot interacting with an item, namely using the function 'grab_or_remove_item' with Robot9 to remove 'large debris'. The Controller is responsible for tasks that directly control robots and their interactions with items, which includes using the 'grab_or_remove_item' function. Therefore, the Controller is the appropriate worker to act next in order to execute this specific task.
# ---
#
# Controller:
#    past steps: ("Apply the grab_or_remove_item function with Robot9 and the item name 'large debris' to remove the debris from the location.", 'Robot9 has successfully grabbed and removed the large debris from the location.')
# ---
#
# replanner:
#     plan:
#         Activate the robot_status_change function with Robot9 and the status 'idle' to set Robot9's status to idle after completing the objective.
#     current step:
#         Activate the robot_status_change function with Robot9 and the status 'idle' to set Robot9's status to idle after completing the objective.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots and has access to the tool 'robot_status_change' which is needed to set Robot9's status to 'idle' after completing the objective.
# ---
#
# Controller:
#    past steps: ("Activate the robot_status_change function with Robot9 and the status 'idle' to set Robot9's status to idle after completing the objective.", "Robot9's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         All tasks have been completed. Robot9 equipped with a front loader has successfully moved to location (12, 3), removed the large debris, and is now set to idle status.
# ---
#
# 4. task: Move Robot35 to location (2, 11) and remove the dust.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot35 and the 'vacuum' tool property to confirm if Robot35 is equipped to remove dust.
#     If Robot35 has the 'vacuum' tool property, use the move_robot tool with Robot35 and position (2, 11) to move the robot to the desired location.
#     Once Robot35 is at position (2, 11), use the grab_or_remove_item tool with Robot35 and the item name 'dust' to remove the dust from the location.
#     After the dust has been removed, use the robot_status_change tool with Robot35 to set its status to 'idle'.
#   current step:
#      Use the select_known_robot_tool with Robot35 and the 'vacuum' tool property to confirm if Robot35 is equipped to remove dust.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to use the 'select_known_robot_tool' to confirm if Robot35 is equipped with a 'vacuum' tool property, which is a task specific to the Robot_selector's responsibilities.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot35 and the 'vacuum' tool property to confirm if Robot35 is equipped to remove dust.", "Initially, the selected tool for the task of removing dust was 'vacuum'. However, Robot35 is equipped with a 'screwdriver', which is not suitable for dealing with dust. According to the list of items with associated tool properties, the appropriate tools for dust are either a vacuum or a broom. Since a screwdriver is not designed for cleaning and does not align with the necessary function to remove dust, Robot35 cannot solve the task with its current tool property: screwdriver.")
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with the 'vacuum' tool property and item position (2, 11) to determine the best suited robot to solve the objective.
#         Once the appropriate robot has been selected, use the move_robot tool with the selected robot's name and position (2, 11) to move the robot to the desired location.
#         After the selected robot is at position (2, 11), use the grab_or_remove_item tool with the selected robot's name and the item name 'dust' to remove the dust from the location.
#         Once the dust has been removed, use the robot_status_change tool with the selected robot to set its status to 'idle'.
#     current step:
#         Use the robot_selection_tool with the 'vacuum' tool property and item position (2, 11) to determine the best suited robot to solve the objective.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves selecting the best suited robot for the objective, which requires the use of the 'robot_selection_tool' with a specified tool property and item position. This is a task for the Robot_selector, as they are responsible for selecting the correct robot using the 'robot_selection_tool' when no specific robot is named in the objective.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with the 'vacuum' tool property and item position (2, 11) to determine the best suited robot to solve the objective.", "The best suited robot to solve the task with the 'vacuum' tool property at position (2, 11) is Robot50.")
# ---
#
# replanner:
#     plan:
#         Move Robot50 to location (2, 11) using the move_robot tool.
#         Once Robot50 is at location (2, 11), use the grab_or_remove_item tool with Robot50's name and the item name 'dust' to remove the dust from the location.
#         After the dust has been removed, use the robot_status_change tool with Robot50 to set its status to 'idle'.
#     current step:
#         Move Robot50 to location (2, 11) using the move_robot tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to move a specified robot, Robot50, to a certain location (2, 11). The Controller is responsible for controlling the robots with tools including move_robot, which is specifically used to move a selected robot to a given position. Therefore, the Controller is the appropriate worker to act next to fulfill this request.
# ---
#
# Controller:
#    past steps: ('Move Robot50 to location (2, 11) using the move_robot tool.', 'Robot50 has been successfully moved to the desired position (2, 11).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item tool with Robot50's name and the item name 'dust' to remove the dust from location (2, 11).
#         After the dust has been removed, use the robot_status_change tool with Robot50 to set its status to 'idle'.
#     current step:
#         Use the grab_or_remove_item tool with Robot50's name and the item name 'dust' to remove the dust from location (2, 11).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is for a specific action to be performed by a robot, namely 'Robot50', to remove an item called 'dust' from a specific location (2, 11). The Controller is responsible for controlling the robots using a set of tools, which includes the 'grab_or_remove_item' tool. This tool matches the requested action, therefore the Controller is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item tool with Robot50's name and the item name 'dust' to remove the dust from location (2, 11).", 'Robot50 has grabbed/removed the dust and has been moved to the location (2, 11).')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change tool with Robot50 to set its status to 'idle'.
#     current step:
#         Use the robot_status_change tool with Robot50 to set its status to 'idle'.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the tool 'robot_status_change' which is within the Controller's set of tools. The task involves changing the status of a specific robot, Robot50, to 'idle', which falls directly under the Controller's responsibilities.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change tool with Robot50 to set its status to 'idle'.", "Robot50's status has been successfully changed to idle.")
# ---
#
# replanner:
#     response:
#         Robot50 equipped with a vacuum has successfully moved to location (2, 11), removed the dust, and is now set to idle status.
# ---
#
# 5. task: Move Robot26 to location (12, 1) and remove the grass.
# ---
# planner:
#   plan:
#     Use the 'select_known_robot_tool' to verify if Robot26 is equipped with the 'lawnmower' tool property required for removing grass.
#     If Robot26 is not equipped with the 'lawnmower', select an alternative robot using 'robot_selection_tool' with the 'lawnmower' property and the position (12, 1).
#     Use the 'move_robot' function to move Robot26 or the alternative selected robot to the location (12, 1).
#     Use the 'grab_or_remove_item' function to remove the grass at location (12, 1) with Robot26 or the alternative selected robot.
#     Set the status of Robot26 or the alternative robot to 'idle' using the 'robot_status_change' function after completing the task.
#   current step:
#      Use the 'select_known_robot_tool' to verify if Robot26 is equipped with the 'lawnmower' tool property required for removing grass.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The 'select_known_robot_tool' is a tool within the Robot_selector's set of tools. The user request specifically asks to verify if Robot26 is equipped with the 'lawnmower' tool property, which is a task for the Robot_selector using the 'select_known_robot_tool'.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'select_known_robot_tool' to verify if Robot26 is equipped with the 'lawnmower' tool property required for removing grass.", "The initial selected tool for the task of removing grass was a 'lawnmower'. Robot26 is not equipped with a lawnmower but has a mop. According to the list of items with associated tool properties, a lawnmower is required to remove grass, and a mop is used for cleaning liquid spills. Since these tasks are very different and the tools are not interchangeable for these purposes, Robot26 with the tool property of a mop cannot solve the task of removing grass.")
# ---
#
# replanner:
#     plan:
#         Use the 'robot_selection_tool' with the 'lawnmower' property and the position (12, 1) to select an alternative robot capable of removing grass.
#         Use the 'move_robot' function to move the alternative selected robot to the location (12, 1).
#         Use the 'grab_or_remove_item' function to remove the grass at location (12, 1) with the alternative selected robot.
#         Set the status of the alternative robot to 'idle' using the 'robot_status_change' function after completing the task.
#     current step:
#         Use the 'robot_selection_tool' with the 'lawnmower' property and the position (12, 1) to select an alternative robot capable of removing grass.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request involves selecting an appropriate robot with a specific tool property ('lawnmower') for a task at a given position ((12, 1)). The 'robot_selection_tool' which is needed to fulfill this request is a part of the Robot_selector's toolkit. Therefore, the Robot_selector is the correct worker to act next in order to determine the best suited robot for the grass removal task.
# ---
#
# Robot_selector:
#    past steps: ("Use the 'robot_selection_tool' with the 'lawnmower' property and the position (12, 1) to select an alternative robot capable of removing grass.", 'Robot31 is the best suited robot to solve the task of removing grass at position (12, 1) with its lawnmower tool.')
# ---
#
# replanner:
#     plan:
#         Use the 'move_robot' function to move Robot31 to the location (12, 1).
#         Use the 'grab_or_remove_item' function to remove the grass at location (12, 1) with Robot31.
#         Set the status of Robot31 to 'idle' using the 'robot_status_change' function after completing the task.
#     current step:
#         Use the 'move_robot' function to move Robot31 to the location (12, 1).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action to move a robot (Robot31) to a specified location (12, 1). The Controller is responsible for controlling the robots and has the tool 'move_robot' which is needed to carry out this specific task. Since the robot is already specified, there is no need for the Robot_selector to act. The misc_agent is not relevant for this action as it deals with more generic questions.
# ---
#
# Controller:
#    past steps: ("Use the 'move_robot' function to move Robot31 to the location (12, 1).", 'Robot31 has been successfully moved to the location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Use the 'grab_or_remove_item' function to remove the grass at location (12, 1) with Robot31.
#         Set the status of Robot31 to 'idle' using the 'robot_status_change' function after completing the task.
#     current step:
#         Use the 'grab_or_remove_item' function to remove the grass at location (12, 1) with Robot31.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action involving a particular robot, Robot31, and a specific task, which is to remove grass at a given location. The 'grab_or_remove_item' function falls under the Controller's set of tools and is the appropriate function to execute this task. Therefore, the Controller should act next to fulfill the user's request.
# ---
#
# Controller:
#    past steps: ("Use the 'grab_or_remove_item' function to remove the grass at location (12, 1) with Robot31.", 'Robot31 has successfully removed the grass at location (12, 1).')
# ---
#
# replanner:
#     plan:
#         Set the status of Robot31 to 'idle' using the 'robot_status_change' function after completing the task.
#     current step:
#         Set the status of Robot31 to 'idle' using the 'robot_status_change' function after completing the task.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The 'robot_status_change' function is one of the tools that the Controller is responsible for using. Since the user request involves setting the status of Robot31 to 'idle' after completing a task, the Controller is the appropriate worker to perform this action.
# ---
#
# Controller:
#    past steps: ("Set the status of Robot31 to 'idle' using the 'robot_status_change' function after completing the task.", "The status of Robot31 has been successfully changed to 'idle'.")
# ---
#
# replanner:
#     response:
#         The grass at location (12, 1) has been successfully removed by Robot31, which is equipped with a lawnmower tool. The robot has been set to 'idle' status upon completion of the task.
# ---
#
# 6. task: Move Robot41 to location (4, 11) and remove the small debris.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify that Robot41 is equipped with a tool property capable of removing small debris, such as a vacuum or broom.
#     If Robot41 has the required tool property, use the move_robot function to move Robot41 to location (4, 11).
#     Once Robot41 is at location (4, 11), use the grab_or_remove_item function to remove the small debris.
#     After removing the small debris, use the robot_status_change function to set Robot41's status to idle.
#   current step:
#      Use the select_known_robot_tool to verify that Robot41 is equipped with a tool property capable of removing small debris, such as a vacuum or broom.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifically asks to verify if Robot41 has the necessary tool property to remove small debris. The Robot_selector is the worker equipped with the 'select_known_robot_tool' which is used to determine if a specified robot has the tool property required for a task. Therefore, the Robot_selector should act next to perform this verification.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to verify that Robot41 is equipped with a tool property capable of removing small debris, such as a vacuum or broom.', 'The initial selected tool properties for removing small debris were either a vacuum or broom. Robot41 is equipped with a lawnmower, which is not suitable for removing small debris according to the list of items with associated tool properties. Therefore, Robot41 cannot solve the task with the tool property: lawnmower, as it is intended for cutting grass and not for cleaning up small debris like a vacuum or broom would.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool to find a suitable robot equipped with a tool property capable of removing small debris, such as a vacuum or broom, at location (4, 11).
#         Once a suitable robot is identified, use the move_robot function to move the selected robot to location (4, 11).
#         After the robot has reached location (4, 11), use the grab_or_remove_item function to remove the small debris.
#         Following the removal of the small debris, use the robot_status_change function to set the robot's status to idle.
#     current step:
#         Use the robot_selection_tool to find a suitable robot equipped with a tool property capable of removing small debris, such as a vacuum or broom, at location (4, 11).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request requires the use of the robot_selection_tool to find a suitable robot with the capability to remove small debris. The Robot_selector is responsible for selecting the correct robot using the robot_selection_tool, which is the appropriate action for the current_step.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to find a suitable robot equipped with a tool property capable of removing small debris, such as a vacuum or broom, at location (4, 11).', 'Robot50 is the best suited to remove small debris at location (4, 11) as it is equipped with a vacuum.')
# ---
#
# replanner:
#     plan:
#         Move Robot50 to location (4, 11) using the move_robot function.
#         Use the grab_or_remove_item function to have Robot50 remove the small debris from location (4, 11).
#         After the small debris has been removed, set Robot50's status to idle using the robot_status_change function.
#     current step:
#         Move Robot50 to location (4, 11) using the move_robot function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the action of moving a robot to a certain location and identifies the specific robot (Robot50) by name. The Controller is responsible for controlling the robots with tools that include the move_robot function, which is directly mentioned in the user request. Therefore, the Controller is the appropriate worker to execute the current_step of moving Robot50 to the location (4, 11).
# ---
#
# Controller:
#    past steps: ('Move Robot50 to location (4, 11) using the move_robot function.', 'Robot50 has been successfully moved to the desired position (4, 11).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to have Robot50 remove the small debris from location (4, 11).
#         After the small debris has been removed, set Robot50's status to idle using the robot_status_change function.
#     current step:
#         Use the grab_or_remove_item function to have Robot50 remove the small debris from location (4, 11).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action for a named robot, Robot50, to remove an item, the small debris, from a specific location (4, 11). Since the robot's name and the required action are already provided, the Controller is the appropriate worker to execute the function 'grab_or_remove_item' as it is within their set of tools to control robot actions.
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to have Robot50 remove the small debris from location (4, 11).', 'Robot50 has successfully grabbed/removed the small debris.')
# ---
#
# replanner:
#     plan:
#         Set Robot50's status to idle using the robot_status_change function.
#     current step:
#         Set Robot50's status to idle using the robot_status_change function.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The task specifically mentions using the 'robot_status_change' function, which is one of the tools available to the Controller. Therefore, the Controller is the worker that should perform the current_step of setting Robot50's status to idle.
# ---
#
# Controller:
#    past steps: ("Set Robot50's status to idle using the robot_status_change function.", "Robot50's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The task is complete. Robot50 with a vacuum tool has successfully moved to location (4, 11) and removed the small debris. The robot's status has been set to idle.
# ---
#
# 7. task: Move Robot2 to location (9, 1) and remove the vehicle.
# ---
# planner:
#   plan:
#     Use select_known_robot_tool to confirm Robot2 is equipped with a tow hook capable of removing the vehicle.
#     Execute move_robot to move Robot2 to location (9, 1).
#     Use grab_or_remove_item to remove the vehicle at location (9, 1).
#     Set Robot2's status to idle using robot_status_change.
#   current step:
#      Use select_known_robot_tool to confirm Robot2 is equipped with a tow hook capable of removing the vehicle.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user has requested to use the 'select_known_robot_tool' to confirm if Robot2 is equipped with a tow hook capable of removing the vehicle. The Robot_selector is the correct worker to perform this task because it is responsible for selecting the correct robot and determining if the specified robot (Robot2) has the required tool property (a tow hook) to solve the objective.
# ---
#
# Robot_selector:
#    past steps: ('Use select_known_robot_tool to confirm Robot2 is equipped with a tow hook capable of removing the vehicle.', 'The initial selected tool for removing a vehicle is a "tow hook." According to the list of items with associated tool properties, a vehicle requires a "tow hook" to be manipulated. Robot2 is equipped with a "gripper," which is not listed as suitable for handling vehicles. Therefore, Robot2 cannot solve the task of removing the vehicle with its current tool property: gripper. The task requires a tow hook specifically for moving vehicles, which Robot2 does not possess.')
# ---
#
# replanner:
#     plan:
#         Select a robot with a tow hook capable of removing the vehicle using robot_selection_tool.
#         Execute move_robot to move the selected robot to location (9, 1).
#         Use grab_or_remove_item to remove the vehicle at location (9, 1).
#         Set the robot's status to idle using robot_status_change.
#     current step:
#         Select a robot with a tow hook capable of removing the vehicle using robot_selection_tool.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The current objective is to select a robot with a specific property (a tow hook) which is required for removing a vehicle. The robot_selection_tool is designed for this purpose when no specific robot has been previously selected. Therefore, the Robot_selector is the appropriate worker to act next to use the robot_selection_tool and determine the best suited robot for the task.
# ---
#
# Robot_selector:
#    past steps: ('Select a robot with a tow hook capable of removing the vehicle using robot_selection_tool.', 'The best suited robot to remove the vehicle with a tow hook is Robot13.')
# ---
#
# replanner:
#     plan:
#         Execute move_robot to move Robot13 to location (9, 1).
#         Use grab_or_remove_item to remove the vehicle at location (9, 1) with Robot13.
#         Set Robot13's status to idle using robot_status_change.
#     current step:
#         Execute move_robot to move Robot13 to location (9, 1).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving the movement of a robot to a specific location. The Controller is responsible for controlling the robots and has the tool 'move_robot' which is needed to carry out this specific task of moving Robot13 to the desired position (9, 1).
# ---
#
# Controller:
#    past steps: ('Execute move_robot to move Robot13 to location (9, 1).', 'Robot13 has been moved to the desired position (9, 1).')
# ---
#
# replanner:
#     plan:
#         Use grab_or_remove_item to remove the vehicle at location (9, 1) with Robot13.
#         Set Robot13's status to idle using robot_status_change.
#     current step:
#         Use grab_or_remove_item to remove the vehicle at location (9, 1) with Robot13.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'grab_or_remove_item' tool to remove an item with a known robot (Robot13). The Controller is responsible for using this tool, as it controls the robots and handles tasks such as grabbing or removing items.
# ---
#
# Controller:
#    past steps: ('Use grab_or_remove_item to remove the vehicle at location (9, 1) with Robot13.', 'Robot13 has successfully grabbed/removed the vehicle at location (9, 1).')
# ---
#
# replanner:
#     plan:
#         Set Robot13's status to idle using robot_status_change.
#     current step:
#         Set Robot13's status to idle using robot_status_change.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is to set Robot13's status to idle using the robot_status_change tool, which is a tool controlled by the Controller. Therefore, the Controller is the appropriate worker to perform the current_step.
# ---
#
# Controller:
#    past steps: ("Set Robot13's status to idle using robot_status_change.", "Robot13's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The task has been successfully completed. Robot13 equipped with a tow hook has moved to location (9, 1) and removed the vehicle. Robot13's status has been set to idle.
# ---
#
# 8. task: Move Robot28 to location (11, 6) and remove the construction materials.
# ---
# planner:
#   plan:
#     Select Robot28 using the select_known_robot_tool, ensuring it has the 'front loader' tool property capable of removing construction materials.
#     Change Robot28's status to 'active' using the robot_status_change tool.
#     Move Robot28 to location (11, 6) using the move_robot tool.
#     Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with Robot28.
#     Change Robot28's status to 'idle' using the robot_status_change tool after completing the objective.
#   current step:
#      Select Robot28 using the select_known_robot_tool, ensuring it has the 'front loader' tool property capable of removing construction materials.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies a particular robot (Robot28) and a required tool property ('front loader'). Since the task is to ensure that the specified robot is equipped with the necessary tool to complete the objective, the Robot_selector should use the select_known_robot_tool to confirm that Robot28 possesses the 'front loader' capability before any action is taken. This falls under the responsibility of the Robot_selector as described by the user request and the tool functionalities.
# ---
#
# Robot_selector:
#    past steps: ("Select Robot28 using the select_known_robot_tool, ensuring it has the 'front loader' tool property capable of removing construction materials.", 'The initial selected tool was "front loader," which is appropriate for removing construction materials as indicated in the provided list of items with associated tool properties. Robot28, however, is equipped with a "broom," which is not suitable for handling construction materials. According to the list, construction materials require a gripper, front loader, or tow hook for effective manipulation. Therefore, Robot28 with the tool property "broom" cannot solve the task of removing construction materials.')
# ---
#
# replanner:
#     plan:
#         Select a robot with the 'front loader' tool property capable of removing construction materials using the robot_selection_tool, since Robot28 does not have the necessary tool.
#         Change the selected robot's status to 'active' using the robot_status_change tool.
#         Move the selected robot to location (11, 6) using the move_robot tool.
#         Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with the selected robot.
#         Change the selected robot's status to 'idle' using the robot_status_change tool after completing the objective.
#     current step:
#         Select a robot with the 'front loader' tool property capable of removing construction materials using the robot_selection_tool, since Robot28 does not have the necessary tool.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector should act next because the user request specifies the need to select a robot with the 'front loader' tool property capable of removing construction materials. Since Robot28 does not have the necessary tool, the robot_selection_tool provided by the Robot_selector will be used to determine the best suited robot for the job.
# ---
#
# Robot_selector:
#    past steps: ("Select a robot with the 'front loader' tool property capable of removing construction materials using the robot_selection_tool, since Robot28 does not have the necessary tool.", "Robot39 is the best suited to solve the task of removing construction materials with its 'front loader' tool property.")
# ---
#
# replanner:
#     plan:
#         Change Robot39's status to 'active' using the robot_status_change tool.
#         Move Robot39 to location (11, 6) using the move_robot tool.
#         Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with Robot39.
#         Change Robot39's status to 'idle' using the robot_status_change tool after completing the objective.
#     current step:
#         Change Robot39's status to 'active' using the robot_status_change tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling the robots and has the tool 'robot_status_change' which is needed to change Robot39's status to 'active'.
# ---
#
# Controller:
#    past steps: ("Change Robot39's status to 'active' using the robot_status_change tool.", "Robot39's status has been changed to active.")
# ---
#
# replanner:
#     plan:
#         Move Robot39 to location (11, 6) using the move_robot tool.
#         Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with Robot39.
#         Change Robot39's status to 'idle' using the robot_status_change tool after completing the objective.
#     current step:
#         Move Robot39 to location (11, 6) using the move_robot tool.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a particular robot, Robot39, and a specific action, moving it to a location (11, 6). The Controller is responsible for controlling the robots with tools such as move_robot, which exactly matches the requested action. Therefore, the Controller should act next to execute the move_robot command.
# ---
#
# Controller:
#    past steps: ('Move Robot39 to location (11, 6) using the move_robot tool.', 'Robot39 has been successfully moved to the location (11, 6).')
# ---
#
# replanner:
#     plan:
#         Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with Robot39.
#         Change Robot39's status to 'idle' using the robot_status_change tool after completing the objective.
#     current step:
#         Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with Robot39.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies an action (remove construction materials) and a specific robot (Robot39) to perform the task using the 'grab_or_remove_item' tool. The Controller is responsible for controlling the robots and has the 'grab_or_remove_item' tool required for this task. Therefore, the Controller should act next to execute the removal of items using Robot39.
# ---
#
# Controller:
#    past steps: ('Remove the construction materials from location (11, 6) using the grab_or_remove_item tool with Robot39.', 'Robot39 has successfully grabbed or removed the construction materials from location (11, 6).')
# ---
#
# replanner:
#     plan:
#         Change Robot39's status to 'idle' using the robot_status_change tool after completing the objective.
#     current step:
#         Change Robot39's status to 'idle' using the robot_status_change tool after completing the objective.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifically mentions changing Robot39's status to 'idle' using the 'robot_status_change' tool, which is a tool controlled by the Controller. Therefore, the Controller should perform the current step.
# ---
#
# Controller:
#    past steps: ("Change Robot39's status to 'idle' using the robot_status_change tool after completing the objective.", "Robot39's status has been successfully changed to 'idle'.")
# ---
#
# replanner:
#     response:
#         Robot39 with the front loader tool has successfully removed the construction materials from location (11, 6) and is now set to idle status.
# ---
#
# 9. task: Move Robot39 to location (6, 1) and remove the tree branches.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool with Robot39 and the tool property 'saw' to ensure Robot39 is equipped to remove tree branches.
#     Use the move_robot function with 'Robot39' and the desired_position '(6, 1)' to move Robot39 to the location of the tree branches.
#     Use the grab_or_remove_item function with 'Robot39' and 'tree branches' to have Robot39 remove the tree branches.
#     Use the robot_status_change function with 'Robot39' and status 'idle' to set Robot39's status to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool with Robot39 and the tool property 'saw' to ensure Robot39 is equipped to remove tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The Robot_selector is responsible for selecting the correct robot and confirming its capabilities. Since the user request specifies Robot39 and a tool property 'saw' that is needed to remove tree branches, the Robot_selector should use the select_known_robot_tool to verify that Robot39 is equipped with a saw.
# ---
#
# Robot_selector:
#    past steps: ("Use the select_known_robot_tool with Robot39 and the tool property 'saw' to ensure Robot39 is equipped to remove tree branches.", "The initial selected tool for the task of removing tree branches was a 'saw'. According to the provided list of items with associated tool properties, the appropriate tool for manipulating tree branches is a 'saw', and there is no mention of a 'front loader' being suitable for this task. Therefore, Robot39, which is equipped with a 'front loader', cannot solve the task of removing tree branches, as it requires a saw to perform the task effectively and according to the specifications.")
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool with the tool property 'saw' and item_position '(6, 1)' to select the best suited robot to remove the tree branches.
#         Use the move_robot function with the selected robot name from the previous step and the desired position '(6, 1)' to move the robot to the location of the tree branches.
#         Use the grab_or_remove_item function with the selected robot's name and 'tree branches' to have the robot remove the tree branches.
#         Use the robot_status_change function with the selected robot's name and status 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the robot_selection_tool with the tool property 'saw' and item_position '(6, 1)' to select the best suited robot to remove the tree branches.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The task requires selecting the best suited robot to remove tree branches, which implies the need for a robot equipped with a 'saw' tool. Since no specific robot has been mentioned in the objective, the robot_selection_tool should be used with the desired robot tool property 'saw' and the item position '(6, 1)' to determine the appropriate robot for the task.
# ---
#
# Robot_selector:
#    past steps: ("Use the robot_selection_tool with the tool property 'saw' and item_position '(6, 1)' to select the best suited robot to remove the tree branches.", 'The best suited robot to remove the tree branches at position (6, 1) with the saw tool property is Robot14.')
# ---
#
# replanner:
#     plan:
#         Use the move_robot function with Robot14 and the desired position '(6, 1)' to move the robot to the location of the tree branches.
#         Use the grab_or_remove_item function with Robot14's name and 'tree branches' to have the robot remove the tree branches.
#         Use the robot_status_change function with Robot14's name and status 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the move_robot function with Robot14 and the desired position '(6, 1)' to move the robot to the location of the tree branches.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user has specified a direct action involving a particular robot (Robot14) and a desired position ('(6, 1)'). The Controller is responsible for controlling the robots with a set of tools, including the 'move_robot' function which is needed to move Robot14 to the specified location. Therefore, the Controller is the correct worker to act next to fulfill the request.
# ---
#
# Controller:
#    past steps: ("Use the move_robot function with Robot14 and the desired position '(6, 1)' to move the robot to the location of the tree branches.", 'Robot14 has been successfully moved to the position (6, 1).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function with Robot14's name and 'tree branches' to have the robot remove the tree branches.
#         Use the robot_status_change function with Robot14's name and status 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the grab_or_remove_item function with Robot14's name and 'tree branches' to have the robot remove the tree branches.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a clear action to be performed by a specific robot, Robot14, and involves the use of the 'grab_or_remove_item' tool which is within the Controller's set of tools. Therefore, the Controller is the appropriate worker to carry out this task.
# ---
#
# Controller:
#    past steps: ("Use the grab_or_remove_item function with Robot14's name and 'tree branches' to have the robot remove the tree branches.", 'Robot14 has successfully grabbed and removed the tree branches.')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function with Robot14's name and status 'idle' to set the robot's status to idle after the task is complete.
#     current step:
#         Use the robot_status_change function with Robot14's name and status 'idle' to set the robot's status to idle after the task is complete.
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request explicitly states the need to use the 'robot_status_change' function to set the robot's status to 'idle' after the task is complete. This function is one of the tools available to the Controller. Therefore, the Controller is the correct worker to perform this current_step.
# ---
#
# Controller:
#    past steps: ("Use the robot_status_change function with Robot14's name and status 'idle' to set the robot's status to idle after the task is complete.", "Robot14's status has been changed to idle.")
# ---
#
# replanner:
#     response:
#         The tree branches at location (6, 1) have been successfully removed by Robot14, which is equipped with a saw. The robot's status is now set to idle.
# ---
#
# 10. task: Move Robot28 to location (2, 8) and remove the screws.
# ---
# planner:
#   plan:
#     Use the select_known_robot_tool to verify that Robot28 is equipped with a screwdriver capable of removing screws.
#     Use the move_robot function to move Robot28 to the desired position (2, 8).
#     Use the grab_or_remove_item function to allow Robot28 to remove the screws at location (2, 8).
#     Use the robot_status_change function to set the status of Robot28 to idle after the task is complete.
#   current step:
#      Use the select_known_robot_tool to verify that Robot28 is equipped with a screwdriver capable of removing screws.
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The request is to use the select_known_robot_tool to verify if a specific robot, Robot28, has a tool property, in this case, a screwdriver. The Robot_selector is responsible for determining if a specified robot is equipped with a tool property capable of solving the objective, which fits the user's request.
# ---
#
# Robot_selector:
#    past steps: ('Use the select_known_robot_tool to verify that Robot28 is equipped with a screwdriver capable of removing screws.', 'The initial selected tool for removing screws was a screwdriver. However, Robot28 is equipped with a broom, which is not suitable for the task of removing screws. According to the provided list of items with associated tool properties, a screwdriver is required to manipulate screws. Therefore, Robot28 with a broom cannot solve the task of removing screws as it does not have the appropriate tool property for the job.')
# ---
#
# replanner:
#     plan:
#         Use the robot_selection_tool to determine the best suited robot with a screwdriver tool property for the task at location (2, 8).
#         Use the move_robot function to move the selected robot to the desired position (2, 8).
#         Use the grab_or_remove_item function to allow the selected robot to remove the screws at location (2, 8).
#         Use the robot_status_change function to set the status of the selected robot to idle after the task is complete.
#     current step:
#         Use the robot_selection_tool to determine the best suited robot with a screwdriver tool property for the task at location (2, 8).
# ---
#
# supervisor:
#    next agent: Robot_selector
#    reason: The user request specifies the need to select a robot with a particular tool property (screwdriver) for a task at a specific location. The Robot_selector is responsible for selecting the correct robot, and the robot_selection_tool is designed to determine the best suited robot based on a desired robot tool property and the item's position. Therefore, the Robot_selector should use the robot_selection_tool to fulfill this request.
# ---
#
# Robot_selector:
#    past steps: ('Use the robot_selection_tool to determine the best suited robot with a screwdriver tool property for the task at location (2, 8).', 'The best suited robot for the task that requires a screwdriver at location (2, 8) is Robot45.')
# ---
#
# replanner:
#     plan:
#         Move Robot45 to location (2, 8).
#         Use the grab_or_remove_item function to allow Robot45 to remove the screws at location (2, 8).
#         Use the robot_status_change function to set the status of Robot45 to idle after the task is complete.
#     current step:
#         Move Robot45 to location (2, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies a direct action involving moving a known robot (Robot45) to a defined location (2, 8). The Controller is responsible for controlling the robots with tools that include 'move_robot', which is the appropriate tool for this task. Therefore, the Controller should act next to execute the move_robot function for Robot45.
# ---
#
# Controller:
#    past steps: ('Move Robot45 to location (2, 8).', 'Robot45 has been moved to the desired position (2, 8).')
# ---
#
# replanner:
#     plan:
#         Use the grab_or_remove_item function to allow Robot45 to remove the screws at location (2, 8).
#         Use the robot_status_change function to set the status of Robot45 to idle after the task is complete.
#     current step:
#         Use the grab_or_remove_item function to allow Robot45 to remove the screws at location (2, 8).
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request is specific in terms of the action to be taken and the robot involved (Robot45). The Controller is responsible for controlling the robots using the set of tools provided, which includes the 'grab_or_remove_item' function. Since the robot's name (Robot45) and the item name (the screws) are both specified, the Controller is the appropriate worker to perform the current step of using the 'grab_or_remove_item' function to allow Robot45 to remove the screws at location (2, 8).
# ---
#
# Controller:
#    past steps: ('Use the grab_or_remove_item function to allow Robot45 to remove the screws at location (2, 8).', 'Robot45 has successfully grabbed or removed the screws.')
# ---
#
# replanner:
#     plan:
#         Move Robot45 to location (2, 8)
#         Use the grab_or_remove_item function to allow Robot45 to remove the screws at location (2, 8)
#         Use the robot_status_change function to set the status of Robot45 to idle after the task is complete
#     current step:
#         Use the robot_status_change function to set the status of Robot45 to idle after the task is complete
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The user request specifies the use of the 'robot_status_change' function to set the status of Robot45 to idle. This function is one of the tools controlled by the Controller. Therefore, the Controller is the appropriate worker to act next to perform the requested task.
# ---
#
# Controller:
#    past steps: ('Move Robot45 to location (2, 8)', 'Robot45 has been successfully moved to the location (2, 8).')
# ---
#
# replanner:
#     plan:
#         Use the robot_status_change function to set the status of Robot45 to idle after the task is complete
#     current step:
#         Use the robot_status_change function to set the status of Robot45 to idle after the task is complete
# ---
#
# supervisor:
#    next agent: Controller
#    reason: The Controller is responsible for controlling robots and has the tool robot_status_change, which is needed to set the status of Robot45 to idle after the task is complete.
# ---
#
# Controller:
#    past steps: ('Use the robot_status_change function to set the status of Robot45 to idle after the task is complete', 'The status of Robot45 has been changed to idle.')
# ---
#
# replanner:
#     response:
#         Robot45 equipped with a screwdriver has successfully moved to location (2, 8) and removed the screws. The task is complete and the robot's status has been set to idle.
# ---
